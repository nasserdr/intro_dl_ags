# %% [markdown]
# # Transfer learning - Learning Rate

# %% [markdown]
# Readings:
# - https://arxiv.org/abs/1506.01186 (Cyclical Learning Rates for Training Neural Networks)
# - Jeremy Jordan post: https://www.jeremyjordan.me/nn-learning-rate/
# - Learning rate annealing: https://cs231n.github.io/neural-networks-3/#annealing-the-learning-rate
# - Experimental results show that 3e-4 is a good starting point for an Adam optimizer

# %% [markdown]
# ## Fine Tuning

# %%
# Setting seeds to try and ensure we have the same results - this is not guaranteed across PyTorch releases.
import torch
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
    ])

trainset = datasets.CIFAR10(root='data/CIFAR10',train=True, download=True,transform=transform)
testset = datasets.CIFAR10(root='data/CIFAR10',train=False, transform=transform)

trainloader = DataLoader(trainset, batch_size=64, shuffle=True)
testloader = DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# Files already downloaded and verified

# %%
for images, labels in trainloader:
  print(images.size(), labels.size())
  break
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64])

# %%
model = models.vgg16(pretrained=True)
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
  param.requires_grad = False

# %%
for i in range(0,7):
  model.classifier[i].requires_grad = True

# %%
model.classifier[6] = nn.Sequential(
                      nn.Linear(4096,512),
                      nn.ReLU(),
                      nn.Dropout(0.5),
                      nn.Linear(512,10),
                      nn.LogSoftmax(dim=1)
                      )

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Sequential(
#       (0): Linear(in_features=4096, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.5, inplace=False)
#       (3): Linear(in_features=512, out_features=10, bias=True)
#       (4): LogSoftmax(dim=1)
#     )
#   )
# )

# %%
criterion = nn.NLLLoss()

# %%
from torch.optim import Adam

model = model.to(device)

# %% [markdown]
# ## Training from the Fully Connected Network onwards

# %% [markdown]
# ### Re-training the model

# %%
from torch.optim import Adam

lr = 3e-4
optimizer = Adam([
    { 'params': model.classifier[0].parameters(), 'lr': lr},
    { 'params': model.classifier[3].parameters(), 'lr': lr},
    { 'params': model.classifier[6].parameters(), 'lr': lr}
    ], lr=lr)

# %%
model = model.to(device)
#optimizer = Adam(filter(lambda p: p.requires_grad, model.parameters()))

num_epochs = 1
batch_loss = 0
cum_epoch_loss = 0

for e in range(num_epochs):
  cum_epoch_loss = 0
  
  for batch, (images, labels) in enumerate(trainloader,1):
    images = images.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    logps = model(images)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()
    
    batch_loss += loss.item()
    print(f'Epoch({e}/{num_epochs} : Batch number({batch}/{len(trainloader)}) : Batch loss : {loss.item()}')
    
  print(f'Training loss : {batch_loss/len(trainloader)}')
# Out:
# Epoch(0/1 : Batch number(1/782) : Batch loss : 2.3528125286102295
# Epoch(0/1 : Batch number(2/782) : Batch loss : 2.281886577606201
# Epoch(0/1 : Batch number(3/782) : Batch loss : 2.0992794036865234
# Epoch(0/1 : Batch number(4/782) : Batch loss : 2.1647257804870605
# Epoch(0/1 : Batch number(5/782) : Batch loss : 2.119939088821411
# Epoch(0/1 : Batch number(6/782) : Batch loss : 1.9770513772964478
# Epoch(0/1 : Batch number(7/782) : Batch loss : 1.9793083667755127
# Epoch(0/1 : Batch number(8/782) : Batch loss : 1.9261523485183716
# Epoch(0/1 : Batch number(9/782) : Batch loss : 1.7236722707748413
# Epoch(0/1 : Batch number(10/782) : Batch loss : 1.6771641969680786
# Epoch(0/1 : Batch number(11/782) : Batch loss : 1.5943920612335205
# Epoch(0/1 : Batch number(12/782) : Batch loss : 1.6339595317840576
# Epoch(0/1 : Batch number(13/782) : Batch loss : 1.5308122634887695
# Epoch(0/1 : Batch number(14/782) : Batch loss : 1.6044483184814453
# Epoch(0/1 : Batch number(15/782) : Batch loss : 1.3871948719024658
# Epoch(0/1 : Batch number(16/782) : Batch loss : 1.4795212745666504
# Epoch(0/1 : Batch number(17/782) : Batch loss : 1.37775456905365
# Epoch(0/1 : Batch number(18/782) : Batch loss : 1.3284963369369507
# Epoch(0/1 : Batch number(19/782) : Batch loss : 1.23405122756958
# Epoch(0/1 : Batch number(20/782) : Batch loss : 1.2382586002349854
# Epoch(0/1 : Batch number(21/782) : Batch loss : 1.1771142482757568
# Epoch(0/1 : Batch number(22/782) : Batch loss : 0.9691488742828369
# Epoch(0/1 : Batch number(23/782) : Batch loss : 1.018080472946167
# Epoch(0/1 : Batch number(24/782) : Batch loss : 1.129520058631897
# Epoch(0/1 : Batch number(25/782) : Batch loss : 0.9002113342285156
# Epoch(0/1 : Batch number(26/782) : Batch loss : 1.1044195890426636
# Epoch(0/1 : Batch number(27/782) : Batch loss : 0.9507534503936768
# Epoch(0/1 : Batch number(28/782) : Batch loss : 1.0682812929153442
# Epoch(0/1 : Batch number(29/782) : Batch loss : 1.1462435722351074
# Epoch(0/1 : Batch number(30/782) : Batch loss : 0.8309840559959412
# Epoch(0/1 : Batch number(31/782) : Batch loss : 0.8706615567207336
# Epoch(0/1 : Batch number(32/782) : Batch loss : 1.0182477235794067
# Epoch(0/1 : Batch number(33/782) : Batch loss : 1.0408672094345093
# Epoch(0/1 : Batch number(34/782) : Batch loss : 0.8646814823150635
# Epoch(0/1 : Batch number(35/782) : Batch loss : 0.9905610084533691
# Epoch(0/1 : Batch number(36/782) : Batch loss : 0.846015989780426
# Epoch(0/1 : Batch number(37/782) : Batch loss : 1.0108797550201416
# Epoch(0/1 : Batch number(38/782) : Batch loss : 0.8840376734733582
# Epoch(0/1 : Batch number(39/782) : Batch loss : 0.9253366589546204
# Epoch(0/1 : Batch number(40/782) : Batch loss : 0.575361430644989
# Epoch(0/1 : Batch number(41/782) : Batch loss : 0.7640018463134766
# Epoch(0/1 : Batch number(42/782) : Batch loss : 0.8165009021759033
# Epoch(0/1 : Batch number(43/782) : Batch loss : 0.8793684840202332
# Epoch(0/1 : Batch number(44/782) : Batch loss : 0.8029887676239014
# Epoch(0/1 : Batch number(45/782) : Batch loss : 0.975645899772644
# Epoch(0/1 : Batch number(46/782) : Batch loss : 0.7968443632125854
# Epoch(0/1 : Batch number(47/782) : Batch loss : 0.786205530166626
# Epoch(0/1 : Batch number(48/782) : Batch loss : 0.8196256756782532
# Epoch(0/1 : Batch number(49/782) : Batch loss : 0.6895870566368103
# Epoch(0/1 : Batch number(50/782) : Batch loss : 0.8098231554031372
# Epoch(0/1 : Batch number(51/782) : Batch loss : 0.9574360847473145
# Epoch(0/1 : Batch number(52/782) : Batch loss : 0.7049039006233215
# Epoch(0/1 : Batch number(53/782) : Batch loss : 0.6768319606781006
# Epoch(0/1 : Batch number(54/782) : Batch loss : 0.7724354863166809
# Epoch(0/1 : Batch number(55/782) : Batch loss : 0.8735725283622742
# Epoch(0/1 : Batch number(56/782) : Batch loss : 1.061139464378357
# Epoch(0/1 : Batch number(57/782) : Batch loss : 0.7592965364456177
# Epoch(0/1 : Batch number(58/782) : Batch loss : 0.7742632031440735
# Epoch(0/1 : Batch number(59/782) : Batch loss : 0.774135947227478
# Epoch(0/1 : Batch number(60/782) : Batch loss : 0.850633978843689
# Epoch(0/1 : Batch number(61/782) : Batch loss : 0.9539726376533508
# Epoch(0/1 : Batch number(62/782) : Batch loss : 0.7794663310050964
# Epoch(0/1 : Batch number(63/782) : Batch loss : 0.7695106863975525
# Epoch(0/1 : Batch number(64/782) : Batch loss : 0.7887701392173767
# Epoch(0/1 : Batch number(65/782) : Batch loss : 0.7136150002479553
# Epoch(0/1 : Batch number(66/782) : Batch loss : 0.7417504787445068
# Epoch(0/1 : Batch number(67/782) : Batch loss : 0.43011850118637085
# Epoch(0/1 : Batch number(68/782) : Batch loss : 0.8801987767219543
# Epoch(0/1 : Batch number(69/782) : Batch loss : 0.8559080958366394
# Epoch(0/1 : Batch number(70/782) : Batch loss : 0.7425923347473145
# Epoch(0/1 : Batch number(71/782) : Batch loss : 0.8932852149009705
# Epoch(0/1 : Batch number(72/782) : Batch loss : 0.765160322189331
# Epoch(0/1 : Batch number(73/782) : Batch loss : 0.7658716440200806
# Epoch(0/1 : Batch number(74/782) : Batch loss : 0.9407095313072205
# Epoch(0/1 : Batch number(75/782) : Batch loss : 0.6659743189811707
# Epoch(0/1 : Batch number(76/782) : Batch loss : 0.7422572374343872
# Epoch(0/1 : Batch number(77/782) : Batch loss : 0.7633004784584045
# Epoch(0/1 : Batch number(78/782) : Batch loss : 0.8173829317092896
# Epoch(0/1 : Batch number(79/782) : Batch loss : 0.9700886011123657
# Epoch(0/1 : Batch number(80/782) : Batch loss : 0.9926474690437317
# Epoch(0/1 : Batch number(81/782) : Batch loss : 0.8997650146484375
# Epoch(0/1 : Batch number(82/782) : Batch loss : 0.78907310962677
# Epoch(0/1 : Batch number(83/782) : Batch loss : 0.6368793249130249
# Epoch(0/1 : Batch number(84/782) : Batch loss : 0.738415002822876
# Epoch(0/1 : Batch number(85/782) : Batch loss : 0.6424067616462708
# Epoch(0/1 : Batch number(86/782) : Batch loss : 0.7457624077796936
# Epoch(0/1 : Batch number(87/782) : Batch loss : 0.8734652400016785
# Epoch(0/1 : Batch number(88/782) : Batch loss : 0.823793888092041
# Epoch(0/1 : Batch number(89/782) : Batch loss : 0.5750134587287903
# Epoch(0/1 : Batch number(90/782) : Batch loss : 0.8713588118553162
# Epoch(0/1 : Batch number(91/782) : Batch loss : 0.7003588080406189
# Epoch(0/1 : Batch number(92/782) : Batch loss : 0.7444894313812256
# Epoch(0/1 : Batch number(93/782) : Batch loss : 0.6999573707580566
# Epoch(0/1 : Batch number(94/782) : Batch loss : 0.8142905831336975
# Epoch(0/1 : Batch number(95/782) : Batch loss : 0.7076981067657471
# Epoch(0/1 : Batch number(96/782) : Batch loss : 0.8159310817718506
# Epoch(0/1 : Batch number(97/782) : Batch loss : 0.9240933656692505
# Epoch(0/1 : Batch number(98/782) : Batch loss : 0.8198397755622864
# Epoch(0/1 : Batch number(99/782) : Batch loss : 0.5950952768325806
# Epoch(0/1 : Batch number(100/782) : Batch loss : 0.6863564848899841
# Epoch(0/1 : Batch number(101/782) : Batch loss : 0.8436433672904968
# Epoch(0/1 : Batch number(102/782) : Batch loss : 0.7999173402786255
# Epoch(0/1 : Batch number(103/782) : Batch loss : 1.0293947458267212
# Epoch(0/1 : Batch number(104/782) : Batch loss : 0.7717299461364746
# Epoch(0/1 : Batch number(105/782) : Batch loss : 0.7785265445709229
# Epoch(0/1 : Batch number(106/782) : Batch loss : 0.6046393513679504
# Epoch(0/1 : Batch number(107/782) : Batch loss : 0.5746983289718628
# Epoch(0/1 : Batch number(108/782) : Batch loss : 0.7673981189727783
# Epoch(0/1 : Batch number(109/782) : Batch loss : 0.7624192237854004
# Epoch(0/1 : Batch number(110/782) : Batch loss : 0.7469655871391296
# Epoch(0/1 : Batch number(111/782) : Batch loss : 0.5940283536911011
# Epoch(0/1 : Batch number(112/782) : Batch loss : 0.6791601181030273
# Epoch(0/1 : Batch number(113/782) : Batch loss : 0.7951129674911499
# Epoch(0/1 : Batch number(114/782) : Batch loss : 0.7790346741676331
# Epoch(0/1 : Batch number(115/782) : Batch loss : 0.5770862698554993
# Epoch(0/1 : Batch number(116/782) : Batch loss : 0.9013216495513916
# Epoch(0/1 : Batch number(117/782) : Batch loss : 0.8610343337059021
# Epoch(0/1 : Batch number(118/782) : Batch loss : 0.5525146722793579
# Epoch(0/1 : Batch number(119/782) : Batch loss : 0.5314828157424927
# Epoch(0/1 : Batch number(120/782) : Batch loss : 0.7223948240280151
# Epoch(0/1 : Batch number(121/782) : Batch loss : 0.6517946124076843
# Epoch(0/1 : Batch number(122/782) : Batch loss : 0.593773603439331
# Epoch(0/1 : Batch number(123/782) : Batch loss : 0.5430034399032593
# Epoch(0/1 : Batch number(124/782) : Batch loss : 0.7678394317626953
# Epoch(0/1 : Batch number(125/782) : Batch loss : 0.5136412382125854
# Epoch(0/1 : Batch number(126/782) : Batch loss : 0.5295041799545288
# Epoch(0/1 : Batch number(127/782) : Batch loss : 0.7036681175231934
# Epoch(0/1 : Batch number(128/782) : Batch loss : 0.7069847583770752
# Epoch(0/1 : Batch number(129/782) : Batch loss : 0.6961726546287537
# Epoch(0/1 : Batch number(130/782) : Batch loss : 0.6162630915641785
# Epoch(0/1 : Batch number(131/782) : Batch loss : 0.8400328159332275
# Epoch(0/1 : Batch number(132/782) : Batch loss : 0.8629761338233948
# Epoch(0/1 : Batch number(133/782) : Batch loss : 0.8016193509101868
# Epoch(0/1 : Batch number(134/782) : Batch loss : 0.6684474349021912
# Epoch(0/1 : Batch number(135/782) : Batch loss : 0.6724238395690918
# Epoch(0/1 : Batch number(136/782) : Batch loss : 0.9500110149383545
# Epoch(0/1 : Batch number(137/782) : Batch loss : 0.5252199769020081
# Epoch(0/1 : Batch number(138/782) : Batch loss : 0.556948721408844
# Epoch(0/1 : Batch number(139/782) : Batch loss : 0.6257259249687195
# Epoch(0/1 : Batch number(140/782) : Batch loss : 0.5407866835594177
# Epoch(0/1 : Batch number(141/782) : Batch loss : 0.9478923678398132
# Epoch(0/1 : Batch number(142/782) : Batch loss : 0.5563769340515137
# Epoch(0/1 : Batch number(143/782) : Batch loss : 0.5496217012405396
# Epoch(0/1 : Batch number(144/782) : Batch loss : 0.6738280653953552
# Epoch(0/1 : Batch number(145/782) : Batch loss : 0.8065488338470459
# Epoch(0/1 : Batch number(146/782) : Batch loss : 0.830904483795166
# Epoch(0/1 : Batch number(147/782) : Batch loss : 0.586169958114624
# Epoch(0/1 : Batch number(148/782) : Batch loss : 0.709894061088562
# Epoch(0/1 : Batch number(149/782) : Batch loss : 0.7212612628936768
# Epoch(0/1 : Batch number(150/782) : Batch loss : 0.49499988555908203
# Epoch(0/1 : Batch number(151/782) : Batch loss : 0.5845304727554321
# Epoch(0/1 : Batch number(152/782) : Batch loss : 0.751300036907196
# Epoch(0/1 : Batch number(153/782) : Batch loss : 0.5864118337631226
# Epoch(0/1 : Batch number(154/782) : Batch loss : 0.7961992025375366
# Epoch(0/1 : Batch number(155/782) : Batch loss : 0.6976516246795654
# Epoch(0/1 : Batch number(156/782) : Batch loss : 0.7606938481330872
# Epoch(0/1 : Batch number(157/782) : Batch loss : 0.5570846199989319
# Epoch(0/1 : Batch number(158/782) : Batch loss : 0.8487594723701477
# Epoch(0/1 : Batch number(159/782) : Batch loss : 0.6038088202476501
# Epoch(0/1 : Batch number(160/782) : Batch loss : 0.8847178816795349
# Epoch(0/1 : Batch number(161/782) : Batch loss : 0.7546528577804565
# Epoch(0/1 : Batch number(162/782) : Batch loss : 0.5228222608566284
# Epoch(0/1 : Batch number(163/782) : Batch loss : 0.6167365908622742
# Epoch(0/1 : Batch number(164/782) : Batch loss : 0.712982714176178
# Epoch(0/1 : Batch number(165/782) : Batch loss : 0.6190779209136963
# Epoch(0/1 : Batch number(166/782) : Batch loss : 0.6707327961921692
# Epoch(0/1 : Batch number(167/782) : Batch loss : 0.7892155647277832
# Epoch(0/1 : Batch number(168/782) : Batch loss : 0.6267076134681702
# Epoch(0/1 : Batch number(169/782) : Batch loss : 0.5355261564254761
# Epoch(0/1 : Batch number(170/782) : Batch loss : 0.8199269771575928
# Epoch(0/1 : Batch number(171/782) : Batch loss : 0.5531677007675171
# Epoch(0/1 : Batch number(172/782) : Batch loss : 0.8366719484329224
# Epoch(0/1 : Batch number(173/782) : Batch loss : 0.5037073493003845
# Epoch(0/1 : Batch number(174/782) : Batch loss : 0.6739238500595093
# Epoch(0/1 : Batch number(175/782) : Batch loss : 0.4126392900943756
# Epoch(0/1 : Batch number(176/782) : Batch loss : 0.6471957564353943
# Epoch(0/1 : Batch number(177/782) : Batch loss : 0.701094388961792
# Epoch(0/1 : Batch number(178/782) : Batch loss : 0.4706711769104004
# Epoch(0/1 : Batch number(179/782) : Batch loss : 0.5496791005134583
# Epoch(0/1 : Batch number(180/782) : Batch loss : 0.847911536693573
# Epoch(0/1 : Batch number(181/782) : Batch loss : 0.7679691314697266
# Epoch(0/1 : Batch number(182/782) : Batch loss : 0.8854274153709412
# Epoch(0/1 : Batch number(183/782) : Batch loss : 0.7155433297157288
# Epoch(0/1 : Batch number(184/782) : Batch loss : 0.6260940432548523
# Epoch(0/1 : Batch number(185/782) : Batch loss : 0.7942079305648804
# Epoch(0/1 : Batch number(186/782) : Batch loss : 0.7413566708564758
# Epoch(0/1 : Batch number(187/782) : Batch loss : 0.8191853165626526
# Epoch(0/1 : Batch number(188/782) : Batch loss : 0.7005409598350525
# Epoch(0/1 : Batch number(189/782) : Batch loss : 0.7207410335540771
# Epoch(0/1 : Batch number(190/782) : Batch loss : 0.6897399425506592
# Epoch(0/1 : Batch number(191/782) : Batch loss : 0.7221238017082214
# Epoch(0/1 : Batch number(192/782) : Batch loss : 0.5389654636383057
# Epoch(0/1 : Batch number(193/782) : Batch loss : 0.65765380859375
# Epoch(0/1 : Batch number(194/782) : Batch loss : 0.8652498126029968
# Epoch(0/1 : Batch number(195/782) : Batch loss : 0.6294847726821899
# Epoch(0/1 : Batch number(196/782) : Batch loss : 0.46938803791999817
# Epoch(0/1 : Batch number(197/782) : Batch loss : 0.7390438318252563
# Epoch(0/1 : Batch number(198/782) : Batch loss : 0.678820013999939
# Epoch(0/1 : Batch number(199/782) : Batch loss : 0.7409023642539978
# Epoch(0/1 : Batch number(200/782) : Batch loss : 0.7693047523498535
# Epoch(0/1 : Batch number(201/782) : Batch loss : 0.6394330263137817
# Epoch(0/1 : Batch number(202/782) : Batch loss : 0.5944965481758118
# Epoch(0/1 : Batch number(203/782) : Batch loss : 0.7373296022415161
# Epoch(0/1 : Batch number(204/782) : Batch loss : 0.6870074272155762
# Epoch(0/1 : Batch number(205/782) : Batch loss : 0.9171189069747925
# Epoch(0/1 : Batch number(206/782) : Batch loss : 0.7431880831718445
# Epoch(0/1 : Batch number(207/782) : Batch loss : 0.825637936592102
# Epoch(0/1 : Batch number(208/782) : Batch loss : 0.6443577408790588
# Epoch(0/1 : Batch number(209/782) : Batch loss : 0.6924222111701965
# Epoch(0/1 : Batch number(210/782) : Batch loss : 0.7825926542282104
# Epoch(0/1 : Batch number(211/782) : Batch loss : 0.6052901148796082
# Epoch(0/1 : Batch number(212/782) : Batch loss : 0.6059211492538452
# Epoch(0/1 : Batch number(213/782) : Batch loss : 0.4680505096912384
# Epoch(0/1 : Batch number(214/782) : Batch loss : 0.70718914270401
# Epoch(0/1 : Batch number(215/782) : Batch loss : 0.5877730846405029
# Epoch(0/1 : Batch number(216/782) : Batch loss : 0.616786003112793
# Epoch(0/1 : Batch number(217/782) : Batch loss : 0.6209917068481445
# Epoch(0/1 : Batch number(218/782) : Batch loss : 0.522489070892334
# Epoch(0/1 : Batch number(219/782) : Batch loss : 0.5362579226493835
# Epoch(0/1 : Batch number(220/782) : Batch loss : 0.5566302537918091
# Epoch(0/1 : Batch number(221/782) : Batch loss : 0.5606982707977295
# Epoch(0/1 : Batch number(222/782) : Batch loss : 0.8045482039451599
# Epoch(0/1 : Batch number(223/782) : Batch loss : 0.621841311454773
# Epoch(0/1 : Batch number(224/782) : Batch loss : 0.603502094745636
# Epoch(0/1 : Batch number(225/782) : Batch loss : 0.808165431022644
# Epoch(0/1 : Batch number(226/782) : Batch loss : 0.5192041397094727
# Epoch(0/1 : Batch number(227/782) : Batch loss : 0.812812089920044
# Epoch(0/1 : Batch number(228/782) : Batch loss : 0.5995230674743652
# Epoch(0/1 : Batch number(229/782) : Batch loss : 0.5123963356018066
# Epoch(0/1 : Batch number(230/782) : Batch loss : 0.7066962122917175
# Epoch(0/1 : Batch number(231/782) : Batch loss : 0.5191745162010193
# Epoch(0/1 : Batch number(232/782) : Batch loss : 0.6135870218276978
# Epoch(0/1 : Batch number(233/782) : Batch loss : 0.8162584900856018
# Epoch(0/1 : Batch number(234/782) : Batch loss : 0.6523491740226746
# Epoch(0/1 : Batch number(235/782) : Batch loss : 0.44375112652778625
# Epoch(0/1 : Batch number(236/782) : Batch loss : 0.644524097442627
# Epoch(0/1 : Batch number(237/782) : Batch loss : 0.6957679390907288
# Epoch(0/1 : Batch number(238/782) : Batch loss : 0.8713104724884033
# Epoch(0/1 : Batch number(239/782) : Batch loss : 0.4693397283554077
# Epoch(0/1 : Batch number(240/782) : Batch loss : 0.6081547141075134
# Epoch(0/1 : Batch number(241/782) : Batch loss : 0.5597049593925476
# Epoch(0/1 : Batch number(242/782) : Batch loss : 0.35553333163261414
# Epoch(0/1 : Batch number(243/782) : Batch loss : 0.42987361550331116
# Epoch(0/1 : Batch number(244/782) : Batch loss : 1.0041351318359375
# Epoch(0/1 : Batch number(245/782) : Batch loss : 0.646470844745636
# Epoch(0/1 : Batch number(246/782) : Batch loss : 0.6327950358390808
# Epoch(0/1 : Batch number(247/782) : Batch loss : 0.6127177476882935
# Epoch(0/1 : Batch number(248/782) : Batch loss : 0.7181200981140137
# Epoch(0/1 : Batch number(249/782) : Batch loss : 0.8724584579467773
# Epoch(0/1 : Batch number(250/782) : Batch loss : 0.9610769152641296
# Epoch(0/1 : Batch number(251/782) : Batch loss : 0.5120128989219666
# Epoch(0/1 : Batch number(252/782) : Batch loss : 0.8698731064796448
# Epoch(0/1 : Batch number(253/782) : Batch loss : 0.9048765301704407
# Epoch(0/1 : Batch number(254/782) : Batch loss : 0.8894737958908081
# Epoch(0/1 : Batch number(255/782) : Batch loss : 0.6241053938865662
# Epoch(0/1 : Batch number(256/782) : Batch loss : 0.7447463274002075
# Epoch(0/1 : Batch number(257/782) : Batch loss : 0.8143624663352966
# Epoch(0/1 : Batch number(258/782) : Batch loss : 0.5947368144989014
# Epoch(0/1 : Batch number(259/782) : Batch loss : 0.6979455947875977
# Epoch(0/1 : Batch number(260/782) : Batch loss : 0.7363455891609192
# Epoch(0/1 : Batch number(261/782) : Batch loss : 1.046439290046692
# Epoch(0/1 : Batch number(262/782) : Batch loss : 0.7345112562179565
# Epoch(0/1 : Batch number(263/782) : Batch loss : 0.6346473693847656
# Epoch(0/1 : Batch number(264/782) : Batch loss : 0.5667617321014404
# Epoch(0/1 : Batch number(265/782) : Batch loss : 0.7598122954368591
# Epoch(0/1 : Batch number(266/782) : Batch loss : 0.6363106966018677
# Epoch(0/1 : Batch number(267/782) : Batch loss : 0.7296015024185181
# Epoch(0/1 : Batch number(268/782) : Batch loss : 0.6214255094528198
# Epoch(0/1 : Batch number(269/782) : Batch loss : 0.780229926109314
# Epoch(0/1 : Batch number(270/782) : Batch loss : 0.6098488569259644
# Epoch(0/1 : Batch number(271/782) : Batch loss : 0.7756547331809998
# Epoch(0/1 : Batch number(272/782) : Batch loss : 0.6699415445327759
# Epoch(0/1 : Batch number(273/782) : Batch loss : 0.5645219683647156
# Epoch(0/1 : Batch number(274/782) : Batch loss : 0.7404943704605103
# Epoch(0/1 : Batch number(275/782) : Batch loss : 0.7455852627754211
# Epoch(0/1 : Batch number(276/782) : Batch loss : 0.7188510298728943
# Epoch(0/1 : Batch number(277/782) : Batch loss : 0.6186069250106812
# Epoch(0/1 : Batch number(278/782) : Batch loss : 0.6037272810935974
# Epoch(0/1 : Batch number(279/782) : Batch loss : 0.6330204010009766
# Epoch(0/1 : Batch number(280/782) : Batch loss : 0.5120723247528076
# Epoch(0/1 : Batch number(281/782) : Batch loss : 0.8842495083808899
# Epoch(0/1 : Batch number(282/782) : Batch loss : 0.6909879446029663
# Epoch(0/1 : Batch number(283/782) : Batch loss : 0.6044090986251831
# Epoch(0/1 : Batch number(284/782) : Batch loss : 0.743201494216919
# Epoch(0/1 : Batch number(285/782) : Batch loss : 0.7605544924736023
# Epoch(0/1 : Batch number(286/782) : Batch loss : 0.5241213440895081
# Epoch(0/1 : Batch number(287/782) : Batch loss : 0.7289984226226807
# Epoch(0/1 : Batch number(288/782) : Batch loss : 0.6335682272911072
# Epoch(0/1 : Batch number(289/782) : Batch loss : 0.7262066602706909
# Epoch(0/1 : Batch number(290/782) : Batch loss : 1.0201665163040161
# Epoch(0/1 : Batch number(291/782) : Batch loss : 0.7681607604026794
# Epoch(0/1 : Batch number(292/782) : Batch loss : 0.7660578489303589
# Epoch(0/1 : Batch number(293/782) : Batch loss : 0.8125663995742798
# Epoch(0/1 : Batch number(294/782) : Batch loss : 0.4893021583557129
# Epoch(0/1 : Batch number(295/782) : Batch loss : 0.5940225720405579
# Epoch(0/1 : Batch number(296/782) : Batch loss : 0.6039833426475525
# Epoch(0/1 : Batch number(297/782) : Batch loss : 0.69613116979599
# Epoch(0/1 : Batch number(298/782) : Batch loss : 0.8131923079490662
# Epoch(0/1 : Batch number(299/782) : Batch loss : 0.4869464039802551
# Epoch(0/1 : Batch number(300/782) : Batch loss : 0.5957602262496948
# Epoch(0/1 : Batch number(301/782) : Batch loss : 0.7139905691146851
# Epoch(0/1 : Batch number(302/782) : Batch loss : 0.8677915334701538
# Epoch(0/1 : Batch number(303/782) : Batch loss : 0.5067258477210999
# Epoch(0/1 : Batch number(304/782) : Batch loss : 0.8907135128974915
# Epoch(0/1 : Batch number(305/782) : Batch loss : 0.4792349338531494
# Epoch(0/1 : Batch number(306/782) : Batch loss : 0.6466831564903259
# Epoch(0/1 : Batch number(307/782) : Batch loss : 0.5083906650543213
# Epoch(0/1 : Batch number(308/782) : Batch loss : 0.7670643925666809
# Epoch(0/1 : Batch number(309/782) : Batch loss : 0.593682587146759
# Epoch(0/1 : Batch number(310/782) : Batch loss : 0.6556490659713745
# Epoch(0/1 : Batch number(311/782) : Batch loss : 0.5950079560279846
# Epoch(0/1 : Batch number(312/782) : Batch loss : 0.7527251243591309
# Epoch(0/1 : Batch number(313/782) : Batch loss : 0.7337853908538818
# Epoch(0/1 : Batch number(314/782) : Batch loss : 0.5240460634231567
# Epoch(0/1 : Batch number(315/782) : Batch loss : 0.6052183508872986
# Epoch(0/1 : Batch number(316/782) : Batch loss : 0.6743476390838623
# Epoch(0/1 : Batch number(317/782) : Batch loss : 0.5015063285827637
# Epoch(0/1 : Batch number(318/782) : Batch loss : 0.4255249500274658
# Epoch(0/1 : Batch number(319/782) : Batch loss : 0.7061202526092529
# Epoch(0/1 : Batch number(320/782) : Batch loss : 0.6376164555549622
# Epoch(0/1 : Batch number(321/782) : Batch loss : 0.8781666159629822
# Epoch(0/1 : Batch number(322/782) : Batch loss : 0.6741570830345154
# Epoch(0/1 : Batch number(323/782) : Batch loss : 0.7806445956230164
# Epoch(0/1 : Batch number(324/782) : Batch loss : 0.7883120179176331
# Epoch(0/1 : Batch number(325/782) : Batch loss : 0.8839226961135864
# Epoch(0/1 : Batch number(326/782) : Batch loss : 0.5886142253875732
# Epoch(0/1 : Batch number(327/782) : Batch loss : 0.7735820412635803
# Epoch(0/1 : Batch number(328/782) : Batch loss : 0.5954981446266174
# Epoch(0/1 : Batch number(329/782) : Batch loss : 0.6941534876823425
# Epoch(0/1 : Batch number(330/782) : Batch loss : 0.7219561338424683
# Epoch(0/1 : Batch number(331/782) : Batch loss : 0.664085865020752
# Epoch(0/1 : Batch number(332/782) : Batch loss : 0.6964175701141357
# Epoch(0/1 : Batch number(333/782) : Batch loss : 0.6291077733039856
# Epoch(0/1 : Batch number(334/782) : Batch loss : 0.6031674146652222
# Epoch(0/1 : Batch number(335/782) : Batch loss : 0.433272123336792
# Epoch(0/1 : Batch number(336/782) : Batch loss : 0.43442854285240173
# Epoch(0/1 : Batch number(337/782) : Batch loss : 0.6179808974266052
# Epoch(0/1 : Batch number(338/782) : Batch loss : 0.6023112535476685
# Epoch(0/1 : Batch number(339/782) : Batch loss : 0.595260500907898
# Epoch(0/1 : Batch number(340/782) : Batch loss : 0.6851128935813904
# Epoch(0/1 : Batch number(341/782) : Batch loss : 0.3318343460559845
# Epoch(0/1 : Batch number(342/782) : Batch loss : 0.6422637701034546
# Epoch(0/1 : Batch number(343/782) : Batch loss : 0.7926164865493774
# Epoch(0/1 : Batch number(344/782) : Batch loss : 0.7910526990890503
# Epoch(0/1 : Batch number(345/782) : Batch loss : 0.6157650947570801
# Epoch(0/1 : Batch number(346/782) : Batch loss : 0.7841038703918457
# Epoch(0/1 : Batch number(347/782) : Batch loss : 0.5129848122596741
# Epoch(0/1 : Batch number(348/782) : Batch loss : 0.6187396049499512
# Epoch(0/1 : Batch number(349/782) : Batch loss : 0.6365630030632019
# Epoch(0/1 : Batch number(350/782) : Batch loss : 0.8036160469055176
# Epoch(0/1 : Batch number(351/782) : Batch loss : 0.676479160785675
# Epoch(0/1 : Batch number(352/782) : Batch loss : 0.530028760433197
# Epoch(0/1 : Batch number(353/782) : Batch loss : 0.6979457139968872
# Epoch(0/1 : Batch number(354/782) : Batch loss : 0.6179029941558838
# Epoch(0/1 : Batch number(355/782) : Batch loss : 0.7412635087966919
# Epoch(0/1 : Batch number(356/782) : Batch loss : 0.5300559401512146
# Epoch(0/1 : Batch number(357/782) : Batch loss : 0.5707818269729614
# Epoch(0/1 : Batch number(358/782) : Batch loss : 0.6817784309387207
# Epoch(0/1 : Batch number(359/782) : Batch loss : 0.8756237626075745
# Epoch(0/1 : Batch number(360/782) : Batch loss : 0.6316425800323486
# Epoch(0/1 : Batch number(361/782) : Batch loss : 0.5072433948516846
# Epoch(0/1 : Batch number(362/782) : Batch loss : 0.8700507283210754
# Epoch(0/1 : Batch number(363/782) : Batch loss : 0.6311192512512207
# Epoch(0/1 : Batch number(364/782) : Batch loss : 0.6666488647460938
# Epoch(0/1 : Batch number(365/782) : Batch loss : 0.7529621124267578
# Epoch(0/1 : Batch number(366/782) : Batch loss : 0.5109062790870667
# Epoch(0/1 : Batch number(367/782) : Batch loss : 0.6645463109016418
# Epoch(0/1 : Batch number(368/782) : Batch loss : 0.5700520277023315
# Epoch(0/1 : Batch number(369/782) : Batch loss : 0.667565107345581
# Epoch(0/1 : Batch number(370/782) : Batch loss : 0.6954476833343506
# Epoch(0/1 : Batch number(371/782) : Batch loss : 0.47523877024650574
# Epoch(0/1 : Batch number(372/782) : Batch loss : 0.47967126965522766
# Epoch(0/1 : Batch number(373/782) : Batch loss : 0.4021862745285034
# Epoch(0/1 : Batch number(374/782) : Batch loss : 0.6807308197021484
# Epoch(0/1 : Batch number(375/782) : Batch loss : 0.8301434516906738
# Epoch(0/1 : Batch number(376/782) : Batch loss : 0.8107219934463501
# Epoch(0/1 : Batch number(377/782) : Batch loss : 0.5232150554656982
# Epoch(0/1 : Batch number(378/782) : Batch loss : 0.5085335969924927
# Epoch(0/1 : Batch number(379/782) : Batch loss : 0.7257972359657288
# Epoch(0/1 : Batch number(380/782) : Batch loss : 0.5512694120407104
# Epoch(0/1 : Batch number(381/782) : Batch loss : 0.8846487998962402
# Epoch(0/1 : Batch number(382/782) : Batch loss : 0.6457838416099548
# Epoch(0/1 : Batch number(383/782) : Batch loss : 0.524878740310669
# Epoch(0/1 : Batch number(384/782) : Batch loss : 0.6700068712234497
# Epoch(0/1 : Batch number(385/782) : Batch loss : 0.8090940713882446
# Epoch(0/1 : Batch number(386/782) : Batch loss : 0.8532407879829407
# Epoch(0/1 : Batch number(387/782) : Batch loss : 0.6483009457588196
# Epoch(0/1 : Batch number(388/782) : Batch loss : 0.5771499872207642
# Epoch(0/1 : Batch number(389/782) : Batch loss : 0.7794493436813354
# Epoch(0/1 : Batch number(390/782) : Batch loss : 0.735167384147644
# Epoch(0/1 : Batch number(391/782) : Batch loss : 0.6395959854125977
# Epoch(0/1 : Batch number(392/782) : Batch loss : 0.7387124300003052
# Epoch(0/1 : Batch number(393/782) : Batch loss : 0.6307359337806702
# Epoch(0/1 : Batch number(394/782) : Batch loss : 0.6501811146736145
# Epoch(0/1 : Batch number(395/782) : Batch loss : 0.5820826292037964
# Epoch(0/1 : Batch number(396/782) : Batch loss : 0.6330584287643433
# Epoch(0/1 : Batch number(397/782) : Batch loss : 0.5533315539360046
# Epoch(0/1 : Batch number(398/782) : Batch loss : 0.8443900346755981
# Epoch(0/1 : Batch number(399/782) : Batch loss : 0.7189662456512451
# Epoch(0/1 : Batch number(400/782) : Batch loss : 0.7617383003234863
# Epoch(0/1 : Batch number(401/782) : Batch loss : 0.622053861618042
# Epoch(0/1 : Batch number(402/782) : Batch loss : 0.5281577706336975
# Epoch(0/1 : Batch number(403/782) : Batch loss : 0.5807202458381653
# Epoch(0/1 : Batch number(404/782) : Batch loss : 0.6371485590934753
# Epoch(0/1 : Batch number(405/782) : Batch loss : 0.38143354654312134
# Epoch(0/1 : Batch number(406/782) : Batch loss : 0.4226611852645874
# Epoch(0/1 : Batch number(407/782) : Batch loss : 0.4678530693054199
# Epoch(0/1 : Batch number(408/782) : Batch loss : 0.622956395149231
# Epoch(0/1 : Batch number(409/782) : Batch loss : 0.49721989035606384
# Epoch(0/1 : Batch number(410/782) : Batch loss : 0.5215767621994019
# Epoch(0/1 : Batch number(411/782) : Batch loss : 0.6203539371490479
# Epoch(0/1 : Batch number(412/782) : Batch loss : 0.5331005454063416
# Epoch(0/1 : Batch number(413/782) : Batch loss : 0.7126789689064026
# Epoch(0/1 : Batch number(414/782) : Batch loss : 0.8636046051979065
# Epoch(0/1 : Batch number(415/782) : Batch loss : 0.5114656686782837
# Epoch(0/1 : Batch number(416/782) : Batch loss : 0.445548415184021
# Epoch(0/1 : Batch number(417/782) : Batch loss : 0.6072393655776978
# Epoch(0/1 : Batch number(418/782) : Batch loss : 0.6282071471214294
# Epoch(0/1 : Batch number(419/782) : Batch loss : 0.6295369267463684
# Epoch(0/1 : Batch number(420/782) : Batch loss : 0.7581995725631714
# Epoch(0/1 : Batch number(421/782) : Batch loss : 0.5884499549865723
# Epoch(0/1 : Batch number(422/782) : Batch loss : 0.5894067287445068
# Epoch(0/1 : Batch number(423/782) : Batch loss : 0.6698132157325745
# Epoch(0/1 : Batch number(424/782) : Batch loss : 0.5409362316131592
# Epoch(0/1 : Batch number(425/782) : Batch loss : 0.5762057304382324
# Epoch(0/1 : Batch number(426/782) : Batch loss : 0.7553832530975342
# Epoch(0/1 : Batch number(427/782) : Batch loss : 0.8349670767784119
# Epoch(0/1 : Batch number(428/782) : Batch loss : 0.7328845262527466
# Epoch(0/1 : Batch number(429/782) : Batch loss : 0.5769977569580078
# Epoch(0/1 : Batch number(430/782) : Batch loss : 0.5571948885917664
# Epoch(0/1 : Batch number(431/782) : Batch loss : 0.6765345335006714
# Epoch(0/1 : Batch number(432/782) : Batch loss : 0.7057909369468689
# Epoch(0/1 : Batch number(433/782) : Batch loss : 0.583867073059082
# Epoch(0/1 : Batch number(434/782) : Batch loss : 0.5062419176101685
# Epoch(0/1 : Batch number(435/782) : Batch loss : 0.6447498798370361
# Epoch(0/1 : Batch number(436/782) : Batch loss : 0.6371609568595886
# Epoch(0/1 : Batch number(437/782) : Batch loss : 0.7565751671791077
# Epoch(0/1 : Batch number(438/782) : Batch loss : 0.5762561559677124
# Epoch(0/1 : Batch number(439/782) : Batch loss : 0.5478191375732422
# Epoch(0/1 : Batch number(440/782) : Batch loss : 0.6402968764305115
# Epoch(0/1 : Batch number(441/782) : Batch loss : 0.7454184889793396
# Epoch(0/1 : Batch number(442/782) : Batch loss : 0.6366009712219238
# Epoch(0/1 : Batch number(443/782) : Batch loss : 0.6256283521652222
# Epoch(0/1 : Batch number(444/782) : Batch loss : 0.7422828674316406
# Epoch(0/1 : Batch number(445/782) : Batch loss : 0.723000168800354
# Epoch(0/1 : Batch number(446/782) : Batch loss : 0.4702445864677429
# Epoch(0/1 : Batch number(447/782) : Batch loss : 0.5706955194473267
# Epoch(0/1 : Batch number(448/782) : Batch loss : 0.6680463552474976
# Epoch(0/1 : Batch number(449/782) : Batch loss : 0.5089328289031982
# Epoch(0/1 : Batch number(450/782) : Batch loss : 0.40942874550819397
# Epoch(0/1 : Batch number(451/782) : Batch loss : 0.49128636717796326
# Epoch(0/1 : Batch number(452/782) : Batch loss : 0.6952818036079407
# Epoch(0/1 : Batch number(453/782) : Batch loss : 0.8476068377494812
# Epoch(0/1 : Batch number(454/782) : Batch loss : 0.42767035961151123
# Epoch(0/1 : Batch number(455/782) : Batch loss : 0.7141690850257874
# Epoch(0/1 : Batch number(456/782) : Batch loss : 0.6806519031524658
# Epoch(0/1 : Batch number(457/782) : Batch loss : 0.7321648001670837
# Epoch(0/1 : Batch number(458/782) : Batch loss : 0.5071085691452026
# Epoch(0/1 : Batch number(459/782) : Batch loss : 0.6877263784408569
# Epoch(0/1 : Batch number(460/782) : Batch loss : 0.5870163440704346
# Epoch(0/1 : Batch number(461/782) : Batch loss : 0.7000712156295776
# Epoch(0/1 : Batch number(462/782) : Batch loss : 0.8767368793487549
# Epoch(0/1 : Batch number(463/782) : Batch loss : 0.5943834185600281
# Epoch(0/1 : Batch number(464/782) : Batch loss : 0.39505428075790405
# Epoch(0/1 : Batch number(465/782) : Batch loss : 0.5775438547134399
# Epoch(0/1 : Batch number(466/782) : Batch loss : 0.4833029806613922
# Epoch(0/1 : Batch number(467/782) : Batch loss : 0.9391131401062012
# Epoch(0/1 : Batch number(468/782) : Batch loss : 0.5648127198219299
# Epoch(0/1 : Batch number(469/782) : Batch loss : 0.6320335865020752
# Epoch(0/1 : Batch number(470/782) : Batch loss : 0.6934938430786133
# Epoch(0/1 : Batch number(471/782) : Batch loss : 0.5325323343276978
# Epoch(0/1 : Batch number(472/782) : Batch loss : 0.7862747311592102
# Epoch(0/1 : Batch number(473/782) : Batch loss : 0.534758448600769
# Epoch(0/1 : Batch number(474/782) : Batch loss : 0.535527765750885
# Epoch(0/1 : Batch number(475/782) : Batch loss : 0.6109868884086609
# Epoch(0/1 : Batch number(476/782) : Batch loss : 0.8516736030578613
# Epoch(0/1 : Batch number(477/782) : Batch loss : 0.7016358971595764
# Epoch(0/1 : Batch number(478/782) : Batch loss : 0.7309858798980713
# Epoch(0/1 : Batch number(479/782) : Batch loss : 0.5461024641990662
# Epoch(0/1 : Batch number(480/782) : Batch loss : 0.5082313418388367
# Epoch(0/1 : Batch number(481/782) : Batch loss : 0.6499018669128418
# Epoch(0/1 : Batch number(482/782) : Batch loss : 0.6190394759178162
# Epoch(0/1 : Batch number(483/782) : Batch loss : 0.4131803512573242
# Epoch(0/1 : Batch number(484/782) : Batch loss : 0.5797792673110962
# Epoch(0/1 : Batch number(485/782) : Batch loss : 0.7528948783874512
# Epoch(0/1 : Batch number(486/782) : Batch loss : 0.687763512134552
# Epoch(0/1 : Batch number(487/782) : Batch loss : 0.9068856239318848
# Epoch(0/1 : Batch number(488/782) : Batch loss : 0.6843076348304749
# Epoch(0/1 : Batch number(489/782) : Batch loss : 0.5584470629692078
# Epoch(0/1 : Batch number(490/782) : Batch loss : 0.843855082988739
# Epoch(0/1 : Batch number(491/782) : Batch loss : 0.6903193593025208
# Epoch(0/1 : Batch number(492/782) : Batch loss : 0.6886274218559265
# Epoch(0/1 : Batch number(493/782) : Batch loss : 0.6546429991722107
# Epoch(0/1 : Batch number(494/782) : Batch loss : 0.7326089143753052
# Epoch(0/1 : Batch number(495/782) : Batch loss : 0.764226496219635
# Epoch(0/1 : Batch number(496/782) : Batch loss : 0.7572683095932007
# Epoch(0/1 : Batch number(497/782) : Batch loss : 0.7369696497917175
# Epoch(0/1 : Batch number(498/782) : Batch loss : 0.7095545530319214
# Epoch(0/1 : Batch number(499/782) : Batch loss : 0.544103741645813
# Epoch(0/1 : Batch number(500/782) : Batch loss : 0.5412098169326782
# Epoch(0/1 : Batch number(501/782) : Batch loss : 0.5190509557723999
# Epoch(0/1 : Batch number(502/782) : Batch loss : 0.7144184112548828
# Epoch(0/1 : Batch number(503/782) : Batch loss : 0.587889552116394
# Epoch(0/1 : Batch number(504/782) : Batch loss : 0.5806475877761841
# Epoch(0/1 : Batch number(505/782) : Batch loss : 0.5372843742370605
# Epoch(0/1 : Batch number(506/782) : Batch loss : 0.4734497368335724
# Epoch(0/1 : Batch number(507/782) : Batch loss : 0.5822394490242004
# Epoch(0/1 : Batch number(508/782) : Batch loss : 0.627730131149292
# Epoch(0/1 : Batch number(509/782) : Batch loss : 0.5748804211616516
# Epoch(0/1 : Batch number(510/782) : Batch loss : 0.5095562934875488
# Epoch(0/1 : Batch number(511/782) : Batch loss : 0.614255964756012
# Epoch(0/1 : Batch number(512/782) : Batch loss : 0.839577853679657
# Epoch(0/1 : Batch number(513/782) : Batch loss : 0.6427807211875916
# Epoch(0/1 : Batch number(514/782) : Batch loss : 0.8482885956764221
# Epoch(0/1 : Batch number(515/782) : Batch loss : 0.5724506974220276
# Epoch(0/1 : Batch number(516/782) : Batch loss : 0.5602186918258667
# Epoch(0/1 : Batch number(517/782) : Batch loss : 0.5940168499946594
# Epoch(0/1 : Batch number(518/782) : Batch loss : 0.562296450138092
# Epoch(0/1 : Batch number(519/782) : Batch loss : 0.39174094796180725
# Epoch(0/1 : Batch number(520/782) : Batch loss : 0.6362943649291992
# Epoch(0/1 : Batch number(521/782) : Batch loss : 0.8304103016853333
# Epoch(0/1 : Batch number(522/782) : Batch loss : 0.650435209274292
# Epoch(0/1 : Batch number(523/782) : Batch loss : 0.5160667896270752
# Epoch(0/1 : Batch number(524/782) : Batch loss : 0.38935619592666626
# Epoch(0/1 : Batch number(525/782) : Batch loss : 0.5655350685119629
# Epoch(0/1 : Batch number(526/782) : Batch loss : 0.5546308755874634
# Epoch(0/1 : Batch number(527/782) : Batch loss : 0.8409851789474487
# Epoch(0/1 : Batch number(528/782) : Batch loss : 0.6078059673309326
# Epoch(0/1 : Batch number(529/782) : Batch loss : 0.6110108494758606
# Epoch(0/1 : Batch number(530/782) : Batch loss : 0.7862693071365356
# Epoch(0/1 : Batch number(531/782) : Batch loss : 0.4949399530887604
# Epoch(0/1 : Batch number(532/782) : Batch loss : 0.5875924229621887
# Epoch(0/1 : Batch number(533/782) : Batch loss : 0.6892278790473938
# Epoch(0/1 : Batch number(534/782) : Batch loss : 0.706308901309967
# Epoch(0/1 : Batch number(535/782) : Batch loss : 0.5687469244003296
# Epoch(0/1 : Batch number(536/782) : Batch loss : 0.6262178421020508
# Epoch(0/1 : Batch number(537/782) : Batch loss : 0.7950758934020996
# Epoch(0/1 : Batch number(538/782) : Batch loss : 0.5349337458610535
# Epoch(0/1 : Batch number(539/782) : Batch loss : 0.5721522569656372
# Epoch(0/1 : Batch number(540/782) : Batch loss : 0.6030812859535217
# Epoch(0/1 : Batch number(541/782) : Batch loss : 0.8564953207969666
# Epoch(0/1 : Batch number(542/782) : Batch loss : 0.5290502309799194
# Epoch(0/1 : Batch number(543/782) : Batch loss : 0.6006877422332764
# Epoch(0/1 : Batch number(544/782) : Batch loss : 0.5921937823295593
# Epoch(0/1 : Batch number(545/782) : Batch loss : 0.6154491901397705
# Epoch(0/1 : Batch number(546/782) : Batch loss : 0.4164135456085205
# Epoch(0/1 : Batch number(547/782) : Batch loss : 0.6406449675559998
# Epoch(0/1 : Batch number(548/782) : Batch loss : 0.7329440116882324
# Epoch(0/1 : Batch number(549/782) : Batch loss : 0.5187878608703613
# Epoch(0/1 : Batch number(550/782) : Batch loss : 0.8336028456687927
# Epoch(0/1 : Batch number(551/782) : Batch loss : 0.48278602957725525
# Epoch(0/1 : Batch number(552/782) : Batch loss : 0.40546131134033203
# Epoch(0/1 : Batch number(553/782) : Batch loss : 0.5736627578735352
# Epoch(0/1 : Batch number(554/782) : Batch loss : 0.8048434853553772
# Epoch(0/1 : Batch number(555/782) : Batch loss : 0.4956831932067871
# Epoch(0/1 : Batch number(556/782) : Batch loss : 0.6718248724937439
# Epoch(0/1 : Batch number(557/782) : Batch loss : 0.34785139560699463
# Epoch(0/1 : Batch number(558/782) : Batch loss : 0.6312527060508728
# Epoch(0/1 : Batch number(559/782) : Batch loss : 0.5400434136390686
# Epoch(0/1 : Batch number(560/782) : Batch loss : 0.8014859557151794
# Epoch(0/1 : Batch number(561/782) : Batch loss : 0.8740828037261963
# Epoch(0/1 : Batch number(562/782) : Batch loss : 0.5574536919593811
# Epoch(0/1 : Batch number(563/782) : Batch loss : 0.6455489993095398
# Epoch(0/1 : Batch number(564/782) : Batch loss : 0.7345234155654907
# Epoch(0/1 : Batch number(565/782) : Batch loss : 0.4945638179779053
# Epoch(0/1 : Batch number(566/782) : Batch loss : 0.6714544296264648
# Epoch(0/1 : Batch number(567/782) : Batch loss : 1.0066784620285034
# Epoch(0/1 : Batch number(568/782) : Batch loss : 0.5464910268783569
# Epoch(0/1 : Batch number(569/782) : Batch loss : 0.5210860967636108
# Epoch(0/1 : Batch number(570/782) : Batch loss : 0.46792829036712646
# Epoch(0/1 : Batch number(571/782) : Batch loss : 0.63496994972229
# Epoch(0/1 : Batch number(572/782) : Batch loss : 0.6845836043357849
# Epoch(0/1 : Batch number(573/782) : Batch loss : 0.7350063920021057
# Epoch(0/1 : Batch number(574/782) : Batch loss : 0.6157558560371399
# Epoch(0/1 : Batch number(575/782) : Batch loss : 0.5425917506217957
# Epoch(0/1 : Batch number(576/782) : Batch loss : 0.563888669013977
# Epoch(0/1 : Batch number(577/782) : Batch loss : 0.6175364851951599
# Epoch(0/1 : Batch number(578/782) : Batch loss : 0.5536324977874756
# Epoch(0/1 : Batch number(579/782) : Batch loss : 0.6058734059333801
# Epoch(0/1 : Batch number(580/782) : Batch loss : 0.4421621263027191
# Epoch(0/1 : Batch number(581/782) : Batch loss : 0.537913978099823
# Epoch(0/1 : Batch number(582/782) : Batch loss : 0.6508178114891052
# Epoch(0/1 : Batch number(583/782) : Batch loss : 0.5923226475715637
# Epoch(0/1 : Batch number(584/782) : Batch loss : 0.5599660277366638
# Epoch(0/1 : Batch number(585/782) : Batch loss : 0.8692436218261719
# Epoch(0/1 : Batch number(586/782) : Batch loss : 0.49596524238586426
# Epoch(0/1 : Batch number(587/782) : Batch loss : 0.7257111668586731
# Epoch(0/1 : Batch number(588/782) : Batch loss : 0.8281775116920471
# Epoch(0/1 : Batch number(589/782) : Batch loss : 0.6700571775436401
# Epoch(0/1 : Batch number(590/782) : Batch loss : 0.4035269618034363
# Epoch(0/1 : Batch number(591/782) : Batch loss : 0.6731628179550171
# Epoch(0/1 : Batch number(592/782) : Batch loss : 0.6697895526885986
# Epoch(0/1 : Batch number(593/782) : Batch loss : 0.5910722017288208
# Epoch(0/1 : Batch number(594/782) : Batch loss : 0.577149510383606
# Epoch(0/1 : Batch number(595/782) : Batch loss : 0.544022262096405
# Epoch(0/1 : Batch number(596/782) : Batch loss : 0.4238497018814087
# Epoch(0/1 : Batch number(597/782) : Batch loss : 0.5251632928848267
# Epoch(0/1 : Batch number(598/782) : Batch loss : 0.5462271571159363
# Epoch(0/1 : Batch number(599/782) : Batch loss : 0.6620466113090515
# Epoch(0/1 : Batch number(600/782) : Batch loss : 0.7131509780883789
# Epoch(0/1 : Batch number(601/782) : Batch loss : 0.8388004899024963
# Epoch(0/1 : Batch number(602/782) : Batch loss : 0.468134343624115
# Epoch(0/1 : Batch number(603/782) : Batch loss : 0.8323279619216919
# Epoch(0/1 : Batch number(604/782) : Batch loss : 0.5271396636962891
# Epoch(0/1 : Batch number(605/782) : Batch loss : 0.7242483496665955
# Epoch(0/1 : Batch number(606/782) : Batch loss : 0.9409717917442322
# Epoch(0/1 : Batch number(607/782) : Batch loss : 0.8384440541267395
# Epoch(0/1 : Batch number(608/782) : Batch loss : 0.5573430061340332
# Epoch(0/1 : Batch number(609/782) : Batch loss : 0.4869335889816284
# Epoch(0/1 : Batch number(610/782) : Batch loss : 0.4988481402397156
# Epoch(0/1 : Batch number(611/782) : Batch loss : 0.5782457590103149
# Epoch(0/1 : Batch number(612/782) : Batch loss : 0.7048206329345703
# Epoch(0/1 : Batch number(613/782) : Batch loss : 0.6188181042671204
# Epoch(0/1 : Batch number(614/782) : Batch loss : 0.7038487195968628
# Epoch(0/1 : Batch number(615/782) : Batch loss : 0.398051917552948
# Epoch(0/1 : Batch number(616/782) : Batch loss : 0.7754755020141602
# Epoch(0/1 : Batch number(617/782) : Batch loss : 0.5927908420562744
# Epoch(0/1 : Batch number(618/782) : Batch loss : 0.47224879264831543
# Epoch(0/1 : Batch number(619/782) : Batch loss : 0.6757412552833557
# Epoch(0/1 : Batch number(620/782) : Batch loss : 0.5306060910224915
# Epoch(0/1 : Batch number(621/782) : Batch loss : 0.3793516159057617
# Epoch(0/1 : Batch number(622/782) : Batch loss : 0.483755499124527
# Epoch(0/1 : Batch number(623/782) : Batch loss : 0.6637177467346191
# Epoch(0/1 : Batch number(624/782) : Batch loss : 0.8135569095611572
# Epoch(0/1 : Batch number(625/782) : Batch loss : 0.6359378695487976
# Epoch(0/1 : Batch number(626/782) : Batch loss : 0.5700753927230835
# Epoch(0/1 : Batch number(627/782) : Batch loss : 0.639892578125
# Epoch(0/1 : Batch number(628/782) : Batch loss : 0.658035933971405
# Epoch(0/1 : Batch number(629/782) : Batch loss : 0.7335687875747681
# Epoch(0/1 : Batch number(630/782) : Batch loss : 0.7124065160751343
# Epoch(0/1 : Batch number(631/782) : Batch loss : 0.732854962348938
# Epoch(0/1 : Batch number(632/782) : Batch loss : 0.27971377968788147
# Epoch(0/1 : Batch number(633/782) : Batch loss : 0.5264316201210022
# Epoch(0/1 : Batch number(634/782) : Batch loss : 0.4814561605453491
# Epoch(0/1 : Batch number(635/782) : Batch loss : 0.5821325778961182
# Epoch(0/1 : Batch number(636/782) : Batch loss : 0.5948097705841064
# Epoch(0/1 : Batch number(637/782) : Batch loss : 0.5444478988647461
# Epoch(0/1 : Batch number(638/782) : Batch loss : 0.6270238757133484
# Epoch(0/1 : Batch number(639/782) : Batch loss : 0.835077166557312
# Epoch(0/1 : Batch number(640/782) : Batch loss : 0.6844494938850403
# Epoch(0/1 : Batch number(641/782) : Batch loss : 0.7144561409950256
# Epoch(0/1 : Batch number(642/782) : Batch loss : 0.5847225189208984
# Epoch(0/1 : Batch number(643/782) : Batch loss : 0.5705279111862183
# Epoch(0/1 : Batch number(644/782) : Batch loss : 0.701090395450592
# Epoch(0/1 : Batch number(645/782) : Batch loss : 0.68585604429245
# Epoch(0/1 : Batch number(646/782) : Batch loss : 0.7371361255645752
# Epoch(0/1 : Batch number(647/782) : Batch loss : 0.5442590713500977
# Epoch(0/1 : Batch number(648/782) : Batch loss : 0.7661808133125305
# Epoch(0/1 : Batch number(649/782) : Batch loss : 0.5551673173904419
# Epoch(0/1 : Batch number(650/782) : Batch loss : 0.6305463314056396
# Epoch(0/1 : Batch number(651/782) : Batch loss : 0.8167291879653931
# Epoch(0/1 : Batch number(652/782) : Batch loss : 0.5716414451599121
# Epoch(0/1 : Batch number(653/782) : Batch loss : 0.6404340863227844
# Epoch(0/1 : Batch number(654/782) : Batch loss : 0.430850625038147
# Epoch(0/1 : Batch number(655/782) : Batch loss : 0.6183873414993286
# Epoch(0/1 : Batch number(656/782) : Batch loss : 0.6436336636543274
# Epoch(0/1 : Batch number(657/782) : Batch loss : 0.5872839093208313
# Epoch(0/1 : Batch number(658/782) : Batch loss : 0.6710054278373718
# Epoch(0/1 : Batch number(659/782) : Batch loss : 0.5819830894470215
# Epoch(0/1 : Batch number(660/782) : Batch loss : 0.7894859313964844
# Epoch(0/1 : Batch number(661/782) : Batch loss : 0.6642335653305054
# Epoch(0/1 : Batch number(662/782) : Batch loss : 0.7799336910247803
# Epoch(0/1 : Batch number(663/782) : Batch loss : 0.8329442143440247
# Epoch(0/1 : Batch number(664/782) : Batch loss : 0.5943732261657715
# Epoch(0/1 : Batch number(665/782) : Batch loss : 0.6525097489356995
# Epoch(0/1 : Batch number(666/782) : Batch loss : 0.6287985444068909
# Epoch(0/1 : Batch number(667/782) : Batch loss : 0.4961095452308655
# Epoch(0/1 : Batch number(668/782) : Batch loss : 0.571845293045044
# Epoch(0/1 : Batch number(669/782) : Batch loss : 0.4641343355178833
# Epoch(0/1 : Batch number(670/782) : Batch loss : 0.5782315731048584
# Epoch(0/1 : Batch number(671/782) : Batch loss : 0.6376639604568481
# Epoch(0/1 : Batch number(672/782) : Batch loss : 0.5973251461982727
# Epoch(0/1 : Batch number(673/782) : Batch loss : 0.5813813805580139
# Epoch(0/1 : Batch number(674/782) : Batch loss : 0.7360984086990356
# Epoch(0/1 : Batch number(675/782) : Batch loss : 0.6314947009086609
# Epoch(0/1 : Batch number(676/782) : Batch loss : 0.563487708568573
# Epoch(0/1 : Batch number(677/782) : Batch loss : 0.6065483093261719
# Epoch(0/1 : Batch number(678/782) : Batch loss : 0.5095910429954529
# Epoch(0/1 : Batch number(679/782) : Batch loss : 0.5904513597488403
# Epoch(0/1 : Batch number(680/782) : Batch loss : 0.6259381771087646
# Epoch(0/1 : Batch number(681/782) : Batch loss : 0.5188210606575012
# Epoch(0/1 : Batch number(682/782) : Batch loss : 0.8562186360359192
# Epoch(0/1 : Batch number(683/782) : Batch loss : 0.39223217964172363
# Epoch(0/1 : Batch number(684/782) : Batch loss : 0.7355063557624817
# Epoch(0/1 : Batch number(685/782) : Batch loss : 0.6528401970863342
# Epoch(0/1 : Batch number(686/782) : Batch loss : 0.7716842889785767
# Epoch(0/1 : Batch number(687/782) : Batch loss : 0.6755948066711426
# Epoch(0/1 : Batch number(688/782) : Batch loss : 0.49433958530426025
# Epoch(0/1 : Batch number(689/782) : Batch loss : 0.5368713736534119
# Epoch(0/1 : Batch number(690/782) : Batch loss : 0.5599822402000427
# Epoch(0/1 : Batch number(691/782) : Batch loss : 0.6680091619491577
# Epoch(0/1 : Batch number(692/782) : Batch loss : 0.49033910036087036
# Epoch(0/1 : Batch number(693/782) : Batch loss : 0.6913708448410034
# Epoch(0/1 : Batch number(694/782) : Batch loss : 0.5563555955886841
# Epoch(0/1 : Batch number(695/782) : Batch loss : 0.4923304319381714
# Epoch(0/1 : Batch number(696/782) : Batch loss : 0.8365771174430847
# Epoch(0/1 : Batch number(697/782) : Batch loss : 0.6171892285346985
# Epoch(0/1 : Batch number(698/782) : Batch loss : 0.5625247359275818
# Epoch(0/1 : Batch number(699/782) : Batch loss : 0.6807406544685364
# Epoch(0/1 : Batch number(700/782) : Batch loss : 0.7505277395248413
# Epoch(0/1 : Batch number(701/782) : Batch loss : 0.5896396040916443
# Epoch(0/1 : Batch number(702/782) : Batch loss : 0.7746402025222778
# Epoch(0/1 : Batch number(703/782) : Batch loss : 0.46895328164100647
# Epoch(0/1 : Batch number(704/782) : Batch loss : 0.37998679280281067
# Epoch(0/1 : Batch number(705/782) : Batch loss : 0.5783687233924866
# Epoch(0/1 : Batch number(706/782) : Batch loss : 0.5792906284332275
# Epoch(0/1 : Batch number(707/782) : Batch loss : 0.5628921389579773
# Epoch(0/1 : Batch number(708/782) : Batch loss : 0.688647985458374
# Epoch(0/1 : Batch number(709/782) : Batch loss : 0.7474583387374878
# Epoch(0/1 : Batch number(710/782) : Batch loss : 0.8487957119941711
# Epoch(0/1 : Batch number(711/782) : Batch loss : 0.5348499417304993
# Epoch(0/1 : Batch number(712/782) : Batch loss : 0.4055960178375244
# Epoch(0/1 : Batch number(713/782) : Batch loss : 0.6352559924125671
# Epoch(0/1 : Batch number(714/782) : Batch loss : 0.7098444104194641
# Epoch(0/1 : Batch number(715/782) : Batch loss : 0.7157060503959656
# Epoch(0/1 : Batch number(716/782) : Batch loss : 0.728783369064331
# Epoch(0/1 : Batch number(717/782) : Batch loss : 0.735120415687561
# Epoch(0/1 : Batch number(718/782) : Batch loss : 0.6235227584838867
# Epoch(0/1 : Batch number(719/782) : Batch loss : 0.600947380065918
# Epoch(0/1 : Batch number(720/782) : Batch loss : 0.7075567245483398
# Epoch(0/1 : Batch number(721/782) : Batch loss : 0.7395427823066711
# Epoch(0/1 : Batch number(722/782) : Batch loss : 0.45831137895584106
# Epoch(0/1 : Batch number(723/782) : Batch loss : 0.4982059895992279
# Epoch(0/1 : Batch number(724/782) : Batch loss : 0.5677434206008911
# Epoch(0/1 : Batch number(725/782) : Batch loss : 0.7502989768981934
# Epoch(0/1 : Batch number(726/782) : Batch loss : 0.6296378374099731
# Epoch(0/1 : Batch number(727/782) : Batch loss : 0.48659127950668335
# Epoch(0/1 : Batch number(728/782) : Batch loss : 0.5585725903511047
# Epoch(0/1 : Batch number(729/782) : Batch loss : 0.6357595920562744
# Epoch(0/1 : Batch number(730/782) : Batch loss : 0.5531750917434692
# Epoch(0/1 : Batch number(731/782) : Batch loss : 0.5151700973510742
# Epoch(0/1 : Batch number(732/782) : Batch loss : 0.8133000731468201
# Epoch(0/1 : Batch number(733/782) : Batch loss : 0.4442712664604187
# Epoch(0/1 : Batch number(734/782) : Batch loss : 0.806523323059082
# Epoch(0/1 : Batch number(735/782) : Batch loss : 0.5952330827713013
# Epoch(0/1 : Batch number(736/782) : Batch loss : 0.6705508232116699
# Epoch(0/1 : Batch number(737/782) : Batch loss : 0.6173154711723328
# Epoch(0/1 : Batch number(738/782) : Batch loss : 0.3936741352081299
# Epoch(0/1 : Batch number(739/782) : Batch loss : 0.5283143520355225
# Epoch(0/1 : Batch number(740/782) : Batch loss : 0.5572076439857483
# Epoch(0/1 : Batch number(741/782) : Batch loss : 0.692412257194519
# Epoch(0/1 : Batch number(742/782) : Batch loss : 0.5018233060836792
# Epoch(0/1 : Batch number(743/782) : Batch loss : 0.6134700775146484
# Epoch(0/1 : Batch number(744/782) : Batch loss : 0.5770875215530396
# Epoch(0/1 : Batch number(745/782) : Batch loss : 0.49631786346435547
# Epoch(0/1 : Batch number(746/782) : Batch loss : 0.6409955620765686
# Epoch(0/1 : Batch number(747/782) : Batch loss : 0.6239582300186157
# Epoch(0/1 : Batch number(748/782) : Batch loss : 0.6371045708656311
# Epoch(0/1 : Batch number(749/782) : Batch loss : 0.5343043804168701
# Epoch(0/1 : Batch number(750/782) : Batch loss : 0.544067919254303
# Epoch(0/1 : Batch number(751/782) : Batch loss : 0.8578104376792908
# Epoch(0/1 : Batch number(752/782) : Batch loss : 0.4181036353111267
# Epoch(0/1 : Batch number(753/782) : Batch loss : 0.8157272934913635
# Epoch(0/1 : Batch number(754/782) : Batch loss : 0.7091817259788513
# Epoch(0/1 : Batch number(755/782) : Batch loss : 0.6155893802642822
# Epoch(0/1 : Batch number(756/782) : Batch loss : 0.6839408874511719
# Epoch(0/1 : Batch number(757/782) : Batch loss : 0.5515451431274414
# Epoch(0/1 : Batch number(758/782) : Batch loss : 0.7361473441123962
# Epoch(0/1 : Batch number(759/782) : Batch loss : 0.48103320598602295
# Epoch(0/1 : Batch number(760/782) : Batch loss : 0.5137630701065063
# Epoch(0/1 : Batch number(761/782) : Batch loss : 0.5376225709915161
# Epoch(0/1 : Batch number(762/782) : Batch loss : 0.5890116095542908
# Epoch(0/1 : Batch number(763/782) : Batch loss : 0.7163324952125549
# Epoch(0/1 : Batch number(764/782) : Batch loss : 0.9088066816329956
# Epoch(0/1 : Batch number(765/782) : Batch loss : 0.5914705991744995
# Epoch(0/1 : Batch number(766/782) : Batch loss : 0.5632030367851257
# Epoch(0/1 : Batch number(767/782) : Batch loss : 0.5497469305992126
# Epoch(0/1 : Batch number(768/782) : Batch loss : 0.49416735768318176
# Epoch(0/1 : Batch number(769/782) : Batch loss : 0.5473214983940125
# Epoch(0/1 : Batch number(770/782) : Batch loss : 0.48579341173171997
# Epoch(0/1 : Batch number(771/782) : Batch loss : 0.567827045917511
# Epoch(0/1 : Batch number(772/782) : Batch loss : 0.6813579201698303
# Epoch(0/1 : Batch number(773/782) : Batch loss : 0.5534353852272034
# Epoch(0/1 : Batch number(774/782) : Batch loss : 0.7381201982498169
# Epoch(0/1 : Batch number(775/782) : Batch loss : 0.5853783488273621
# Epoch(0/1 : Batch number(776/782) : Batch loss : 0.7013473510742188
# Epoch(0/1 : Batch number(777/782) : Batch loss : 0.5946494340896606
# Epoch(0/1 : Batch number(778/782) : Batch loss : 0.7359184622764587
# Epoch(0/1 : Batch number(779/782) : Batch loss : 0.7572023868560791
# Epoch(0/1 : Batch number(780/782) : Batch loss : 0.6262819170951843
# Epoch(0/1 : Batch number(781/782) : Batch loss : 0.6998046636581421
# Epoch(0/1 : Batch number(782/782) : Batch loss : 0.40928468108177185
# Training loss : 0.6923415603692574

# %% [markdown]
# ### The accuracy of the model

# %%
model.to('cpu')

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0

    #set_trace()
    for batch, (images, labels) in enumerate(testloader,1):
        
        logps = model(images)
        output = torch.exp(logps)
        
        pred = torch.argmax(output, 1)
        total += labels.size(0)
        num_correct += (pred == labels).sum().item()
        print(f'Batch ({batch}/{len(testloader)})')
        
        if batch == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 79.0625%

# %% [markdown]
# ## Un-freezing & training on the LAST CNN block onwards

# %% [markdown]
# ### Re-training the model

# %%
for i in range(24,31):
  model.features[i].requires_grad = True

# %%
from torch.optim import Adam

lr = 3e-4
optimizer = Adam([
    { 'params': model.features[24].parameters(), 'lr': lr},
    { 'params': model.features[26].parameters(), 'lr': lr},
    { 'params': model.features[28].parameters(), 'lr': lr},
    { 'params': model.classifier[0].parameters(), 'lr': lr},
    { 'params': model.classifier[3].parameters(), 'lr': lr},
    { 'params': model.classifier[6].parameters(), 'lr': lr}
    ], lr=lr)

# %%
model = model.to(device)
#optimizer = Adam(filter(lambda p: p.requires_grad, model.parameters()))

num_epochs = 3
batch_loss = 0
cum_epoch_loss = 0

for e in range(num_epochs):
  cum_epoch_loss = 0
  
  for batch, (images, labels) in enumerate(trainloader,1):
    images = images.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    logps = model(images)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()
    
    batch_loss += loss.item()
    print(f'Epoch({e}/{num_epochs} : Batch number({batch}/{len(trainloader)}) : Batch loss : {loss.item()}')
    
  print(f'Training loss : {batch_loss/len(trainloader)}')
# Out:
# Epoch(0/3 : Batch number(1/782) : Batch loss : 0.37384113669395447
# Epoch(0/3 : Batch number(2/782) : Batch loss : 0.5146580934524536
# Epoch(0/3 : Batch number(3/782) : Batch loss : 0.5885090827941895
# Epoch(0/3 : Batch number(4/782) : Batch loss : 0.31350016593933105
# Epoch(0/3 : Batch number(5/782) : Batch loss : 0.4741794764995575
# Epoch(0/3 : Batch number(6/782) : Batch loss : 0.33164510130882263
# Epoch(0/3 : Batch number(7/782) : Batch loss : 0.5082323551177979
# Epoch(0/3 : Batch number(8/782) : Batch loss : 0.5119118094444275
# Epoch(0/3 : Batch number(9/782) : Batch loss : 0.5857939720153809
# Epoch(0/3 : Batch number(10/782) : Batch loss : 0.4682360887527466
# Epoch(0/3 : Batch number(11/782) : Batch loss : 0.3581196963787079
# Epoch(0/3 : Batch number(12/782) : Batch loss : 0.3989426791667938
# Epoch(0/3 : Batch number(13/782) : Batch loss : 0.5390603542327881
# Epoch(0/3 : Batch number(14/782) : Batch loss : 0.3741486966609955
# Epoch(0/3 : Batch number(15/782) : Batch loss : 0.6649900078773499
# Epoch(0/3 : Batch number(16/782) : Batch loss : 0.4322894513607025
# Epoch(0/3 : Batch number(17/782) : Batch loss : 0.4640738070011139
# Epoch(0/3 : Batch number(18/782) : Batch loss : 0.4906274080276489
# Epoch(0/3 : Batch number(19/782) : Batch loss : 0.7019714117050171
# Epoch(0/3 : Batch number(20/782) : Batch loss : 0.7956370115280151
# Epoch(0/3 : Batch number(21/782) : Batch loss : 0.7047297954559326
# Epoch(0/3 : Batch number(22/782) : Batch loss : 0.447098970413208
# Epoch(0/3 : Batch number(23/782) : Batch loss : 0.4784814715385437
# Epoch(0/3 : Batch number(24/782) : Batch loss : 0.5789734125137329
# Epoch(0/3 : Batch number(25/782) : Batch loss : 0.48907554149627686
# Epoch(0/3 : Batch number(26/782) : Batch loss : 0.2943984270095825
# Epoch(0/3 : Batch number(27/782) : Batch loss : 0.3737415075302124
# Epoch(0/3 : Batch number(28/782) : Batch loss : 0.40493136644363403
# Epoch(0/3 : Batch number(29/782) : Batch loss : 0.30921217799186707
# Epoch(0/3 : Batch number(30/782) : Batch loss : 0.44091957807540894
# Epoch(0/3 : Batch number(31/782) : Batch loss : 0.5565390586853027
# Epoch(0/3 : Batch number(32/782) : Batch loss : 0.3518409729003906
# Epoch(0/3 : Batch number(33/782) : Batch loss : 0.522716224193573
# Epoch(0/3 : Batch number(34/782) : Batch loss : 0.39403030276298523
# Epoch(0/3 : Batch number(35/782) : Batch loss : 0.38789916038513184
# Epoch(0/3 : Batch number(36/782) : Batch loss : 0.5277231335639954
# Epoch(0/3 : Batch number(37/782) : Batch loss : 0.4893273711204529
# Epoch(0/3 : Batch number(38/782) : Batch loss : 0.29275017976760864
# Epoch(0/3 : Batch number(39/782) : Batch loss : 0.43333718180656433
# Epoch(0/3 : Batch number(40/782) : Batch loss : 0.557266116142273
# Epoch(0/3 : Batch number(41/782) : Batch loss : 0.48183056712150574
# Epoch(0/3 : Batch number(42/782) : Batch loss : 0.4239959716796875
# Epoch(0/3 : Batch number(43/782) : Batch loss : 0.5294823050498962
# Epoch(0/3 : Batch number(44/782) : Batch loss : 0.4731787443161011
# Epoch(0/3 : Batch number(45/782) : Batch loss : 0.4503716826438904
# Epoch(0/3 : Batch number(46/782) : Batch loss : 0.28014257550239563
# Epoch(0/3 : Batch number(47/782) : Batch loss : 0.40621596574783325
# Epoch(0/3 : Batch number(48/782) : Batch loss : 0.6563381552696228
# Epoch(0/3 : Batch number(49/782) : Batch loss : 0.4993259608745575
# Epoch(0/3 : Batch number(50/782) : Batch loss : 0.4168354868888855
# Epoch(0/3 : Batch number(51/782) : Batch loss : 0.370665580034256
# Epoch(0/3 : Batch number(52/782) : Batch loss : 0.3460279405117035
# Epoch(0/3 : Batch number(53/782) : Batch loss : 0.48993563652038574
# Epoch(0/3 : Batch number(54/782) : Batch loss : 0.4566356837749481
# Epoch(0/3 : Batch number(55/782) : Batch loss : 0.33265063166618347
# Epoch(0/3 : Batch number(56/782) : Batch loss : 0.45095711946487427
# Epoch(0/3 : Batch number(57/782) : Batch loss : 0.4476639926433563
# Epoch(0/3 : Batch number(58/782) : Batch loss : 0.34485477209091187
# Epoch(0/3 : Batch number(59/782) : Batch loss : 0.706386387348175
# Epoch(0/3 : Batch number(60/782) : Batch loss : 0.3950372338294983
# Epoch(0/3 : Batch number(61/782) : Batch loss : 0.2800558805465698
# Epoch(0/3 : Batch number(62/782) : Batch loss : 0.4708777368068695
# Epoch(0/3 : Batch number(63/782) : Batch loss : 0.4598855972290039
# Epoch(0/3 : Batch number(64/782) : Batch loss : 0.394077330827713
# Epoch(0/3 : Batch number(65/782) : Batch loss : 0.5165576338768005
# Epoch(0/3 : Batch number(66/782) : Batch loss : 0.5386666655540466
# Epoch(0/3 : Batch number(67/782) : Batch loss : 0.47495317459106445
# Epoch(0/3 : Batch number(68/782) : Batch loss : 0.5370596051216125
# Epoch(0/3 : Batch number(69/782) : Batch loss : 0.4481273293495178
# Epoch(0/3 : Batch number(70/782) : Batch loss : 0.4575783610343933
# Epoch(0/3 : Batch number(71/782) : Batch loss : 0.4574327766895294
# Epoch(0/3 : Batch number(72/782) : Batch loss : 0.3912484049797058
# Epoch(0/3 : Batch number(73/782) : Batch loss : 0.48120081424713135
# Epoch(0/3 : Batch number(74/782) : Batch loss : 0.434762179851532
# Epoch(0/3 : Batch number(75/782) : Batch loss : 0.48786094784736633
# Epoch(0/3 : Batch number(76/782) : Batch loss : 0.3734533488750458
# Epoch(0/3 : Batch number(77/782) : Batch loss : 0.4214465916156769
# Epoch(0/3 : Batch number(78/782) : Batch loss : 0.4400253891944885
# Epoch(0/3 : Batch number(79/782) : Batch loss : 0.3072643578052521
# Epoch(0/3 : Batch number(80/782) : Batch loss : 0.25967639684677124
# Epoch(0/3 : Batch number(81/782) : Batch loss : 0.4914467930793762
# Epoch(0/3 : Batch number(82/782) : Batch loss : 0.27491140365600586
# Epoch(0/3 : Batch number(83/782) : Batch loss : 0.44444236159324646
# Epoch(0/3 : Batch number(84/782) : Batch loss : 0.47717612981796265
# Epoch(0/3 : Batch number(85/782) : Batch loss : 0.4246079623699188
# Epoch(0/3 : Batch number(86/782) : Batch loss : 0.59417724609375
# Epoch(0/3 : Batch number(87/782) : Batch loss : 0.5547562837600708
# Epoch(0/3 : Batch number(88/782) : Batch loss : 0.5766476392745972
# Epoch(0/3 : Batch number(89/782) : Batch loss : 0.5300869345664978
# Epoch(0/3 : Batch number(90/782) : Batch loss : 0.3920407295227051
# Epoch(0/3 : Batch number(91/782) : Batch loss : 0.5849759578704834
# Epoch(0/3 : Batch number(92/782) : Batch loss : 0.5336053371429443
# Epoch(0/3 : Batch number(93/782) : Batch loss : 0.4538612365722656
# Epoch(0/3 : Batch number(94/782) : Batch loss : 0.6204468607902527
# Epoch(0/3 : Batch number(95/782) : Batch loss : 0.4626970589160919
# Epoch(0/3 : Batch number(96/782) : Batch loss : 0.48577582836151123
# Epoch(0/3 : Batch number(97/782) : Batch loss : 0.7993531227111816
# Epoch(0/3 : Batch number(98/782) : Batch loss : 0.4747542142868042
# Epoch(0/3 : Batch number(99/782) : Batch loss : 0.4606829881668091
# Epoch(0/3 : Batch number(100/782) : Batch loss : 0.29445475339889526
# Epoch(0/3 : Batch number(101/782) : Batch loss : 0.730827808380127
# Epoch(0/3 : Batch number(102/782) : Batch loss : 0.5442963242530823
# Epoch(0/3 : Batch number(103/782) : Batch loss : 0.35514694452285767
# Epoch(0/3 : Batch number(104/782) : Batch loss : 0.5734102129936218
# Epoch(0/3 : Batch number(105/782) : Batch loss : 0.665679395198822
# Epoch(0/3 : Batch number(106/782) : Batch loss : 0.6691533923149109
# Epoch(0/3 : Batch number(107/782) : Batch loss : 0.27453696727752686
# Epoch(0/3 : Batch number(108/782) : Batch loss : 0.42079582810401917
# Epoch(0/3 : Batch number(109/782) : Batch loss : 0.42025548219680786
# Epoch(0/3 : Batch number(110/782) : Batch loss : 0.37846624851226807
# Epoch(0/3 : Batch number(111/782) : Batch loss : 0.5933353304862976
# Epoch(0/3 : Batch number(112/782) : Batch loss : 0.3988912105560303
# Epoch(0/3 : Batch number(113/782) : Batch loss : 0.36921849846839905
# Epoch(0/3 : Batch number(114/782) : Batch loss : 0.4404105544090271
# Epoch(0/3 : Batch number(115/782) : Batch loss : 0.5630120635032654
# Epoch(0/3 : Batch number(116/782) : Batch loss : 0.4119304120540619
# Epoch(0/3 : Batch number(117/782) : Batch loss : 0.538061261177063
# Epoch(0/3 : Batch number(118/782) : Batch loss : 0.49386659264564514
# Epoch(0/3 : Batch number(119/782) : Batch loss : 0.4781191349029541
# Epoch(0/3 : Batch number(120/782) : Batch loss : 0.4803364872932434
# Epoch(0/3 : Batch number(121/782) : Batch loss : 0.5829168558120728
# Epoch(0/3 : Batch number(122/782) : Batch loss : 0.2728216052055359
# Epoch(0/3 : Batch number(123/782) : Batch loss : 0.5413828492164612
# Epoch(0/3 : Batch number(124/782) : Batch loss : 0.4497913420200348
# Epoch(0/3 : Batch number(125/782) : Batch loss : 0.43519455194473267
# Epoch(0/3 : Batch number(126/782) : Batch loss : 0.37003180384635925
# Epoch(0/3 : Batch number(127/782) : Batch loss : 0.4607405364513397
# Epoch(0/3 : Batch number(128/782) : Batch loss : 0.3884654939174652
# Epoch(0/3 : Batch number(129/782) : Batch loss : 0.6141878366470337
# Epoch(0/3 : Batch number(130/782) : Batch loss : 0.6596391797065735
# Epoch(0/3 : Batch number(131/782) : Batch loss : 0.4037117063999176
# Epoch(0/3 : Batch number(132/782) : Batch loss : 0.4839993119239807
# Epoch(0/3 : Batch number(133/782) : Batch loss : 0.40195006132125854
# Epoch(0/3 : Batch number(134/782) : Batch loss : 0.4550709128379822
# Epoch(0/3 : Batch number(135/782) : Batch loss : 0.6055247187614441
# Epoch(0/3 : Batch number(136/782) : Batch loss : 0.2736474275588989
# Epoch(0/3 : Batch number(137/782) : Batch loss : 0.4202057719230652
# Epoch(0/3 : Batch number(138/782) : Batch loss : 0.5764427781105042
# Epoch(0/3 : Batch number(139/782) : Batch loss : 0.39421623945236206
# Epoch(0/3 : Batch number(140/782) : Batch loss : 0.7102577090263367
# Epoch(0/3 : Batch number(141/782) : Batch loss : 0.30787038803100586
# Epoch(0/3 : Batch number(142/782) : Batch loss : 0.6299768090248108
# Epoch(0/3 : Batch number(143/782) : Batch loss : 0.41380229592323303
# Epoch(0/3 : Batch number(144/782) : Batch loss : 0.34267231822013855
# Epoch(0/3 : Batch number(145/782) : Batch loss : 0.6463600993156433
# Epoch(0/3 : Batch number(146/782) : Batch loss : 0.5804511904716492
# Epoch(0/3 : Batch number(147/782) : Batch loss : 0.6271100044250488
# Epoch(0/3 : Batch number(148/782) : Batch loss : 0.5521223545074463
# Epoch(0/3 : Batch number(149/782) : Batch loss : 0.3112587630748749
# Epoch(0/3 : Batch number(150/782) : Batch loss : 0.4959332346916199
# Epoch(0/3 : Batch number(151/782) : Batch loss : 0.5907813310623169
# Epoch(0/3 : Batch number(152/782) : Batch loss : 0.4910679757595062
# Epoch(0/3 : Batch number(153/782) : Batch loss : 0.5310919880867004
# Epoch(0/3 : Batch number(154/782) : Batch loss : 0.320732444524765
# Epoch(0/3 : Batch number(155/782) : Batch loss : 0.523961067199707
# Epoch(0/3 : Batch number(156/782) : Batch loss : 0.5702881217002869
# Epoch(0/3 : Batch number(157/782) : Batch loss : 0.5872947573661804
# Epoch(0/3 : Batch number(158/782) : Batch loss : 0.40201976895332336
# Epoch(0/3 : Batch number(159/782) : Batch loss : 0.3808608055114746
# Epoch(0/3 : Batch number(160/782) : Batch loss : 0.4956343472003937
# Epoch(0/3 : Batch number(161/782) : Batch loss : 0.4709565043449402
# Epoch(0/3 : Batch number(162/782) : Batch loss : 0.3509131371974945
# Epoch(0/3 : Batch number(163/782) : Batch loss : 0.4583526849746704
# Epoch(0/3 : Batch number(164/782) : Batch loss : 0.5522246360778809
# Epoch(0/3 : Batch number(165/782) : Batch loss : 0.38262951374053955
# Epoch(0/3 : Batch number(166/782) : Batch loss : 0.4540974199771881
# Epoch(0/3 : Batch number(167/782) : Batch loss : 0.3758932650089264
# Epoch(0/3 : Batch number(168/782) : Batch loss : 0.42642027139663696
# Epoch(0/3 : Batch number(169/782) : Batch loss : 0.7958188056945801
# Epoch(0/3 : Batch number(170/782) : Batch loss : 0.7567083835601807
# Epoch(0/3 : Batch number(171/782) : Batch loss : 0.7039570212364197
# Epoch(0/3 : Batch number(172/782) : Batch loss : 0.37032151222229004
# Epoch(0/3 : Batch number(173/782) : Batch loss : 0.4228219985961914
# Epoch(0/3 : Batch number(174/782) : Batch loss : 0.6758941411972046
# Epoch(0/3 : Batch number(175/782) : Batch loss : 0.7354618310928345
# Epoch(0/3 : Batch number(176/782) : Batch loss : 0.5687839984893799
# Epoch(0/3 : Batch number(177/782) : Batch loss : 0.32994458079338074
# Epoch(0/3 : Batch number(178/782) : Batch loss : 0.2973794937133789
# Epoch(0/3 : Batch number(179/782) : Batch loss : 0.3272824287414551
# Epoch(0/3 : Batch number(180/782) : Batch loss : 0.5742956399917603
# Epoch(0/3 : Batch number(181/782) : Batch loss : 0.8198798298835754
# Epoch(0/3 : Batch number(182/782) : Batch loss : 0.44041329622268677
# Epoch(0/3 : Batch number(183/782) : Batch loss : 0.27474862337112427
# Epoch(0/3 : Batch number(184/782) : Batch loss : 0.5003098249435425
# Epoch(0/3 : Batch number(185/782) : Batch loss : 0.5245102643966675
# Epoch(0/3 : Batch number(186/782) : Batch loss : 0.288187175989151
# Epoch(0/3 : Batch number(187/782) : Batch loss : 0.3592327833175659
# Epoch(0/3 : Batch number(188/782) : Batch loss : 0.4410126507282257
# Epoch(0/3 : Batch number(189/782) : Batch loss : 0.30292123556137085
# Epoch(0/3 : Batch number(190/782) : Batch loss : 0.47982871532440186
# Epoch(0/3 : Batch number(191/782) : Batch loss : 0.3949642479419708
# Epoch(0/3 : Batch number(192/782) : Batch loss : 0.3698905110359192
# Epoch(0/3 : Batch number(193/782) : Batch loss : 0.21941787004470825
# Epoch(0/3 : Batch number(194/782) : Batch loss : 0.6110958456993103
# Epoch(0/3 : Batch number(195/782) : Batch loss : 0.5330020189285278
# Epoch(0/3 : Batch number(196/782) : Batch loss : 0.48480096459388733
# Epoch(0/3 : Batch number(197/782) : Batch loss : 0.49617648124694824
# Epoch(0/3 : Batch number(198/782) : Batch loss : 0.7112104892730713
# Epoch(0/3 : Batch number(199/782) : Batch loss : 0.49234044551849365
# Epoch(0/3 : Batch number(200/782) : Batch loss : 0.3671403229236603
# Epoch(0/3 : Batch number(201/782) : Batch loss : 0.2514595687389374
# Epoch(0/3 : Batch number(202/782) : Batch loss : 0.5088630318641663
# Epoch(0/3 : Batch number(203/782) : Batch loss : 0.23719607293605804
# Epoch(0/3 : Batch number(204/782) : Batch loss : 0.3831411600112915
# Epoch(0/3 : Batch number(205/782) : Batch loss : 0.26168519258499146
# Epoch(0/3 : Batch number(206/782) : Batch loss : 0.6210341453552246
# Epoch(0/3 : Batch number(207/782) : Batch loss : 0.4850495755672455
# Epoch(0/3 : Batch number(208/782) : Batch loss : 0.5739766955375671
# Epoch(0/3 : Batch number(209/782) : Batch loss : 0.8448986411094666
# Epoch(0/3 : Batch number(210/782) : Batch loss : 0.32664239406585693
# Epoch(0/3 : Batch number(211/782) : Batch loss : 0.5117359757423401
# Epoch(0/3 : Batch number(212/782) : Batch loss : 0.4573632478713989
# Epoch(0/3 : Batch number(213/782) : Batch loss : 0.24700874090194702
# Epoch(0/3 : Batch number(214/782) : Batch loss : 0.5814844369888306
# Epoch(0/3 : Batch number(215/782) : Batch loss : 0.5921821594238281
# Epoch(0/3 : Batch number(216/782) : Batch loss : 0.6258807182312012
# Epoch(0/3 : Batch number(217/782) : Batch loss : 0.34960097074508667
# Epoch(0/3 : Batch number(218/782) : Batch loss : 0.281146377325058
# Epoch(0/3 : Batch number(219/782) : Batch loss : 0.47363510727882385
# Epoch(0/3 : Batch number(220/782) : Batch loss : 0.4980821907520294
# Epoch(0/3 : Batch number(221/782) : Batch loss : 0.7027766108512878
# Epoch(0/3 : Batch number(222/782) : Batch loss : 0.5684411525726318
# Epoch(0/3 : Batch number(223/782) : Batch loss : 0.3695796728134155
# Epoch(0/3 : Batch number(224/782) : Batch loss : 0.4047695994377136
# Epoch(0/3 : Batch number(225/782) : Batch loss : 0.4529356062412262
# Epoch(0/3 : Batch number(226/782) : Batch loss : 0.4024333357810974
# Epoch(0/3 : Batch number(227/782) : Batch loss : 0.4194597899913788
# Epoch(0/3 : Batch number(228/782) : Batch loss : 0.5815239548683167
# Epoch(0/3 : Batch number(229/782) : Batch loss : 0.30748462677001953
# Epoch(0/3 : Batch number(230/782) : Batch loss : 0.49677300453186035
# Epoch(0/3 : Batch number(231/782) : Batch loss : 0.46208029985427856
# Epoch(0/3 : Batch number(232/782) : Batch loss : 0.642369270324707
# Epoch(0/3 : Batch number(233/782) : Batch loss : 0.44159063696861267
# Epoch(0/3 : Batch number(234/782) : Batch loss : 0.414529949426651
# Epoch(0/3 : Batch number(235/782) : Batch loss : 0.5817766189575195
# Epoch(0/3 : Batch number(236/782) : Batch loss : 0.5008820295333862
# Epoch(0/3 : Batch number(237/782) : Batch loss : 0.471491277217865
# Epoch(0/3 : Batch number(238/782) : Batch loss : 0.7069833874702454
# Epoch(0/3 : Batch number(239/782) : Batch loss : 0.2619854807853699
# Epoch(0/3 : Batch number(240/782) : Batch loss : 0.4708561897277832
# Epoch(0/3 : Batch number(241/782) : Batch loss : 0.5415935516357422
# Epoch(0/3 : Batch number(242/782) : Batch loss : 0.27074941992759705
# Epoch(0/3 : Batch number(243/782) : Batch loss : 0.5058359503746033
# Epoch(0/3 : Batch number(244/782) : Batch loss : 0.33540886640548706
# Epoch(0/3 : Batch number(245/782) : Batch loss : 0.4275335371494293
# Epoch(0/3 : Batch number(246/782) : Batch loss : 0.31894275546073914
# Epoch(0/3 : Batch number(247/782) : Batch loss : 0.43618297576904297
# Epoch(0/3 : Batch number(248/782) : Batch loss : 0.4053581655025482
# Epoch(0/3 : Batch number(249/782) : Batch loss : 0.31621408462524414
# Epoch(0/3 : Batch number(250/782) : Batch loss : 0.486768513917923
# Epoch(0/3 : Batch number(251/782) : Batch loss : 0.596974790096283
# Epoch(0/3 : Batch number(252/782) : Batch loss : 0.49762147665023804
# Epoch(0/3 : Batch number(253/782) : Batch loss : 0.5111058354377747
# Epoch(0/3 : Batch number(254/782) : Batch loss : 0.5636689066886902
# Epoch(0/3 : Batch number(255/782) : Batch loss : 0.2973003685474396
# Epoch(0/3 : Batch number(256/782) : Batch loss : 0.4280238151550293
# Epoch(0/3 : Batch number(257/782) : Batch loss : 0.24585990607738495
# Epoch(0/3 : Batch number(258/782) : Batch loss : 0.4172021150588989
# Epoch(0/3 : Batch number(259/782) : Batch loss : 0.3268357515335083
# Epoch(0/3 : Batch number(260/782) : Batch loss : 0.4130341410636902
# Epoch(0/3 : Batch number(261/782) : Batch loss : 0.508812665939331
# Epoch(0/3 : Batch number(262/782) : Batch loss : 0.551223635673523
# Epoch(0/3 : Batch number(263/782) : Batch loss : 0.3049967885017395
# Epoch(0/3 : Batch number(264/782) : Batch loss : 0.3908767104148865
# Epoch(0/3 : Batch number(265/782) : Batch loss : 0.3302146792411804
# Epoch(0/3 : Batch number(266/782) : Batch loss : 0.3741168975830078
# Epoch(0/3 : Batch number(267/782) : Batch loss : 0.5069005489349365
# Epoch(0/3 : Batch number(268/782) : Batch loss : 0.44162312150001526
# Epoch(0/3 : Batch number(269/782) : Batch loss : 0.40772745013237
# Epoch(0/3 : Batch number(270/782) : Batch loss : 0.4264911711215973
# Epoch(0/3 : Batch number(271/782) : Batch loss : 0.45570486783981323
# Epoch(0/3 : Batch number(272/782) : Batch loss : 0.570384681224823
# Epoch(0/3 : Batch number(273/782) : Batch loss : 0.5714932084083557
# Epoch(0/3 : Batch number(274/782) : Batch loss : 0.4781627655029297
# Epoch(0/3 : Batch number(275/782) : Batch loss : 0.3288578689098358
# Epoch(0/3 : Batch number(276/782) : Batch loss : 0.4550120234489441
# Epoch(0/3 : Batch number(277/782) : Batch loss : 0.4975804090499878
# Epoch(0/3 : Batch number(278/782) : Batch loss : 0.440242737531662
# Epoch(0/3 : Batch number(279/782) : Batch loss : 0.6712331771850586
# Epoch(0/3 : Batch number(280/782) : Batch loss : 0.630837082862854
# Epoch(0/3 : Batch number(281/782) : Batch loss : 0.44068920612335205
# Epoch(0/3 : Batch number(282/782) : Batch loss : 0.4473392963409424
# Epoch(0/3 : Batch number(283/782) : Batch loss : 0.7174444198608398
# Epoch(0/3 : Batch number(284/782) : Batch loss : 0.7025395631790161
# Epoch(0/3 : Batch number(285/782) : Batch loss : 0.5126801133155823
# Epoch(0/3 : Batch number(286/782) : Batch loss : 0.5562690496444702
# Epoch(0/3 : Batch number(287/782) : Batch loss : 0.35056164860725403
# Epoch(0/3 : Batch number(288/782) : Batch loss : 0.4056096076965332
# Epoch(0/3 : Batch number(289/782) : Batch loss : 0.6025678515434265
# Epoch(0/3 : Batch number(290/782) : Batch loss : 0.3432435989379883
# Epoch(0/3 : Batch number(291/782) : Batch loss : 0.48018521070480347
# Epoch(0/3 : Batch number(292/782) : Batch loss : 0.5861441493034363
# Epoch(0/3 : Batch number(293/782) : Batch loss : 0.4501038193702698
# Epoch(0/3 : Batch number(294/782) : Batch loss : 0.5004929900169373
# Epoch(0/3 : Batch number(295/782) : Batch loss : 0.37998610734939575
# Epoch(0/3 : Batch number(296/782) : Batch loss : 0.564061164855957
# Epoch(0/3 : Batch number(297/782) : Batch loss : 0.4714716076850891
# Epoch(0/3 : Batch number(298/782) : Batch loss : 0.64973384141922
# Epoch(0/3 : Batch number(299/782) : Batch loss : 0.4839838743209839
# Epoch(0/3 : Batch number(300/782) : Batch loss : 0.3974773585796356
# Epoch(0/3 : Batch number(301/782) : Batch loss : 0.5212510228157043
# Epoch(0/3 : Batch number(302/782) : Batch loss : 0.5088786482810974
# Epoch(0/3 : Batch number(303/782) : Batch loss : 0.3449679911136627
# Epoch(0/3 : Batch number(304/782) : Batch loss : 0.459580659866333
# Epoch(0/3 : Batch number(305/782) : Batch loss : 0.2828412652015686
# Epoch(0/3 : Batch number(306/782) : Batch loss : 0.3049144744873047
# Epoch(0/3 : Batch number(307/782) : Batch loss : 0.3800777196884155
# Epoch(0/3 : Batch number(308/782) : Batch loss : 0.3332366645336151
# Epoch(0/3 : Batch number(309/782) : Batch loss : 0.4574427604675293
# Epoch(0/3 : Batch number(310/782) : Batch loss : 0.4718467891216278
# Epoch(0/3 : Batch number(311/782) : Batch loss : 0.36139756441116333
# Epoch(0/3 : Batch number(312/782) : Batch loss : 0.5325349569320679
# Epoch(0/3 : Batch number(313/782) : Batch loss : 0.31741583347320557
# Epoch(0/3 : Batch number(314/782) : Batch loss : 0.5583800673484802
# Epoch(0/3 : Batch number(315/782) : Batch loss : 0.6370230913162231
# Epoch(0/3 : Batch number(316/782) : Batch loss : 0.28781136870384216
# Epoch(0/3 : Batch number(317/782) : Batch loss : 0.2622375190258026
# Epoch(0/3 : Batch number(318/782) : Batch loss : 0.5679165124893188
# Epoch(0/3 : Batch number(319/782) : Batch loss : 0.3567582070827484
# Epoch(0/3 : Batch number(320/782) : Batch loss : 0.3858650326728821
# Epoch(0/3 : Batch number(321/782) : Batch loss : 0.5387497544288635
# Epoch(0/3 : Batch number(322/782) : Batch loss : 0.4474365711212158
# Epoch(0/3 : Batch number(323/782) : Batch loss : 0.48322173953056335
# Epoch(0/3 : Batch number(324/782) : Batch loss : 0.5501577854156494
# Epoch(0/3 : Batch number(325/782) : Batch loss : 0.5190739631652832
# Epoch(0/3 : Batch number(326/782) : Batch loss : 0.47009536623954773
# Epoch(0/3 : Batch number(327/782) : Batch loss : 0.36203527450561523
# Epoch(0/3 : Batch number(328/782) : Batch loss : 0.31838589906692505
# Epoch(0/3 : Batch number(329/782) : Batch loss : 0.5346319079399109
# Epoch(0/3 : Batch number(330/782) : Batch loss : 0.4337696433067322
# Epoch(0/3 : Batch number(331/782) : Batch loss : 0.43390658497810364
# Epoch(0/3 : Batch number(332/782) : Batch loss : 0.43710076808929443
# Epoch(0/3 : Batch number(333/782) : Batch loss : 0.3743877410888672
# Epoch(0/3 : Batch number(334/782) : Batch loss : 0.43498021364212036
# Epoch(0/3 : Batch number(335/782) : Batch loss : 0.3170130252838135
# Epoch(0/3 : Batch number(336/782) : Batch loss : 0.45411020517349243
# Epoch(0/3 : Batch number(337/782) : Batch loss : 0.5158270597457886
# Epoch(0/3 : Batch number(338/782) : Batch loss : 0.4543147683143616
# Epoch(0/3 : Batch number(339/782) : Batch loss : 0.4370807707309723
# Epoch(0/3 : Batch number(340/782) : Batch loss : 0.6316688656806946
# Epoch(0/3 : Batch number(341/782) : Batch loss : 0.5448757410049438
# Epoch(0/3 : Batch number(342/782) : Batch loss : 0.4175703525543213
# Epoch(0/3 : Batch number(343/782) : Batch loss : 0.31530094146728516
# Epoch(0/3 : Batch number(344/782) : Batch loss : 0.5921768546104431
# Epoch(0/3 : Batch number(345/782) : Batch loss : 0.27567702531814575
# Epoch(0/3 : Batch number(346/782) : Batch loss : 0.4282088279724121
# Epoch(0/3 : Batch number(347/782) : Batch loss : 0.3468955159187317
# Epoch(0/3 : Batch number(348/782) : Batch loss : 0.5598889589309692
# Epoch(0/3 : Batch number(349/782) : Batch loss : 0.46613460779190063
# Epoch(0/3 : Batch number(350/782) : Batch loss : 0.3407193124294281
# Epoch(0/3 : Batch number(351/782) : Batch loss : 0.38053447008132935
# Epoch(0/3 : Batch number(352/782) : Batch loss : 0.4064284563064575
# Epoch(0/3 : Batch number(353/782) : Batch loss : 0.744979977607727
# Epoch(0/3 : Batch number(354/782) : Batch loss : 0.576400876045227
# Epoch(0/3 : Batch number(355/782) : Batch loss : 0.4177386164665222
# Epoch(0/3 : Batch number(356/782) : Batch loss : 0.30116739869117737
# Epoch(0/3 : Batch number(357/782) : Batch loss : 0.4382624924182892
# Epoch(0/3 : Batch number(358/782) : Batch loss : 0.5744183659553528
# Epoch(0/3 : Batch number(359/782) : Batch loss : 0.2937030792236328
# Epoch(0/3 : Batch number(360/782) : Batch loss : 0.42878586053848267
# Epoch(0/3 : Batch number(361/782) : Batch loss : 0.5144752264022827
# Epoch(0/3 : Batch number(362/782) : Batch loss : 0.3645869195461273
# Epoch(0/3 : Batch number(363/782) : Batch loss : 0.5146785378456116
# Epoch(0/3 : Batch number(364/782) : Batch loss : 0.5760374069213867
# Epoch(0/3 : Batch number(365/782) : Batch loss : 0.44139158725738525
# Epoch(0/3 : Batch number(366/782) : Batch loss : 0.3335244059562683
# Epoch(0/3 : Batch number(367/782) : Batch loss : 0.5589180588722229
# Epoch(0/3 : Batch number(368/782) : Batch loss : 0.5112014412879944
# Epoch(0/3 : Batch number(369/782) : Batch loss : 0.45522454380989075
# Epoch(0/3 : Batch number(370/782) : Batch loss : 0.5092514753341675
# Epoch(0/3 : Batch number(371/782) : Batch loss : 0.541559636592865
# Epoch(0/3 : Batch number(372/782) : Batch loss : 0.3458958566188812
# Epoch(0/3 : Batch number(373/782) : Batch loss : 0.5178186893463135
# Epoch(0/3 : Batch number(374/782) : Batch loss : 0.4421777129173279
# Epoch(0/3 : Batch number(375/782) : Batch loss : 0.33693256974220276
# Epoch(0/3 : Batch number(376/782) : Batch loss : 0.28074097633361816
# Epoch(0/3 : Batch number(377/782) : Batch loss : 0.4214477837085724
# Epoch(0/3 : Batch number(378/782) : Batch loss : 0.479763925075531
# Epoch(0/3 : Batch number(379/782) : Batch loss : 0.35654914379119873
# Epoch(0/3 : Batch number(380/782) : Batch loss : 0.33654531836509705
# Epoch(0/3 : Batch number(381/782) : Batch loss : 0.5203189849853516
# Epoch(0/3 : Batch number(382/782) : Batch loss : 0.42902886867523193
# Epoch(0/3 : Batch number(383/782) : Batch loss : 0.4117967486381531
# Epoch(0/3 : Batch number(384/782) : Batch loss : 0.4466506838798523
# Epoch(0/3 : Batch number(385/782) : Batch loss : 0.3295498788356781
# Epoch(0/3 : Batch number(386/782) : Batch loss : 0.40936851501464844
# Epoch(0/3 : Batch number(387/782) : Batch loss : 0.4012584090232849
# Epoch(0/3 : Batch number(388/782) : Batch loss : 0.6823837757110596
# Epoch(0/3 : Batch number(389/782) : Batch loss : 0.4817744195461273
# Epoch(0/3 : Batch number(390/782) : Batch loss : 0.5594529509544373
# Epoch(0/3 : Batch number(391/782) : Batch loss : 0.3823218047618866
# Epoch(0/3 : Batch number(392/782) : Batch loss : 0.3507618010044098
# Epoch(0/3 : Batch number(393/782) : Batch loss : 0.3744620680809021
# Epoch(0/3 : Batch number(394/782) : Batch loss : 0.3866215646266937
# Epoch(0/3 : Batch number(395/782) : Batch loss : 0.34040567278862
# Epoch(0/3 : Batch number(396/782) : Batch loss : 0.3155570924282074
# Epoch(0/3 : Batch number(397/782) : Batch loss : 0.4051288366317749
# Epoch(0/3 : Batch number(398/782) : Batch loss : 0.6154382228851318
# Epoch(0/3 : Batch number(399/782) : Batch loss : 0.29224205017089844
# Epoch(0/3 : Batch number(400/782) : Batch loss : 0.5855552554130554
# Epoch(0/3 : Batch number(401/782) : Batch loss : 0.3751343786716461
# Epoch(0/3 : Batch number(402/782) : Batch loss : 0.36518868803977966
# Epoch(0/3 : Batch number(403/782) : Batch loss : 0.5710253715515137
# Epoch(0/3 : Batch number(404/782) : Batch loss : 0.4253205955028534
# Epoch(0/3 : Batch number(405/782) : Batch loss : 0.4713105261325836
# Epoch(0/3 : Batch number(406/782) : Batch loss : 0.4983678460121155
# Epoch(0/3 : Batch number(407/782) : Batch loss : 0.3833633363246918
# Epoch(0/3 : Batch number(408/782) : Batch loss : 0.39919573068618774
# Epoch(0/3 : Batch number(409/782) : Batch loss : 0.46220460534095764
# Epoch(0/3 : Batch number(410/782) : Batch loss : 0.31590527296066284
# Epoch(0/3 : Batch number(411/782) : Batch loss : 0.46063467860221863
# Epoch(0/3 : Batch number(412/782) : Batch loss : 0.44575178623199463
# Epoch(0/3 : Batch number(413/782) : Batch loss : 0.3008480668067932
# Epoch(0/3 : Batch number(414/782) : Batch loss : 0.434447705745697
# Epoch(0/3 : Batch number(415/782) : Batch loss : 0.39117366075515747
# Epoch(0/3 : Batch number(416/782) : Batch loss : 0.24421468377113342
# Epoch(0/3 : Batch number(417/782) : Batch loss : 0.3663749098777771
# Epoch(0/3 : Batch number(418/782) : Batch loss : 0.3372686505317688
# Epoch(0/3 : Batch number(419/782) : Batch loss : 0.4594035744667053
# Epoch(0/3 : Batch number(420/782) : Batch loss : 0.39291059970855713
# Epoch(0/3 : Batch number(421/782) : Batch loss : 0.2995089590549469
# Epoch(0/3 : Batch number(422/782) : Batch loss : 0.3477911055088043
# Epoch(0/3 : Batch number(423/782) : Batch loss : 0.3130614757537842
# Epoch(0/3 : Batch number(424/782) : Batch loss : 0.37525641918182373
# Epoch(0/3 : Batch number(425/782) : Batch loss : 0.4304508864879608
# Epoch(0/3 : Batch number(426/782) : Batch loss : 0.4152093827724457
# Epoch(0/3 : Batch number(427/782) : Batch loss : 0.48590970039367676
# Epoch(0/3 : Batch number(428/782) : Batch loss : 0.46059051156044006
# Epoch(0/3 : Batch number(429/782) : Batch loss : 0.46813908219337463
# Epoch(0/3 : Batch number(430/782) : Batch loss : 0.6473338007926941
# Epoch(0/3 : Batch number(431/782) : Batch loss : 0.4743494987487793
# Epoch(0/3 : Batch number(432/782) : Batch loss : 0.22907862067222595
# Epoch(0/3 : Batch number(433/782) : Batch loss : 0.2559794485569
# Epoch(0/3 : Batch number(434/782) : Batch loss : 0.7254576086997986
# Epoch(0/3 : Batch number(435/782) : Batch loss : 0.32383453845977783
# Epoch(0/3 : Batch number(436/782) : Batch loss : 0.4136767089366913
# Epoch(0/3 : Batch number(437/782) : Batch loss : 0.3991548717021942
# Epoch(0/3 : Batch number(438/782) : Batch loss : 0.35287219285964966
# Epoch(0/3 : Batch number(439/782) : Batch loss : 0.547021746635437
# Epoch(0/3 : Batch number(440/782) : Batch loss : 0.6082854866981506
# Epoch(0/3 : Batch number(441/782) : Batch loss : 0.5225522518157959
# Epoch(0/3 : Batch number(442/782) : Batch loss : 0.35938096046447754
# Epoch(0/3 : Batch number(443/782) : Batch loss : 0.3845393657684326
# Epoch(0/3 : Batch number(444/782) : Batch loss : 0.3988869786262512
# Epoch(0/3 : Batch number(445/782) : Batch loss : 0.38142237067222595
# Epoch(0/3 : Batch number(446/782) : Batch loss : 0.36816006898880005
# Epoch(0/3 : Batch number(447/782) : Batch loss : 0.32109442353248596
# Epoch(0/3 : Batch number(448/782) : Batch loss : 0.7466320991516113
# Epoch(0/3 : Batch number(449/782) : Batch loss : 0.5191327929496765
# Epoch(0/3 : Batch number(450/782) : Batch loss : 0.3864075541496277
# Epoch(0/3 : Batch number(451/782) : Batch loss : 0.3584117591381073
# Epoch(0/3 : Batch number(452/782) : Batch loss : 0.3781803846359253
# Epoch(0/3 : Batch number(453/782) : Batch loss : 0.5760406851768494
# Epoch(0/3 : Batch number(454/782) : Batch loss : 0.4291691184043884
# Epoch(0/3 : Batch number(455/782) : Batch loss : 0.3759862184524536
# Epoch(0/3 : Batch number(456/782) : Batch loss : 0.5183969140052795
# Epoch(0/3 : Batch number(457/782) : Batch loss : 0.46926528215408325
# Epoch(0/3 : Batch number(458/782) : Batch loss : 0.29837343096733093
# Epoch(0/3 : Batch number(459/782) : Batch loss : 0.40599218010902405
# Epoch(0/3 : Batch number(460/782) : Batch loss : 0.34466537833213806
# Epoch(0/3 : Batch number(461/782) : Batch loss : 0.7311369776725769
# Epoch(0/3 : Batch number(462/782) : Batch loss : 0.3806869387626648
# Epoch(0/3 : Batch number(463/782) : Batch loss : 0.37677741050720215
# Epoch(0/3 : Batch number(464/782) : Batch loss : 0.3696230947971344
# Epoch(0/3 : Batch number(465/782) : Batch loss : 0.3070591688156128
# Epoch(0/3 : Batch number(466/782) : Batch loss : 0.6022054553031921
# Epoch(0/3 : Batch number(467/782) : Batch loss : 0.5206698179244995
# Epoch(0/3 : Batch number(468/782) : Batch loss : 0.45876967906951904
# Epoch(0/3 : Batch number(469/782) : Batch loss : 0.25335514545440674
# Epoch(0/3 : Batch number(470/782) : Batch loss : 0.8028806447982788
# Epoch(0/3 : Batch number(471/782) : Batch loss : 0.4701218008995056
# Epoch(0/3 : Batch number(472/782) : Batch loss : 0.598836362361908
# Epoch(0/3 : Batch number(473/782) : Batch loss : 0.7200031280517578
# Epoch(0/3 : Batch number(474/782) : Batch loss : 0.3557341396808624
# Epoch(0/3 : Batch number(475/782) : Batch loss : 0.5822751522064209
# Epoch(0/3 : Batch number(476/782) : Batch loss : 0.6548029780387878
# Epoch(0/3 : Batch number(477/782) : Batch loss : 0.4151354134082794
# Epoch(0/3 : Batch number(478/782) : Batch loss : 0.48556649684906006
# Epoch(0/3 : Batch number(479/782) : Batch loss : 0.592723548412323
# Epoch(0/3 : Batch number(480/782) : Batch loss : 0.2825544476509094
# Epoch(0/3 : Batch number(481/782) : Batch loss : 0.3740425705909729
# Epoch(0/3 : Batch number(482/782) : Batch loss : 0.27319279313087463
# Epoch(0/3 : Batch number(483/782) : Batch loss : 0.375266432762146
# Epoch(0/3 : Batch number(484/782) : Batch loss : 0.3922045826911926
# Epoch(0/3 : Batch number(485/782) : Batch loss : 0.39799225330352783
# Epoch(0/3 : Batch number(486/782) : Batch loss : 0.45511555671691895
# Epoch(0/3 : Batch number(487/782) : Batch loss : 0.5608402490615845
# Epoch(0/3 : Batch number(488/782) : Batch loss : 0.48414117097854614
# Epoch(0/3 : Batch number(489/782) : Batch loss : 0.4302000403404236
# Epoch(0/3 : Batch number(490/782) : Batch loss : 0.41905295848846436
# Epoch(0/3 : Batch number(491/782) : Batch loss : 0.3601144850254059
# Epoch(0/3 : Batch number(492/782) : Batch loss : 0.42252886295318604
# Epoch(0/3 : Batch number(493/782) : Batch loss : 0.5416774749755859
# Epoch(0/3 : Batch number(494/782) : Batch loss : 0.46584510803222656
# Epoch(0/3 : Batch number(495/782) : Batch loss : 0.2856212854385376
# Epoch(0/3 : Batch number(496/782) : Batch loss : 0.5272430181503296
# Epoch(0/3 : Batch number(497/782) : Batch loss : 0.5502825975418091
# Epoch(0/3 : Batch number(498/782) : Batch loss : 0.34028512239456177
# Epoch(0/3 : Batch number(499/782) : Batch loss : 0.5065914392471313
# Epoch(0/3 : Batch number(500/782) : Batch loss : 0.29235154390335083
# Epoch(0/3 : Batch number(501/782) : Batch loss : 0.36407703161239624
# Epoch(0/3 : Batch number(502/782) : Batch loss : 0.5059555768966675
# Epoch(0/3 : Batch number(503/782) : Batch loss : 0.6134830713272095
# Epoch(0/3 : Batch number(504/782) : Batch loss : 0.7453052997589111
# Epoch(0/3 : Batch number(505/782) : Batch loss : 0.393682062625885
# Epoch(0/3 : Batch number(506/782) : Batch loss : 0.5202930569648743
# Epoch(0/3 : Batch number(507/782) : Batch loss : 0.4223518371582031
# Epoch(0/3 : Batch number(508/782) : Batch loss : 0.37280553579330444
# Epoch(0/3 : Batch number(509/782) : Batch loss : 0.33431702852249146
# Epoch(0/3 : Batch number(510/782) : Batch loss : 0.5361150503158569
# Epoch(0/3 : Batch number(511/782) : Batch loss : 0.4803847074508667
# Epoch(0/3 : Batch number(512/782) : Batch loss : 0.6057187914848328
# Epoch(0/3 : Batch number(513/782) : Batch loss : 0.4363691210746765
# Epoch(0/3 : Batch number(514/782) : Batch loss : 0.5112921595573425
# Epoch(0/3 : Batch number(515/782) : Batch loss : 0.4036288857460022
# Epoch(0/3 : Batch number(516/782) : Batch loss : 0.3266054689884186
# Epoch(0/3 : Batch number(517/782) : Batch loss : 0.36755168437957764
# Epoch(0/3 : Batch number(518/782) : Batch loss : 0.33212682604789734
# Epoch(0/3 : Batch number(519/782) : Batch loss : 0.3212970197200775
# Epoch(0/3 : Batch number(520/782) : Batch loss : 0.49762946367263794
# Epoch(0/3 : Batch number(521/782) : Batch loss : 0.3601512908935547
# Epoch(0/3 : Batch number(522/782) : Batch loss : 0.41941550374031067
# Epoch(0/3 : Batch number(523/782) : Batch loss : 0.3498343229293823
# Epoch(0/3 : Batch number(524/782) : Batch loss : 0.40588465332984924
# Epoch(0/3 : Batch number(525/782) : Batch loss : 0.4509531855583191
# Epoch(0/3 : Batch number(526/782) : Batch loss : 0.3496675491333008
# Epoch(0/3 : Batch number(527/782) : Batch loss : 0.4791852831840515
# Epoch(0/3 : Batch number(528/782) : Batch loss : 0.4637351632118225
# Epoch(0/3 : Batch number(529/782) : Batch loss : 0.34591206908226013
# Epoch(0/3 : Batch number(530/782) : Batch loss : 0.5366019606590271
# Epoch(0/3 : Batch number(531/782) : Batch loss : 0.3074241280555725
# Epoch(0/3 : Batch number(532/782) : Batch loss : 0.386974573135376
# Epoch(0/3 : Batch number(533/782) : Batch loss : 0.5221136808395386
# Epoch(0/3 : Batch number(534/782) : Batch loss : 0.30448850989341736
# Epoch(0/3 : Batch number(535/782) : Batch loss : 0.2505814731121063
# Epoch(0/3 : Batch number(536/782) : Batch loss : 0.3908751308917999
# Epoch(0/3 : Batch number(537/782) : Batch loss : 0.5279378890991211
# Epoch(0/3 : Batch number(538/782) : Batch loss : 0.3842241168022156
# Epoch(0/3 : Batch number(539/782) : Batch loss : 0.3404088020324707
# Epoch(0/3 : Batch number(540/782) : Batch loss : 0.4885665774345398
# Epoch(0/3 : Batch number(541/782) : Batch loss : 0.4753241539001465
# Epoch(0/3 : Batch number(542/782) : Batch loss : 0.332869291305542
# Epoch(0/3 : Batch number(543/782) : Batch loss : 0.4388505220413208
# Epoch(0/3 : Batch number(544/782) : Batch loss : 0.3026542067527771
# Epoch(0/3 : Batch number(545/782) : Batch loss : 0.5132438540458679
# Epoch(0/3 : Batch number(546/782) : Batch loss : 0.36883771419525146
# Epoch(0/3 : Batch number(547/782) : Batch loss : 0.49348562955856323
# Epoch(0/3 : Batch number(548/782) : Batch loss : 0.6402513980865479
# Epoch(0/3 : Batch number(549/782) : Batch loss : 0.4328249990940094
# Epoch(0/3 : Batch number(550/782) : Batch loss : 0.25309833884239197
# Epoch(0/3 : Batch number(551/782) : Batch loss : 0.5216290950775146
# Epoch(0/3 : Batch number(552/782) : Batch loss : 0.29997718334198
# Epoch(0/3 : Batch number(553/782) : Batch loss : 0.4523344337940216
# Epoch(0/3 : Batch number(554/782) : Batch loss : 0.6530620455741882
# Epoch(0/3 : Batch number(555/782) : Batch loss : 0.5841419100761414
# Epoch(0/3 : Batch number(556/782) : Batch loss : 0.4617044925689697
# Epoch(0/3 : Batch number(557/782) : Batch loss : 0.6017633080482483
# Epoch(0/3 : Batch number(558/782) : Batch loss : 0.4951545298099518
# Epoch(0/3 : Batch number(559/782) : Batch loss : 0.5074220299720764
# Epoch(0/3 : Batch number(560/782) : Batch loss : 0.32087206840515137
# Epoch(0/3 : Batch number(561/782) : Batch loss : 0.35685092210769653
# Epoch(0/3 : Batch number(562/782) : Batch loss : 0.5561178922653198
# Epoch(0/3 : Batch number(563/782) : Batch loss : 0.5094123482704163
# Epoch(0/3 : Batch number(564/782) : Batch loss : 0.6814404129981995
# Epoch(0/3 : Batch number(565/782) : Batch loss : 0.5329939126968384
# Epoch(0/3 : Batch number(566/782) : Batch loss : 0.3869311213493347
# Epoch(0/3 : Batch number(567/782) : Batch loss : 0.36249661445617676
# Epoch(0/3 : Batch number(568/782) : Batch loss : 0.36589181423187256
# Epoch(0/3 : Batch number(569/782) : Batch loss : 0.22495105862617493
# Epoch(0/3 : Batch number(570/782) : Batch loss : 0.3957985043525696
# Epoch(0/3 : Batch number(571/782) : Batch loss : 0.5958441495895386
# Epoch(0/3 : Batch number(572/782) : Batch loss : 0.33027493953704834
# Epoch(0/3 : Batch number(573/782) : Batch loss : 0.6030517816543579
# Epoch(0/3 : Batch number(574/782) : Batch loss : 0.5295239686965942
# Epoch(0/3 : Batch number(575/782) : Batch loss : 0.41001632809638977
# Epoch(0/3 : Batch number(576/782) : Batch loss : 0.50422203540802
# Epoch(0/3 : Batch number(577/782) : Batch loss : 0.30818432569503784
# Epoch(0/3 : Batch number(578/782) : Batch loss : 0.4504808783531189
# Epoch(0/3 : Batch number(579/782) : Batch loss : 0.31437546014785767
# Epoch(0/3 : Batch number(580/782) : Batch loss : 0.4119608998298645
# Epoch(0/3 : Batch number(581/782) : Batch loss : 0.4347006678581238
# Epoch(0/3 : Batch number(582/782) : Batch loss : 0.24228909611701965
# Epoch(0/3 : Batch number(583/782) : Batch loss : 0.34354516863822937
# Epoch(0/3 : Batch number(584/782) : Batch loss : 0.6035052537918091
# Epoch(0/3 : Batch number(585/782) : Batch loss : 0.27645111083984375
# Epoch(0/3 : Batch number(586/782) : Batch loss : 0.707846999168396
# Epoch(0/3 : Batch number(587/782) : Batch loss : 0.35502395033836365
# Epoch(0/3 : Batch number(588/782) : Batch loss : 0.4493138790130615
# Epoch(0/3 : Batch number(589/782) : Batch loss : 0.31603264808654785
# Epoch(0/3 : Batch number(590/782) : Batch loss : 0.45482137799263
# Epoch(0/3 : Batch number(591/782) : Batch loss : 0.31797516345977783
# Epoch(0/3 : Batch number(592/782) : Batch loss : 0.3361130654811859
# Epoch(0/3 : Batch number(593/782) : Batch loss : 0.36644572019577026
# Epoch(0/3 : Batch number(594/782) : Batch loss : 0.549141526222229
# Epoch(0/3 : Batch number(595/782) : Batch loss : 0.3274790644645691
# Epoch(0/3 : Batch number(596/782) : Batch loss : 0.5987766981124878
# Epoch(0/3 : Batch number(597/782) : Batch loss : 0.4382104277610779
# Epoch(0/3 : Batch number(598/782) : Batch loss : 0.3537415862083435
# Epoch(0/3 : Batch number(599/782) : Batch loss : 0.43024566769599915
# Epoch(0/3 : Batch number(600/782) : Batch loss : 0.6571594476699829
# Epoch(0/3 : Batch number(601/782) : Batch loss : 0.2732839584350586
# Epoch(0/3 : Batch number(602/782) : Batch loss : 0.35272765159606934
# Epoch(0/3 : Batch number(603/782) : Batch loss : 0.3979877829551697
# Epoch(0/3 : Batch number(604/782) : Batch loss : 0.5813199281692505
# Epoch(0/3 : Batch number(605/782) : Batch loss : 0.4138510227203369
# Epoch(0/3 : Batch number(606/782) : Batch loss : 0.7309936881065369
# Epoch(0/3 : Batch number(607/782) : Batch loss : 0.3409035801887512
# Epoch(0/3 : Batch number(608/782) : Batch loss : 0.5054811835289001
# Epoch(0/3 : Batch number(609/782) : Batch loss : 0.5205225944519043
# Epoch(0/3 : Batch number(610/782) : Batch loss : 0.4052594006061554
# Epoch(0/3 : Batch number(611/782) : Batch loss : 0.3725380301475525
# Epoch(0/3 : Batch number(612/782) : Batch loss : 0.3722130060195923
# Epoch(0/3 : Batch number(613/782) : Batch loss : 0.3085169792175293
# Epoch(0/3 : Batch number(614/782) : Batch loss : 0.7370650172233582
# Epoch(0/3 : Batch number(615/782) : Batch loss : 0.5160375833511353
# Epoch(0/3 : Batch number(616/782) : Batch loss : 0.5090678930282593
# Epoch(0/3 : Batch number(617/782) : Batch loss : 0.37370774149894714
# Epoch(0/3 : Batch number(618/782) : Batch loss : 0.298632949590683
# Epoch(0/3 : Batch number(619/782) : Batch loss : 0.35428860783576965
# Epoch(0/3 : Batch number(620/782) : Batch loss : 0.28271451592445374
# Epoch(0/3 : Batch number(621/782) : Batch loss : 0.33033838868141174
# Epoch(0/3 : Batch number(622/782) : Batch loss : 0.44445598125457764
# Epoch(0/3 : Batch number(623/782) : Batch loss : 0.267702579498291
# Epoch(0/3 : Batch number(624/782) : Batch loss : 0.5058258771896362
# Epoch(0/3 : Batch number(625/782) : Batch loss : 0.3639090359210968
# Epoch(0/3 : Batch number(626/782) : Batch loss : 0.628055214881897
# Epoch(0/3 : Batch number(627/782) : Batch loss : 0.3850706219673157
# Epoch(0/3 : Batch number(628/782) : Batch loss : 0.3321269154548645
# Epoch(0/3 : Batch number(629/782) : Batch loss : 0.4029490649700165
# Epoch(0/3 : Batch number(630/782) : Batch loss : 0.50594162940979
# Epoch(0/3 : Batch number(631/782) : Batch loss : 0.4167938232421875
# Epoch(0/3 : Batch number(632/782) : Batch loss : 0.4471738934516907
# Epoch(0/3 : Batch number(633/782) : Batch loss : 0.3756343126296997
# Epoch(0/3 : Batch number(634/782) : Batch loss : 0.5274315476417542
# Epoch(0/3 : Batch number(635/782) : Batch loss : 0.26634514331817627
# Epoch(0/3 : Batch number(636/782) : Batch loss : 0.46465080976486206
# Epoch(0/3 : Batch number(637/782) : Batch loss : 0.36996620893478394
# Epoch(0/3 : Batch number(638/782) : Batch loss : 0.3676060438156128
# Epoch(0/3 : Batch number(639/782) : Batch loss : 0.29525089263916016
# Epoch(0/3 : Batch number(640/782) : Batch loss : 0.4720916152000427
# Epoch(0/3 : Batch number(641/782) : Batch loss : 0.3450356721878052
# Epoch(0/3 : Batch number(642/782) : Batch loss : 0.4258168339729309
# Epoch(0/3 : Batch number(643/782) : Batch loss : 0.49591270089149475
# Epoch(0/3 : Batch number(644/782) : Batch loss : 0.6654286980628967
# Epoch(0/3 : Batch number(645/782) : Batch loss : 0.49407050013542175
# Epoch(0/3 : Batch number(646/782) : Batch loss : 0.5200179219245911
# Epoch(0/3 : Batch number(647/782) : Batch loss : 0.4466744363307953
# Epoch(0/3 : Batch number(648/782) : Batch loss : 0.634599506855011
# Epoch(0/3 : Batch number(649/782) : Batch loss : 0.4247456192970276
# Epoch(0/3 : Batch number(650/782) : Batch loss : 0.42922425270080566
# Epoch(0/3 : Batch number(651/782) : Batch loss : 0.36854788661003113
# Epoch(0/3 : Batch number(652/782) : Batch loss : 0.3903064727783203
# Epoch(0/3 : Batch number(653/782) : Batch loss : 0.43777740001678467
# Epoch(0/3 : Batch number(654/782) : Batch loss : 0.8143365979194641
# Epoch(0/3 : Batch number(655/782) : Batch loss : 0.3672153949737549
# Epoch(0/3 : Batch number(656/782) : Batch loss : 0.3505597412586212
# Epoch(0/3 : Batch number(657/782) : Batch loss : 0.49080386757850647
# Epoch(0/3 : Batch number(658/782) : Batch loss : 0.3552742898464203
# Epoch(0/3 : Batch number(659/782) : Batch loss : 0.3613860607147217
# Epoch(0/3 : Batch number(660/782) : Batch loss : 0.40648677945137024
# Epoch(0/3 : Batch number(661/782) : Batch loss : 0.48964163661003113
# Epoch(0/3 : Batch number(662/782) : Batch loss : 0.33834099769592285
# Epoch(0/3 : Batch number(663/782) : Batch loss : 0.36453741788864136
# Epoch(0/3 : Batch number(664/782) : Batch loss : 0.46729183197021484
# Epoch(0/3 : Batch number(665/782) : Batch loss : 0.47642967104911804
# Epoch(0/3 : Batch number(666/782) : Batch loss : 0.44928327202796936
# Epoch(0/3 : Batch number(667/782) : Batch loss : 0.3608909845352173
# Epoch(0/3 : Batch number(668/782) : Batch loss : 0.521027147769928
# Epoch(0/3 : Batch number(669/782) : Batch loss : 0.2965560853481293
# Epoch(0/3 : Batch number(670/782) : Batch loss : 0.4916340708732605
# Epoch(0/3 : Batch number(671/782) : Batch loss : 0.29814085364341736
# Epoch(0/3 : Batch number(672/782) : Batch loss : 0.45930472016334534
# Epoch(0/3 : Batch number(673/782) : Batch loss : 0.3145321011543274
# Epoch(0/3 : Batch number(674/782) : Batch loss : 0.5206565260887146
# Epoch(0/3 : Batch number(675/782) : Batch loss : 0.41151756048202515
# Epoch(0/3 : Batch number(676/782) : Batch loss : 0.2776716947555542
# Epoch(0/3 : Batch number(677/782) : Batch loss : 0.283237099647522
# Epoch(0/3 : Batch number(678/782) : Batch loss : 0.5903916954994202
# Epoch(0/3 : Batch number(679/782) : Batch loss : 0.1837751418352127
# Epoch(0/3 : Batch number(680/782) : Batch loss : 0.38046810030937195
# Epoch(0/3 : Batch number(681/782) : Batch loss : 0.3643505573272705
# Epoch(0/3 : Batch number(682/782) : Batch loss : 0.5008273124694824
# Epoch(0/3 : Batch number(683/782) : Batch loss : 0.3965286612510681
# Epoch(0/3 : Batch number(684/782) : Batch loss : 0.5071491003036499
# Epoch(0/3 : Batch number(685/782) : Batch loss : 0.38117504119873047
# Epoch(0/3 : Batch number(686/782) : Batch loss : 0.40725070238113403
# Epoch(0/3 : Batch number(687/782) : Batch loss : 0.4142482280731201
# Epoch(0/3 : Batch number(688/782) : Batch loss : 0.32140398025512695
# Epoch(0/3 : Batch number(689/782) : Batch loss : 0.21204878389835358
# Epoch(0/3 : Batch number(690/782) : Batch loss : 0.5340778231620789
# Epoch(0/3 : Batch number(691/782) : Batch loss : 0.3207009434700012
# Epoch(0/3 : Batch number(692/782) : Batch loss : 0.3071984052658081
# Epoch(0/3 : Batch number(693/782) : Batch loss : 0.42242300510406494
# Epoch(0/3 : Batch number(694/782) : Batch loss : 0.35647204518318176
# Epoch(0/3 : Batch number(695/782) : Batch loss : 0.5305893421173096
# Epoch(0/3 : Batch number(696/782) : Batch loss : 0.33137255907058716
# Epoch(0/3 : Batch number(697/782) : Batch loss : 0.6287023425102234
# Epoch(0/3 : Batch number(698/782) : Batch loss : 0.4208655059337616
# Epoch(0/3 : Batch number(699/782) : Batch loss : 0.5793178081512451
# Epoch(0/3 : Batch number(700/782) : Batch loss : 0.4388030171394348
# Epoch(0/3 : Batch number(701/782) : Batch loss : 0.33545342087745667
# Epoch(0/3 : Batch number(702/782) : Batch loss : 0.5074991583824158
# Epoch(0/3 : Batch number(703/782) : Batch loss : 0.39818018674850464
# Epoch(0/3 : Batch number(704/782) : Batch loss : 0.5782134532928467
# Epoch(0/3 : Batch number(705/782) : Batch loss : 0.6316839456558228
# Epoch(0/3 : Batch number(706/782) : Batch loss : 0.1834503561258316
# Epoch(0/3 : Batch number(707/782) : Batch loss : 0.5075581669807434
# Epoch(0/3 : Batch number(708/782) : Batch loss : 0.3968043923377991
# Epoch(0/3 : Batch number(709/782) : Batch loss : 0.26742810010910034
# Epoch(0/3 : Batch number(710/782) : Batch loss : 0.48120689392089844
# Epoch(0/3 : Batch number(711/782) : Batch loss : 0.5210830569267273
# Epoch(0/3 : Batch number(712/782) : Batch loss : 0.4294458329677582
# Epoch(0/3 : Batch number(713/782) : Batch loss : 0.44121354818344116
# Epoch(0/3 : Batch number(714/782) : Batch loss : 0.49293315410614014
# Epoch(0/3 : Batch number(715/782) : Batch loss : 0.6331716179847717
# Epoch(0/3 : Batch number(716/782) : Batch loss : 0.32995954155921936
# Epoch(0/3 : Batch number(717/782) : Batch loss : 0.33903270959854126
# Epoch(0/3 : Batch number(718/782) : Batch loss : 0.377643883228302
# Epoch(0/3 : Batch number(719/782) : Batch loss : 0.5391918420791626
# Epoch(0/3 : Batch number(720/782) : Batch loss : 0.325734943151474
# Epoch(0/3 : Batch number(721/782) : Batch loss : 0.302028089761734
# Epoch(0/3 : Batch number(722/782) : Batch loss : 0.4556969404220581
# Epoch(0/3 : Batch number(723/782) : Batch loss : 0.2675786018371582
# Epoch(0/3 : Batch number(724/782) : Batch loss : 0.44885876774787903
# Epoch(0/3 : Batch number(725/782) : Batch loss : 0.3467548191547394
# Epoch(0/3 : Batch number(726/782) : Batch loss : 0.28544697165489197
# Epoch(0/3 : Batch number(727/782) : Batch loss : 0.43481898307800293
# Epoch(0/3 : Batch number(728/782) : Batch loss : 0.34698325395584106
# Epoch(0/3 : Batch number(729/782) : Batch loss : 0.45234984159469604
# Epoch(0/3 : Batch number(730/782) : Batch loss : 0.39721161127090454
# Epoch(0/3 : Batch number(731/782) : Batch loss : 0.48963412642478943
# Epoch(0/3 : Batch number(732/782) : Batch loss : 0.4788733720779419
# Epoch(0/3 : Batch number(733/782) : Batch loss : 0.27838748693466187
# Epoch(0/3 : Batch number(734/782) : Batch loss : 0.3268090486526489
# Epoch(0/3 : Batch number(735/782) : Batch loss : 0.32308822870254517
# Epoch(0/3 : Batch number(736/782) : Batch loss : 0.4274361729621887
# Epoch(0/3 : Batch number(737/782) : Batch loss : 0.36951860785484314
# Epoch(0/3 : Batch number(738/782) : Batch loss : 0.40570998191833496
# Epoch(0/3 : Batch number(739/782) : Batch loss : 0.2592046856880188
# Epoch(0/3 : Batch number(740/782) : Batch loss : 0.36719298362731934
# Epoch(0/3 : Batch number(741/782) : Batch loss : 0.3314594328403473
# Epoch(0/3 : Batch number(742/782) : Batch loss : 0.33172088861465454
# Epoch(0/3 : Batch number(743/782) : Batch loss : 0.3533179759979248
# Epoch(0/3 : Batch number(744/782) : Batch loss : 0.4583899974822998
# Epoch(0/3 : Batch number(745/782) : Batch loss : 0.522960901260376
# Epoch(0/3 : Batch number(746/782) : Batch loss : 0.2845861315727234
# Epoch(0/3 : Batch number(747/782) : Batch loss : 0.3806033134460449
# Epoch(0/3 : Batch number(748/782) : Batch loss : 0.4441371560096741
# Epoch(0/3 : Batch number(749/782) : Batch loss : 0.24330320954322815
# Epoch(0/3 : Batch number(750/782) : Batch loss : 0.2720257043838501
# Epoch(0/3 : Batch number(751/782) : Batch loss : 0.3353031873703003
# Epoch(0/3 : Batch number(752/782) : Batch loss : 0.5968098640441895
# Epoch(0/3 : Batch number(753/782) : Batch loss : 0.5052903890609741
# Epoch(0/3 : Batch number(754/782) : Batch loss : 0.27137333154678345
# Epoch(0/3 : Batch number(755/782) : Batch loss : 0.30670467019081116
# Epoch(0/3 : Batch number(756/782) : Batch loss : 0.26081907749176025
# Epoch(0/3 : Batch number(757/782) : Batch loss : 0.33044135570526123
# Epoch(0/3 : Batch number(758/782) : Batch loss : 0.30723461508750916
# Epoch(0/3 : Batch number(759/782) : Batch loss : 0.3313850164413452
# Epoch(0/3 : Batch number(760/782) : Batch loss : 0.38401904702186584
# Epoch(0/3 : Batch number(761/782) : Batch loss : 0.38861221075057983
# Epoch(0/3 : Batch number(762/782) : Batch loss : 0.5213159918785095
# Epoch(0/3 : Batch number(763/782) : Batch loss : 0.576446533203125
# Epoch(0/3 : Batch number(764/782) : Batch loss : 0.2848092317581177
# Epoch(0/3 : Batch number(765/782) : Batch loss : 0.5496551990509033
# Epoch(0/3 : Batch number(766/782) : Batch loss : 0.4277227520942688
# Epoch(0/3 : Batch number(767/782) : Batch loss : 0.5424360036849976
# Epoch(0/3 : Batch number(768/782) : Batch loss : 0.4376385509967804
# Epoch(0/3 : Batch number(769/782) : Batch loss : 0.24879756569862366
# Epoch(0/3 : Batch number(770/782) : Batch loss : 0.36036616563796997
# Epoch(0/3 : Batch number(771/782) : Batch loss : 0.4405357539653778
# Epoch(0/3 : Batch number(772/782) : Batch loss : 0.3917139768600464
# Epoch(0/3 : Batch number(773/782) : Batch loss : 0.5193890929222107
# Epoch(0/3 : Batch number(774/782) : Batch loss : 0.3304099142551422
# Epoch(0/3 : Batch number(775/782) : Batch loss : 0.39767611026763916
# Epoch(0/3 : Batch number(776/782) : Batch loss : 0.45327627658843994
# Epoch(0/3 : Batch number(777/782) : Batch loss : 0.32776838541030884
# Epoch(0/3 : Batch number(778/782) : Batch loss : 0.271533340215683
# Epoch(0/3 : Batch number(779/782) : Batch loss : 0.4705467224121094
# Epoch(0/3 : Batch number(780/782) : Batch loss : 0.5808207988739014
# Epoch(0/3 : Batch number(781/782) : Batch loss : 0.42756539583206177
# Epoch(0/3 : Batch number(782/782) : Batch loss : 0.6118879318237305
# Training loss : 0.44474372463991574
# Epoch(1/3 : Batch number(1/782) : Batch loss : 0.25906041264533997
# Epoch(1/3 : Batch number(2/782) : Batch loss : 0.3271121382713318
# Epoch(1/3 : Batch number(3/782) : Batch loss : 0.32419320940971375
# Epoch(1/3 : Batch number(4/782) : Batch loss : 0.3598174750804901
# Epoch(1/3 : Batch number(5/782) : Batch loss : 0.3791603446006775
# Epoch(1/3 : Batch number(6/782) : Batch loss : 0.2790472209453583
# Epoch(1/3 : Batch number(7/782) : Batch loss : 0.5106220245361328
# Epoch(1/3 : Batch number(8/782) : Batch loss : 0.2738282084465027
# Epoch(1/3 : Batch number(9/782) : Batch loss : 0.4464683532714844
# Epoch(1/3 : Batch number(10/782) : Batch loss : 0.5497719645500183
# Epoch(1/3 : Batch number(11/782) : Batch loss : 0.21146222949028015
# Epoch(1/3 : Batch number(12/782) : Batch loss : 0.2614462077617645
# Epoch(1/3 : Batch number(13/782) : Batch loss : 0.5170100331306458
# Epoch(1/3 : Batch number(14/782) : Batch loss : 0.31758248805999756
# Epoch(1/3 : Batch number(15/782) : Batch loss : 0.275518536567688
# Epoch(1/3 : Batch number(16/782) : Batch loss : 0.285844624042511
# Epoch(1/3 : Batch number(17/782) : Batch loss : 0.5765017867088318
# Epoch(1/3 : Batch number(18/782) : Batch loss : 0.506940484046936
# Epoch(1/3 : Batch number(19/782) : Batch loss : 0.29654955863952637
# Epoch(1/3 : Batch number(20/782) : Batch loss : 0.4150630533695221
# Epoch(1/3 : Batch number(21/782) : Batch loss : 0.17730483412742615
# Epoch(1/3 : Batch number(22/782) : Batch loss : 0.48171254992485046
# Epoch(1/3 : Batch number(23/782) : Batch loss : 0.3577096164226532
# Epoch(1/3 : Batch number(24/782) : Batch loss : 0.28419432044029236
# Epoch(1/3 : Batch number(25/782) : Batch loss : 0.3157320022583008
# Epoch(1/3 : Batch number(26/782) : Batch loss : 0.3700181543827057
# Epoch(1/3 : Batch number(27/782) : Batch loss : 0.5458055734634399
# Epoch(1/3 : Batch number(28/782) : Batch loss : 0.24394986033439636
# Epoch(1/3 : Batch number(29/782) : Batch loss : 0.30691292881965637
# Epoch(1/3 : Batch number(30/782) : Batch loss : 0.31654244661331177
# Epoch(1/3 : Batch number(31/782) : Batch loss : 0.3521632254123688
# Epoch(1/3 : Batch number(32/782) : Batch loss : 0.2263440042734146
# Epoch(1/3 : Batch number(33/782) : Batch loss : 0.3752736449241638
# Epoch(1/3 : Batch number(34/782) : Batch loss : 0.32264599204063416
# Epoch(1/3 : Batch number(35/782) : Batch loss : 0.734848141670227
# Epoch(1/3 : Batch number(36/782) : Batch loss : 0.5360894799232483
# Epoch(1/3 : Batch number(37/782) : Batch loss : 0.3350791037082672
# Epoch(1/3 : Batch number(38/782) : Batch loss : 0.4658470153808594
# Epoch(1/3 : Batch number(39/782) : Batch loss : 0.3767908215522766
# Epoch(1/3 : Batch number(40/782) : Batch loss : 0.4245753586292267
# Epoch(1/3 : Batch number(41/782) : Batch loss : 0.3550676107406616
# Epoch(1/3 : Batch number(42/782) : Batch loss : 0.40202075242996216
# Epoch(1/3 : Batch number(43/782) : Batch loss : 0.1913928985595703
# Epoch(1/3 : Batch number(44/782) : Batch loss : 0.43478286266326904
# Epoch(1/3 : Batch number(45/782) : Batch loss : 0.24518242478370667
# Epoch(1/3 : Batch number(46/782) : Batch loss : 0.23140200972557068
# Epoch(1/3 : Batch number(47/782) : Batch loss : 0.4686828553676605
# Epoch(1/3 : Batch number(48/782) : Batch loss : 0.27695634961128235
# Epoch(1/3 : Batch number(49/782) : Batch loss : 0.37016236782073975
# Epoch(1/3 : Batch number(50/782) : Batch loss : 0.25841638445854187
# Epoch(1/3 : Batch number(51/782) : Batch loss : 0.4025401473045349
# Epoch(1/3 : Batch number(52/782) : Batch loss : 0.36039185523986816
# Epoch(1/3 : Batch number(53/782) : Batch loss : 0.2864811420440674
# Epoch(1/3 : Batch number(54/782) : Batch loss : 0.3761817216873169
# Epoch(1/3 : Batch number(55/782) : Batch loss : 0.16868317127227783
# Epoch(1/3 : Batch number(56/782) : Batch loss : 0.13137638568878174
# Epoch(1/3 : Batch number(57/782) : Batch loss : 0.27402833104133606
# Epoch(1/3 : Batch number(58/782) : Batch loss : 0.36912959814071655
# Epoch(1/3 : Batch number(59/782) : Batch loss : 0.34937700629234314
# Epoch(1/3 : Batch number(60/782) : Batch loss : 0.43512409925460815
# Epoch(1/3 : Batch number(61/782) : Batch loss : 0.5489751100540161
# Epoch(1/3 : Batch number(62/782) : Batch loss : 0.35155364871025085
# Epoch(1/3 : Batch number(63/782) : Batch loss : 0.403116375207901
# Epoch(1/3 : Batch number(64/782) : Batch loss : 0.30668413639068604
# Epoch(1/3 : Batch number(65/782) : Batch loss : 0.46517062187194824
# Epoch(1/3 : Batch number(66/782) : Batch loss : 0.37298548221588135
# Epoch(1/3 : Batch number(67/782) : Batch loss : 0.22231659293174744
# Epoch(1/3 : Batch number(68/782) : Batch loss : 0.29364538192749023
# Epoch(1/3 : Batch number(69/782) : Batch loss : 0.5601505637168884
# Epoch(1/3 : Batch number(70/782) : Batch loss : 0.2950424551963806
# Epoch(1/3 : Batch number(71/782) : Batch loss : 0.3602341413497925
# Epoch(1/3 : Batch number(72/782) : Batch loss : 0.5828072428703308
# Epoch(1/3 : Batch number(73/782) : Batch loss : 0.44161340594291687
# Epoch(1/3 : Batch number(74/782) : Batch loss : 0.2402193546295166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9acf8f5d0c57> in <module>()
#      19     optimizer.step()
#      20
# ---> 21     batch_loss += loss.item()
#      22     print(f'Epoch({e}/{num_epochs} : Batch number({batch}/{len(trainloader)}) : Batch loss : {loss.item()}')
#      23
#
# KeyboardInterrupt:

# %% [markdown]
# ### The accuracy of the model

# %%
model.to('cpu')

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0

    #set_trace()
    for batch, (images, labels) in enumerate(testloader,1):
        
        logps = model(images)
        output = torch.exp(logps)
        
        pred = torch.argmax(output, 1)
        total += labels.size(0)
        num_correct += (pred == labels).sum().item()
        print(f'Batch ({batch}/{len(testloader)})')
        
        if batch == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 82.8125%

# %% [markdown]
# ## Un-freezing & training on the LAST TWO CNN block onwards

# %% [markdown]
# ### Re-training the model

# %%
for i in range(17,24):
  model.features[i].requires_grad = True

# %%
from torch.optim import Adam

lr = 3e-4
optimizer = Adam([
    { 'params': model.features[17].parameters(), 'lr': lr},
    { 'params': model.features[19].parameters(), 'lr': lr},
    { 'params': model.features[21].parameters(), 'lr': lr},
    { 'params': model.features[24].parameters(), 'lr': lr},
    { 'params': model.features[26].parameters(), 'lr': lr},
    { 'params': model.features[28].parameters(), 'lr': lr},
    { 'params': model.classifier[0].parameters(), 'lr': lr},
    { 'params': model.classifier[3].parameters(), 'lr': lr},
    { 'params': model.classifier[6].parameters(), 'lr': lr}
    ], lr=lr)

# %%
model = model.to(device)
#optimizer = Adam(filter(lambda p: p.requires_grad, model.parameters()))

num_epochs = 1
batch_loss = 0
cum_epoch_loss = 0

for e in range(num_epochs):
  cum_epoch_loss = 0
  
  for batch, (images, labels) in enumerate(trainloader,1):
    images = images.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()
    logps = model(images)
    loss = criterion(logps, labels)
    loss.backward()
    optimizer.step()
    
    batch_loss += loss.item()
    print(f'Epoch({e}/{num_epochs} : Batch number({batch}/{len(trainloader)}) : Batch loss : {loss.item()}')
    
  print(f'Training loss : {batch_loss/len(trainloader)}')
# Out:
# Epoch(0/1 : Batch number(1/782) : Batch loss : 0.3778439164161682
# Epoch(0/1 : Batch number(2/782) : Batch loss : 0.23955854773521423
# Epoch(0/1 : Batch number(3/782) : Batch loss : 0.5916640758514404
# Epoch(0/1 : Batch number(4/782) : Batch loss : 0.3050242066383362
# Epoch(0/1 : Batch number(5/782) : Batch loss : 0.5073587894439697
# Epoch(0/1 : Batch number(6/782) : Batch loss : 0.28958654403686523
# Epoch(0/1 : Batch number(7/782) : Batch loss : 0.4297773838043213
# Epoch(0/1 : Batch number(8/782) : Batch loss : 0.24711520969867706
# Epoch(0/1 : Batch number(9/782) : Batch loss : 0.3713686764240265
# Epoch(0/1 : Batch number(10/782) : Batch loss : 0.3815925121307373
# Epoch(0/1 : Batch number(11/782) : Batch loss : 0.38709938526153564
# Epoch(0/1 : Batch number(12/782) : Batch loss : 0.4454638659954071
# Epoch(0/1 : Batch number(13/782) : Batch loss : 0.357410728931427
# Epoch(0/1 : Batch number(14/782) : Batch loss : 0.43848666548728943
# Epoch(0/1 : Batch number(15/782) : Batch loss : 0.31920498609542847
# Epoch(0/1 : Batch number(16/782) : Batch loss : 0.3150846064090729
# Epoch(0/1 : Batch number(17/782) : Batch loss : 0.3722075819969177
# Epoch(0/1 : Batch number(18/782) : Batch loss : 0.35717105865478516
# Epoch(0/1 : Batch number(19/782) : Batch loss : 0.37771326303482056
# Epoch(0/1 : Batch number(20/782) : Batch loss : 0.3143810033798218
# Epoch(0/1 : Batch number(21/782) : Batch loss : 0.2916056513786316
# Epoch(0/1 : Batch number(22/782) : Batch loss : 0.2992974519729614
# Epoch(0/1 : Batch number(23/782) : Batch loss : 0.45708632469177246
# Epoch(0/1 : Batch number(24/782) : Batch loss : 0.30697429180145264
# Epoch(0/1 : Batch number(25/782) : Batch loss : 0.24535192549228668
# Epoch(0/1 : Batch number(26/782) : Batch loss : 0.3395637273788452
# Epoch(0/1 : Batch number(27/782) : Batch loss : 0.29581478238105774
# Epoch(0/1 : Batch number(28/782) : Batch loss : 0.40422046184539795
# Epoch(0/1 : Batch number(29/782) : Batch loss : 0.15774372220039368
# Epoch(0/1 : Batch number(30/782) : Batch loss : 0.37623631954193115
# Epoch(0/1 : Batch number(31/782) : Batch loss : 0.3870336711406708
# Epoch(0/1 : Batch number(32/782) : Batch loss : 0.264224112033844
# Epoch(0/1 : Batch number(33/782) : Batch loss : 0.3115506172180176
# Epoch(0/1 : Batch number(34/782) : Batch loss : 0.44349366426467896
# Epoch(0/1 : Batch number(35/782) : Batch loss : 0.2738229036331177
# Epoch(0/1 : Batch number(36/782) : Batch loss : 0.42445507645606995
# Epoch(0/1 : Batch number(37/782) : Batch loss : 0.4084452986717224
# Epoch(0/1 : Batch number(38/782) : Batch loss : 0.44671738147735596
# Epoch(0/1 : Batch number(39/782) : Batch loss : 0.47266697883605957
# Epoch(0/1 : Batch number(40/782) : Batch loss : 0.4453125298023224
# Epoch(0/1 : Batch number(41/782) : Batch loss : 0.40723368525505066
# Epoch(0/1 : Batch number(42/782) : Batch loss : 0.28849297761917114
# Epoch(0/1 : Batch number(43/782) : Batch loss : 0.31960588693618774
# Epoch(0/1 : Batch number(44/782) : Batch loss : 0.4835665822029114
# Epoch(0/1 : Batch number(45/782) : Batch loss : 0.30193373560905457
# Epoch(0/1 : Batch number(46/782) : Batch loss : 0.4728469252586365
# Epoch(0/1 : Batch number(47/782) : Batch loss : 0.2857951521873474
# Epoch(0/1 : Batch number(48/782) : Batch loss : 0.3157083988189697
# Epoch(0/1 : Batch number(49/782) : Batch loss : 0.33503738045692444
# Epoch(0/1 : Batch number(50/782) : Batch loss : 0.2137145698070526
# Epoch(0/1 : Batch number(51/782) : Batch loss : 0.2216411530971527
# Epoch(0/1 : Batch number(52/782) : Batch loss : 0.5584150552749634
# Epoch(0/1 : Batch number(53/782) : Batch loss : 0.18647095561027527
# Epoch(0/1 : Batch number(54/782) : Batch loss : 0.301054447889328
# Epoch(0/1 : Batch number(55/782) : Batch loss : 0.2988506257534027
# Epoch(0/1 : Batch number(56/782) : Batch loss : 0.31117767095565796
# Epoch(0/1 : Batch number(57/782) : Batch loss : 0.40593603253364563
# Epoch(0/1 : Batch number(58/782) : Batch loss : 0.4131806790828705
# Epoch(0/1 : Batch number(59/782) : Batch loss : 0.2897203862667084
# Epoch(0/1 : Batch number(60/782) : Batch loss : 0.2506657838821411
# Epoch(0/1 : Batch number(61/782) : Batch loss : 0.5922684669494629
# Epoch(0/1 : Batch number(62/782) : Batch loss : 0.2523345649242401
# Epoch(0/1 : Batch number(63/782) : Batch loss : 0.2739883065223694
# Epoch(0/1 : Batch number(64/782) : Batch loss : 0.45416098833084106
# Epoch(0/1 : Batch number(65/782) : Batch loss : 0.17325693368911743
# Epoch(0/1 : Batch number(66/782) : Batch loss : 0.2962528467178345
# Epoch(0/1 : Batch number(67/782) : Batch loss : 0.4961085021495819
# Epoch(0/1 : Batch number(68/782) : Batch loss : 0.28749823570251465
# Epoch(0/1 : Batch number(69/782) : Batch loss : 0.2101304829120636
# Epoch(0/1 : Batch number(70/782) : Batch loss : 0.26307615637779236
# Epoch(0/1 : Batch number(71/782) : Batch loss : 0.29935508966445923
# Epoch(0/1 : Batch number(72/782) : Batch loss : 0.3599926829338074
# Epoch(0/1 : Batch number(73/782) : Batch loss : 0.28085729479789734
# Epoch(0/1 : Batch number(74/782) : Batch loss : 0.27772343158721924
# Epoch(0/1 : Batch number(75/782) : Batch loss : 0.2947458028793335
# Epoch(0/1 : Batch number(76/782) : Batch loss : 0.2784973680973053
# Epoch(0/1 : Batch number(77/782) : Batch loss : 0.37070465087890625
# Epoch(0/1 : Batch number(78/782) : Batch loss : 0.44113418459892273
# Epoch(0/1 : Batch number(79/782) : Batch loss : 0.316018670797348
# Epoch(0/1 : Batch number(80/782) : Batch loss : 0.42439720034599304
# Epoch(0/1 : Batch number(81/782) : Batch loss : 0.28222793340682983
# Epoch(0/1 : Batch number(82/782) : Batch loss : 0.4053392708301544
# Epoch(0/1 : Batch number(83/782) : Batch loss : 0.2815830111503601
# Epoch(0/1 : Batch number(84/782) : Batch loss : 0.4502159357070923
# Epoch(0/1 : Batch number(85/782) : Batch loss : 0.19661036133766174
# Epoch(0/1 : Batch number(86/782) : Batch loss : 0.36835718154907227
# Epoch(0/1 : Batch number(87/782) : Batch loss : 0.3431152105331421
# Epoch(0/1 : Batch number(88/782) : Batch loss : 0.41296640038490295
# Epoch(0/1 : Batch number(89/782) : Batch loss : 0.3465956449508667
# Epoch(0/1 : Batch number(90/782) : Batch loss : 0.34379997849464417
# Epoch(0/1 : Batch number(91/782) : Batch loss : 0.2340444177389145
# Epoch(0/1 : Batch number(92/782) : Batch loss : 0.3633703589439392
# Epoch(0/1 : Batch number(93/782) : Batch loss : 0.3426066040992737
# Epoch(0/1 : Batch number(94/782) : Batch loss : 0.28933650255203247
# Epoch(0/1 : Batch number(95/782) : Batch loss : 0.48110687732696533
# Epoch(0/1 : Batch number(96/782) : Batch loss : 0.33221936225891113
# Epoch(0/1 : Batch number(97/782) : Batch loss : 0.42696496844291687
# Epoch(0/1 : Batch number(98/782) : Batch loss : 0.3984970450401306
# Epoch(0/1 : Batch number(99/782) : Batch loss : 0.3133910596370697
# Epoch(0/1 : Batch number(100/782) : Batch loss : 0.3661514222621918
# Epoch(0/1 : Batch number(101/782) : Batch loss : 0.5281319618225098
# Epoch(0/1 : Batch number(102/782) : Batch loss : 0.40927213430404663
# Epoch(0/1 : Batch number(103/782) : Batch loss : 0.5016480684280396
# Epoch(0/1 : Batch number(104/782) : Batch loss : 0.3720044791698456
# Epoch(0/1 : Batch number(105/782) : Batch loss : 0.4122743308544159
# Epoch(0/1 : Batch number(106/782) : Batch loss : 0.18942126631736755
# Epoch(0/1 : Batch number(107/782) : Batch loss : 0.2360384166240692
# Epoch(0/1 : Batch number(108/782) : Batch loss : 0.4019956588745117
# Epoch(0/1 : Batch number(109/782) : Batch loss : 0.4471890926361084
# Epoch(0/1 : Batch number(110/782) : Batch loss : 0.4114871025085449
# Epoch(0/1 : Batch number(111/782) : Batch loss : 0.25513455271720886
# Epoch(0/1 : Batch number(112/782) : Batch loss : 0.3128109574317932
# Epoch(0/1 : Batch number(113/782) : Batch loss : 0.4521928131580353
# Epoch(0/1 : Batch number(114/782) : Batch loss : 0.22139355540275574
# Epoch(0/1 : Batch number(115/782) : Batch loss : 0.2533245384693146
# Epoch(0/1 : Batch number(116/782) : Batch loss : 0.2620590925216675
# Epoch(0/1 : Batch number(117/782) : Batch loss : 0.16941754519939423
# Epoch(0/1 : Batch number(118/782) : Batch loss : 0.5114439725875854
# Epoch(0/1 : Batch number(119/782) : Batch loss : 0.26460111141204834
# Epoch(0/1 : Batch number(120/782) : Batch loss : 0.2750539481639862
# Epoch(0/1 : Batch number(121/782) : Batch loss : 0.5209000110626221
# Epoch(0/1 : Batch number(122/782) : Batch loss : 0.4632151126861572
# Epoch(0/1 : Batch number(123/782) : Batch loss : 0.3382583260536194
# Epoch(0/1 : Batch number(124/782) : Batch loss : 0.3225967288017273
# Epoch(0/1 : Batch number(125/782) : Batch loss : 0.23460736870765686
# Epoch(0/1 : Batch number(126/782) : Batch loss : 0.5323557257652283
# Epoch(0/1 : Batch number(127/782) : Batch loss : 0.5403836965560913
# Epoch(0/1 : Batch number(128/782) : Batch loss : 0.34897345304489136
# Epoch(0/1 : Batch number(129/782) : Batch loss : 0.3042830228805542
# Epoch(0/1 : Batch number(130/782) : Batch loss : 0.338049054145813
# Epoch(0/1 : Batch number(131/782) : Batch loss : 0.5157342553138733
# Epoch(0/1 : Batch number(132/782) : Batch loss : 0.2369363009929657
# Epoch(0/1 : Batch number(133/782) : Batch loss : 0.30191197991371155
# Epoch(0/1 : Batch number(134/782) : Batch loss : 0.33218568563461304
# Epoch(0/1 : Batch number(135/782) : Batch loss : 0.41110944747924805
# Epoch(0/1 : Batch number(136/782) : Batch loss : 0.34669578075408936
# Epoch(0/1 : Batch number(137/782) : Batch loss : 0.39936548471450806
# Epoch(0/1 : Batch number(138/782) : Batch loss : 0.26075345277786255
# Epoch(0/1 : Batch number(139/782) : Batch loss : 0.20948652923107147
# Epoch(0/1 : Batch number(140/782) : Batch loss : 0.1804167479276657
# Epoch(0/1 : Batch number(141/782) : Batch loss : 0.4175921380519867
# Epoch(0/1 : Batch number(142/782) : Batch loss : 0.39088594913482666
# Epoch(0/1 : Batch number(143/782) : Batch loss : 0.5669875144958496
# Epoch(0/1 : Batch number(144/782) : Batch loss : 0.5172985792160034
# Epoch(0/1 : Batch number(145/782) : Batch loss : 0.24240627884864807
# Epoch(0/1 : Batch number(146/782) : Batch loss : 0.4876744747161865
# Epoch(0/1 : Batch number(147/782) : Batch loss : 0.5163865685462952
# Epoch(0/1 : Batch number(148/782) : Batch loss : 0.4146885871887207
# Epoch(0/1 : Batch number(149/782) : Batch loss : 0.24616748094558716
# Epoch(0/1 : Batch number(150/782) : Batch loss : 0.4386778473854065
# Epoch(0/1 : Batch number(151/782) : Batch loss : 0.3843430280685425
# Epoch(0/1 : Batch number(152/782) : Batch loss : 0.31428271532058716
# Epoch(0/1 : Batch number(153/782) : Batch loss : 0.4655719995498657
# Epoch(0/1 : Batch number(154/782) : Batch loss : 0.2565608620643616
# Epoch(0/1 : Batch number(155/782) : Batch loss : 0.2418397068977356
# Epoch(0/1 : Batch number(156/782) : Batch loss : 0.31520751118659973
# Epoch(0/1 : Batch number(157/782) : Batch loss : 0.3605414628982544
# Epoch(0/1 : Batch number(158/782) : Batch loss : 0.5166680812835693
# Epoch(0/1 : Batch number(159/782) : Batch loss : 0.31247425079345703
# Epoch(0/1 : Batch number(160/782) : Batch loss : 0.2677518129348755
# Epoch(0/1 : Batch number(161/782) : Batch loss : 0.49111422896385193
# Epoch(0/1 : Batch number(162/782) : Batch loss : 0.22733333706855774
# Epoch(0/1 : Batch number(163/782) : Batch loss : 0.22470805048942566
# Epoch(0/1 : Batch number(164/782) : Batch loss : 0.30978459119796753
# Epoch(0/1 : Batch number(165/782) : Batch loss : 0.3756478428840637
# Epoch(0/1 : Batch number(166/782) : Batch loss : 0.271550714969635
# Epoch(0/1 : Batch number(167/782) : Batch loss : 0.19098135828971863
# Epoch(0/1 : Batch number(168/782) : Batch loss : 0.36407631635665894
# Epoch(0/1 : Batch number(169/782) : Batch loss : 0.4458214342594147
# Epoch(0/1 : Batch number(170/782) : Batch loss : 0.28646862506866455
# Epoch(0/1 : Batch number(171/782) : Batch loss : 0.32285118103027344
# Epoch(0/1 : Batch number(172/782) : Batch loss : 0.27565255761146545
# Epoch(0/1 : Batch number(173/782) : Batch loss : 0.33574092388153076
# Epoch(0/1 : Batch number(174/782) : Batch loss : 0.37471240758895874
# Epoch(0/1 : Batch number(175/782) : Batch loss : 0.3316952586174011
# Epoch(0/1 : Batch number(176/782) : Batch loss : 0.46765798330307007
# Epoch(0/1 : Batch number(177/782) : Batch loss : 0.4372902810573578
# Epoch(0/1 : Batch number(178/782) : Batch loss : 0.267184317111969
# Epoch(0/1 : Batch number(179/782) : Batch loss : 0.28856828808784485
# Epoch(0/1 : Batch number(180/782) : Batch loss : 0.17076779901981354
# Epoch(0/1 : Batch number(181/782) : Batch loss : 0.30146533250808716
# Epoch(0/1 : Batch number(182/782) : Batch loss : 0.31030675768852234
# Epoch(0/1 : Batch number(183/782) : Batch loss : 0.32655006647109985
# Epoch(0/1 : Batch number(184/782) : Batch loss : 0.43599438667297363
# Epoch(0/1 : Batch number(185/782) : Batch loss : 0.3319714069366455
# Epoch(0/1 : Batch number(186/782) : Batch loss : 0.3510870635509491
# Epoch(0/1 : Batch number(187/782) : Batch loss : 0.535941481590271
# Epoch(0/1 : Batch number(188/782) : Batch loss : 0.23321399092674255
# Epoch(0/1 : Batch number(189/782) : Batch loss : 0.5456186532974243
# Epoch(0/1 : Batch number(190/782) : Batch loss : 0.4976031184196472
# Epoch(0/1 : Batch number(191/782) : Batch loss : 0.3001241981983185
# Epoch(0/1 : Batch number(192/782) : Batch loss : 0.3161131739616394
# Epoch(0/1 : Batch number(193/782) : Batch loss : 0.2112198770046234
# Epoch(0/1 : Batch number(194/782) : Batch loss : 0.4794386327266693
# Epoch(0/1 : Batch number(195/782) : Batch loss : 0.3928278386592865
# Epoch(0/1 : Batch number(196/782) : Batch loss : 0.5004348158836365
# Epoch(0/1 : Batch number(197/782) : Batch loss : 0.5098145008087158
# Epoch(0/1 : Batch number(198/782) : Batch loss : 0.32695215940475464
# Epoch(0/1 : Batch number(199/782) : Batch loss : 0.3502248525619507
# Epoch(0/1 : Batch number(200/782) : Batch loss : 0.3696751594543457
# Epoch(0/1 : Batch number(201/782) : Batch loss : 0.4351509213447571
# Epoch(0/1 : Batch number(202/782) : Batch loss : 0.42456290125846863
# Epoch(0/1 : Batch number(203/782) : Batch loss : 0.25544512271881104
# Epoch(0/1 : Batch number(204/782) : Batch loss : 0.28589674830436707
# Epoch(0/1 : Batch number(205/782) : Batch loss : 0.4589952528476715
# Epoch(0/1 : Batch number(206/782) : Batch loss : 0.37603577971458435
# Epoch(0/1 : Batch number(207/782) : Batch loss : 0.31090185046195984
# Epoch(0/1 : Batch number(208/782) : Batch loss : 0.19414855539798737
# Epoch(0/1 : Batch number(209/782) : Batch loss : 0.36658579111099243
# Epoch(0/1 : Batch number(210/782) : Batch loss : 0.35779109597206116
# Epoch(0/1 : Batch number(211/782) : Batch loss : 0.3852688670158386
# Epoch(0/1 : Batch number(212/782) : Batch loss : 0.3298499286174774
# Epoch(0/1 : Batch number(213/782) : Batch loss : 0.32849356532096863
# Epoch(0/1 : Batch number(214/782) : Batch loss : 0.436346173286438
# Epoch(0/1 : Batch number(215/782) : Batch loss : 0.41177064180374146
# Epoch(0/1 : Batch number(216/782) : Batch loss : 0.34287625551223755
# Epoch(0/1 : Batch number(217/782) : Batch loss : 0.29115432500839233
# Epoch(0/1 : Batch number(218/782) : Batch loss : 0.39492353796958923
# Epoch(0/1 : Batch number(219/782) : Batch loss : 0.29127687215805054
# Epoch(0/1 : Batch number(220/782) : Batch loss : 0.3180534839630127
# Epoch(0/1 : Batch number(221/782) : Batch loss : 0.2685892879962921
# Epoch(0/1 : Batch number(222/782) : Batch loss : 0.49309879541397095
# Epoch(0/1 : Batch number(223/782) : Batch loss : 0.34692642092704773
# Epoch(0/1 : Batch number(224/782) : Batch loss : 0.2712024450302124
# Epoch(0/1 : Batch number(225/782) : Batch loss : 0.5405486226081848
# Epoch(0/1 : Batch number(226/782) : Batch loss : 0.26585158705711365
# Epoch(0/1 : Batch number(227/782) : Batch loss : 0.41014397144317627
# Epoch(0/1 : Batch number(228/782) : Batch loss : 0.39299026131629944
# Epoch(0/1 : Batch number(229/782) : Batch loss : 0.2795337438583374
# Epoch(0/1 : Batch number(230/782) : Batch loss : 0.35242241621017456
# Epoch(0/1 : Batch number(231/782) : Batch loss : 0.3482986092567444
# Epoch(0/1 : Batch number(232/782) : Batch loss : 0.285395085811615
# Epoch(0/1 : Batch number(233/782) : Batch loss : 0.270068883895874
# Epoch(0/1 : Batch number(234/782) : Batch loss : 0.4550313651561737
# Epoch(0/1 : Batch number(235/782) : Batch loss : 0.42809346318244934
# Epoch(0/1 : Batch number(236/782) : Batch loss : 0.2987920939922333
# Epoch(0/1 : Batch number(237/782) : Batch loss : 0.4488605856895447
# Epoch(0/1 : Batch number(238/782) : Batch loss : 0.2822430729866028
# Epoch(0/1 : Batch number(239/782) : Batch loss : 0.4499259889125824
# Epoch(0/1 : Batch number(240/782) : Batch loss : 0.37145715951919556
# Epoch(0/1 : Batch number(241/782) : Batch loss : 0.4667273163795471
# Epoch(0/1 : Batch number(242/782) : Batch loss : 0.2951200604438782
# Epoch(0/1 : Batch number(243/782) : Batch loss : 0.5320839881896973
# Epoch(0/1 : Batch number(244/782) : Batch loss : 0.26148396730422974
# Epoch(0/1 : Batch number(245/782) : Batch loss : 0.29177865386009216
# Epoch(0/1 : Batch number(246/782) : Batch loss : 0.25747495889663696
# Epoch(0/1 : Batch number(247/782) : Batch loss : 0.206586554646492
# Epoch(0/1 : Batch number(248/782) : Batch loss : 0.21402472257614136
# Epoch(0/1 : Batch number(249/782) : Batch loss : 0.2672845423221588
# Epoch(0/1 : Batch number(250/782) : Batch loss : 0.3526463508605957
# Epoch(0/1 : Batch number(251/782) : Batch loss : 0.3239871561527252
# Epoch(0/1 : Batch number(252/782) : Batch loss : 0.18987134099006653
# Epoch(0/1 : Batch number(253/782) : Batch loss : 0.35621851682662964
# Epoch(0/1 : Batch number(254/782) : Batch loss : 0.26783373951911926
# Epoch(0/1 : Batch number(255/782) : Batch loss : 0.28035521507263184
# Epoch(0/1 : Batch number(256/782) : Batch loss : 0.32300516963005066
# Epoch(0/1 : Batch number(257/782) : Batch loss : 0.2818813920021057
# Epoch(0/1 : Batch number(258/782) : Batch loss : 0.39247632026672363
# Epoch(0/1 : Batch number(259/782) : Batch loss : 0.20491208136081696
# Epoch(0/1 : Batch number(260/782) : Batch loss : 0.3400443196296692
# Epoch(0/1 : Batch number(261/782) : Batch loss : 0.2946692705154419
# Epoch(0/1 : Batch number(262/782) : Batch loss : 0.3257560729980469
# Epoch(0/1 : Batch number(263/782) : Batch loss : 0.30956417322158813
# Epoch(0/1 : Batch number(264/782) : Batch loss : 0.3521553575992584
# Epoch(0/1 : Batch number(265/782) : Batch loss : 0.22109833359718323
# Epoch(0/1 : Batch number(266/782) : Batch loss : 0.2676359713077545
# Epoch(0/1 : Batch number(267/782) : Batch loss : 0.38256171345710754
# Epoch(0/1 : Batch number(268/782) : Batch loss : 0.3752424418926239
# Epoch(0/1 : Batch number(269/782) : Batch loss : 0.3041447103023529
# Epoch(0/1 : Batch number(270/782) : Batch loss : 0.27250635623931885
# Epoch(0/1 : Batch number(271/782) : Batch loss : 0.3180024027824402
# Epoch(0/1 : Batch number(272/782) : Batch loss : 0.3384619355201721
# Epoch(0/1 : Batch number(273/782) : Batch loss : 0.32860878109931946
# Epoch(0/1 : Batch number(274/782) : Batch loss : 0.5658243894577026
# Epoch(0/1 : Batch number(275/782) : Batch loss : 0.39706990122795105
# Epoch(0/1 : Batch number(276/782) : Batch loss : 0.3459206223487854
# Epoch(0/1 : Batch number(277/782) : Batch loss : 0.3821030259132385
# Epoch(0/1 : Batch number(278/782) : Batch loss : 0.4127090573310852
# Epoch(0/1 : Batch number(279/782) : Batch loss : 0.18546342849731445
# Epoch(0/1 : Batch number(280/782) : Batch loss : 0.26466935873031616
# Epoch(0/1 : Batch number(281/782) : Batch loss : 0.3521343469619751
# Epoch(0/1 : Batch number(282/782) : Batch loss : 0.6314752697944641
# Epoch(0/1 : Batch number(283/782) : Batch loss : 0.3167778551578522
# Epoch(0/1 : Batch number(284/782) : Batch loss : 0.13438597321510315
# Epoch(0/1 : Batch number(285/782) : Batch loss : 0.3051827847957611
# Epoch(0/1 : Batch number(286/782) : Batch loss : 0.24365296959877014
# Epoch(0/1 : Batch number(287/782) : Batch loss : 0.43708276748657227
# Epoch(0/1 : Batch number(288/782) : Batch loss : 0.48464685678482056
# Epoch(0/1 : Batch number(289/782) : Batch loss : 0.3219953179359436
# Epoch(0/1 : Batch number(290/782) : Batch loss : 0.3935756981372833
# Epoch(0/1 : Batch number(291/782) : Batch loss : 0.5061701536178589
# Epoch(0/1 : Batch number(292/782) : Batch loss : 0.33032143115997314
# Epoch(0/1 : Batch number(293/782) : Batch loss : 0.24894241988658905
# Epoch(0/1 : Batch number(294/782) : Batch loss : 0.24984166026115417
# Epoch(0/1 : Batch number(295/782) : Batch loss : 0.6046278476715088
# Epoch(0/1 : Batch number(296/782) : Batch loss : 0.3637565076351166
# Epoch(0/1 : Batch number(297/782) : Batch loss : 0.4560893774032593
# Epoch(0/1 : Batch number(298/782) : Batch loss : 0.4966861605644226
# Epoch(0/1 : Batch number(299/782) : Batch loss : 0.2719379663467407
# Epoch(0/1 : Batch number(300/782) : Batch loss : 0.2489023506641388
# Epoch(0/1 : Batch number(301/782) : Batch loss : 0.2472575604915619
# Epoch(0/1 : Batch number(302/782) : Batch loss : 0.38190606236457825
# Epoch(0/1 : Batch number(303/782) : Batch loss : 0.2380593717098236
# Epoch(0/1 : Batch number(304/782) : Batch loss : 0.4298669695854187
# Epoch(0/1 : Batch number(305/782) : Batch loss : 0.4357447028160095
# Epoch(0/1 : Batch number(306/782) : Batch loss : 0.3900054395198822
# Epoch(0/1 : Batch number(307/782) : Batch loss : 0.2840844392776489
# Epoch(0/1 : Batch number(308/782) : Batch loss : 0.2998051941394806
# Epoch(0/1 : Batch number(309/782) : Batch loss : 0.27320078015327454
# Epoch(0/1 : Batch number(310/782) : Batch loss : 0.2727484703063965
# Epoch(0/1 : Batch number(311/782) : Batch loss : 0.3567342162132263
# Epoch(0/1 : Batch number(312/782) : Batch loss : 0.27385392785072327
# Epoch(0/1 : Batch number(313/782) : Batch loss : 0.30077797174453735
# Epoch(0/1 : Batch number(314/782) : Batch loss : 0.32213571667671204
# Epoch(0/1 : Batch number(315/782) : Batch loss : 0.2969372868537903
# Epoch(0/1 : Batch number(316/782) : Batch loss : 0.5038842558860779
# Epoch(0/1 : Batch number(317/782) : Batch loss : 0.29833048582077026
# Epoch(0/1 : Batch number(318/782) : Batch loss : 0.34736013412475586
# Epoch(0/1 : Batch number(319/782) : Batch loss : 0.45758143067359924
# Epoch(0/1 : Batch number(320/782) : Batch loss : 0.2990161180496216
# Epoch(0/1 : Batch number(321/782) : Batch loss : 0.18399888277053833
# Epoch(0/1 : Batch number(322/782) : Batch loss : 0.33723336458206177
# Epoch(0/1 : Batch number(323/782) : Batch loss : 0.4085179567337036
# Epoch(0/1 : Batch number(324/782) : Batch loss : 0.21004870533943176
# Epoch(0/1 : Batch number(325/782) : Batch loss : 0.30075696110725403
# Epoch(0/1 : Batch number(326/782) : Batch loss : 0.44612157344818115
# Epoch(0/1 : Batch number(327/782) : Batch loss : 0.2980397045612335
# Epoch(0/1 : Batch number(328/782) : Batch loss : 0.47234922647476196
# Epoch(0/1 : Batch number(329/782) : Batch loss : 0.38965317606925964
# Epoch(0/1 : Batch number(330/782) : Batch loss : 0.3787052035331726
# Epoch(0/1 : Batch number(331/782) : Batch loss : 0.4827105402946472
# Epoch(0/1 : Batch number(332/782) : Batch loss : 0.32513880729675293
# Epoch(0/1 : Batch number(333/782) : Batch loss : 0.2846514582633972
# Epoch(0/1 : Batch number(334/782) : Batch loss : 0.47824499011039734
# Epoch(0/1 : Batch number(335/782) : Batch loss : 0.4499242901802063
# Epoch(0/1 : Batch number(336/782) : Batch loss : 0.26881322264671326
# Epoch(0/1 : Batch number(337/782) : Batch loss : 0.3492465615272522
# Epoch(0/1 : Batch number(338/782) : Batch loss : 0.28472089767456055
# Epoch(0/1 : Batch number(339/782) : Batch loss : 0.546711802482605
# Epoch(0/1 : Batch number(340/782) : Batch loss : 0.3312970697879791
# Epoch(0/1 : Batch number(341/782) : Batch loss : 0.3263656497001648
# Epoch(0/1 : Batch number(342/782) : Batch loss : 0.2983396649360657
# Epoch(0/1 : Batch number(343/782) : Batch loss : 0.3238949179649353
# Epoch(0/1 : Batch number(344/782) : Batch loss : 0.34269678592681885
# Epoch(0/1 : Batch number(345/782) : Batch loss : 0.38165828585624695
# Epoch(0/1 : Batch number(346/782) : Batch loss : 0.5291155576705933
# Epoch(0/1 : Batch number(347/782) : Batch loss : 0.3713682293891907
# Epoch(0/1 : Batch number(348/782) : Batch loss : 0.27441641688346863
# Epoch(0/1 : Batch number(349/782) : Batch loss : 0.26253122091293335
# Epoch(0/1 : Batch number(350/782) : Batch loss : 0.6345599889755249
# Epoch(0/1 : Batch number(351/782) : Batch loss : 0.1772957444190979
# Epoch(0/1 : Batch number(352/782) : Batch loss : 0.3819197118282318
# Epoch(0/1 : Batch number(353/782) : Batch loss : 0.3404500484466553
# Epoch(0/1 : Batch number(354/782) : Batch loss : 0.32821062207221985
# Epoch(0/1 : Batch number(355/782) : Batch loss : 0.40230071544647217
# Epoch(0/1 : Batch number(356/782) : Batch loss : 0.4205905795097351
# Epoch(0/1 : Batch number(357/782) : Batch loss : 0.3149620592594147
# Epoch(0/1 : Batch number(358/782) : Batch loss : 0.34447336196899414
# Epoch(0/1 : Batch number(359/782) : Batch loss : 0.2689903974533081
# Epoch(0/1 : Batch number(360/782) : Batch loss : 0.3169108033180237
# Epoch(0/1 : Batch number(361/782) : Batch loss : 0.37069427967071533
# Epoch(0/1 : Batch number(362/782) : Batch loss : 0.378330796957016
# Epoch(0/1 : Batch number(363/782) : Batch loss : 0.5157506465911865
# Epoch(0/1 : Batch number(364/782) : Batch loss : 0.37847602367401123
# Epoch(0/1 : Batch number(365/782) : Batch loss : 0.194169282913208
# Epoch(0/1 : Batch number(366/782) : Batch loss : 0.3749008774757385
# Epoch(0/1 : Batch number(367/782) : Batch loss : 0.4840846359729767
# Epoch(0/1 : Batch number(368/782) : Batch loss : 0.29739540815353394
# Epoch(0/1 : Batch number(369/782) : Batch loss : 0.5331357717514038
# Epoch(0/1 : Batch number(370/782) : Batch loss : 0.2642137110233307
# Epoch(0/1 : Batch number(371/782) : Batch loss : 0.27627307176589966
# Epoch(0/1 : Batch number(372/782) : Batch loss : 0.49070224165916443
# Epoch(0/1 : Batch number(373/782) : Batch loss : 0.36680811643600464
# Epoch(0/1 : Batch number(374/782) : Batch loss : 0.22183385491371155
# Epoch(0/1 : Batch number(375/782) : Batch loss : 0.20219124853610992
# Epoch(0/1 : Batch number(376/782) : Batch loss : 0.5666346549987793
# Epoch(0/1 : Batch number(377/782) : Batch loss : 0.3226887583732605
# Epoch(0/1 : Batch number(378/782) : Batch loss : 0.30049076676368713
# Epoch(0/1 : Batch number(379/782) : Batch loss : 0.3667765259742737
# Epoch(0/1 : Batch number(380/782) : Batch loss : 0.44500094652175903
# Epoch(0/1 : Batch number(381/782) : Batch loss : 0.19416487216949463
# Epoch(0/1 : Batch number(382/782) : Batch loss : 0.3541841208934784
# Epoch(0/1 : Batch number(383/782) : Batch loss : 0.2616341710090637
# Epoch(0/1 : Batch number(384/782) : Batch loss : 0.4386727511882782
# Epoch(0/1 : Batch number(385/782) : Batch loss : 0.4621090888977051
# Epoch(0/1 : Batch number(386/782) : Batch loss : 0.4367009997367859
# Epoch(0/1 : Batch number(387/782) : Batch loss : 0.321556031703949
# Epoch(0/1 : Batch number(388/782) : Batch loss : 0.5331633687019348
# Epoch(0/1 : Batch number(389/782) : Batch loss : 0.1972658336162567
# Epoch(0/1 : Batch number(390/782) : Batch loss : 0.43798530101776123
# Epoch(0/1 : Batch number(391/782) : Batch loss : 0.2644363045692444
# Epoch(0/1 : Batch number(392/782) : Batch loss : 0.3271033763885498
# Epoch(0/1 : Batch number(393/782) : Batch loss : 0.3478360176086426
# Epoch(0/1 : Batch number(394/782) : Batch loss : 0.27467238903045654
# Epoch(0/1 : Batch number(395/782) : Batch loss : 0.32953858375549316
# Epoch(0/1 : Batch number(396/782) : Batch loss : 0.2400684356689453
# Epoch(0/1 : Batch number(397/782) : Batch loss : 0.3854103684425354
# Epoch(0/1 : Batch number(398/782) : Batch loss : 0.33066755533218384
# Epoch(0/1 : Batch number(399/782) : Batch loss : 0.30297091603279114
# Epoch(0/1 : Batch number(400/782) : Batch loss : 0.4362480342388153
# Epoch(0/1 : Batch number(401/782) : Batch loss : 0.4831920862197876
# Epoch(0/1 : Batch number(402/782) : Batch loss : 0.5225009322166443
# Epoch(0/1 : Batch number(403/782) : Batch loss : 0.31727999448776245
# Epoch(0/1 : Batch number(404/782) : Batch loss : 0.4547152519226074
# Epoch(0/1 : Batch number(405/782) : Batch loss : 0.42371922731399536
# Epoch(0/1 : Batch number(406/782) : Batch loss : 0.40366020798683167
# Epoch(0/1 : Batch number(407/782) : Batch loss : 0.3587212860584259
# Epoch(0/1 : Batch number(408/782) : Batch loss : 0.6667173504829407
# Epoch(0/1 : Batch number(409/782) : Batch loss : 0.46927157044410706
# Epoch(0/1 : Batch number(410/782) : Batch loss : 0.25673866271972656
# Epoch(0/1 : Batch number(411/782) : Batch loss : 0.30008000135421753
# Epoch(0/1 : Batch number(412/782) : Batch loss : 0.20160913467407227
# Epoch(0/1 : Batch number(413/782) : Batch loss : 0.1873675286769867
# Epoch(0/1 : Batch number(414/782) : Batch loss : 0.23421385884284973
# Epoch(0/1 : Batch number(415/782) : Batch loss : 0.2579229474067688
# Epoch(0/1 : Batch number(416/782) : Batch loss : 0.3532836437225342
# Epoch(0/1 : Batch number(417/782) : Batch loss : 0.3606393337249756
# Epoch(0/1 : Batch number(418/782) : Batch loss : 0.4230632781982422
# Epoch(0/1 : Batch number(419/782) : Batch loss : 0.1683061420917511
# Epoch(0/1 : Batch number(420/782) : Batch loss : 0.2037256807088852
# Epoch(0/1 : Batch number(421/782) : Batch loss : 0.22337135672569275
# Epoch(0/1 : Batch number(422/782) : Batch loss : 0.24536322057247162
# Epoch(0/1 : Batch number(423/782) : Batch loss : 0.3706859052181244
# Epoch(0/1 : Batch number(424/782) : Batch loss : 0.24396035075187683
# Epoch(0/1 : Batch number(425/782) : Batch loss : 0.42580533027648926
# Epoch(0/1 : Batch number(426/782) : Batch loss : 0.303930401802063
# Epoch(0/1 : Batch number(427/782) : Batch loss : 0.5781649947166443
# Epoch(0/1 : Batch number(428/782) : Batch loss : 0.34603291749954224
# Epoch(0/1 : Batch number(429/782) : Batch loss : 0.3943411409854889
# Epoch(0/1 : Batch number(430/782) : Batch loss : 0.37891513109207153
# Epoch(0/1 : Batch number(431/782) : Batch loss : 0.39813312888145447
# Epoch(0/1 : Batch number(432/782) : Batch loss : 0.3662358522415161
# Epoch(0/1 : Batch number(433/782) : Batch loss : 0.25756293535232544
# Epoch(0/1 : Batch number(434/782) : Batch loss : 0.45123571157455444
# Epoch(0/1 : Batch number(435/782) : Batch loss : 0.3245466351509094
# Epoch(0/1 : Batch number(436/782) : Batch loss : 0.30990344285964966
# Epoch(0/1 : Batch number(437/782) : Batch loss : 0.3150862455368042
# Epoch(0/1 : Batch number(438/782) : Batch loss : 0.3144212067127228
# Epoch(0/1 : Batch number(439/782) : Batch loss : 0.30470025539398193
# Epoch(0/1 : Batch number(440/782) : Batch loss : 0.23046880960464478
# Epoch(0/1 : Batch number(441/782) : Batch loss : 0.44281989336013794
# Epoch(0/1 : Batch number(442/782) : Batch loss : 0.36902087926864624
# Epoch(0/1 : Batch number(443/782) : Batch loss : 0.22975477576255798
# Epoch(0/1 : Batch number(444/782) : Batch loss : 0.2185227870941162
# Epoch(0/1 : Batch number(445/782) : Batch loss : 0.37578892707824707
# Epoch(0/1 : Batch number(446/782) : Batch loss : 0.31867265701293945
# Epoch(0/1 : Batch number(447/782) : Batch loss : 0.29695597290992737
# Epoch(0/1 : Batch number(448/782) : Batch loss : 0.2537783682346344
# Epoch(0/1 : Batch number(449/782) : Batch loss : 0.4152596592903137
# Epoch(0/1 : Batch number(450/782) : Batch loss : 0.22755007445812225
# Epoch(0/1 : Batch number(451/782) : Batch loss : 0.38438931107521057
# Epoch(0/1 : Batch number(452/782) : Batch loss : 0.3381878137588501
# Epoch(0/1 : Batch number(453/782) : Batch loss : 0.28127601742744446
# Epoch(0/1 : Batch number(454/782) : Batch loss : 0.28362762928009033
# Epoch(0/1 : Batch number(455/782) : Batch loss : 0.49716904759407043
# Epoch(0/1 : Batch number(456/782) : Batch loss : 0.28735077381134033
# Epoch(0/1 : Batch number(457/782) : Batch loss : 0.3391021192073822
# Epoch(0/1 : Batch number(458/782) : Batch loss : 0.46547964215278625
# Epoch(0/1 : Batch number(459/782) : Batch loss : 0.32131144404411316
# Epoch(0/1 : Batch number(460/782) : Batch loss : 0.40152454376220703
# Epoch(0/1 : Batch number(461/782) : Batch loss : 0.32728880643844604
# Epoch(0/1 : Batch number(462/782) : Batch loss : 0.30447492003440857
# Epoch(0/1 : Batch number(463/782) : Batch loss : 0.4363189935684204
# Epoch(0/1 : Batch number(464/782) : Batch loss : 0.3611893355846405
# Epoch(0/1 : Batch number(465/782) : Batch loss : 0.34559258818626404
# Epoch(0/1 : Batch number(466/782) : Batch loss : 0.39039307832717896
# Epoch(0/1 : Batch number(467/782) : Batch loss : 0.2960363030433655
# Epoch(0/1 : Batch number(468/782) : Batch loss : 0.3215922713279724
# Epoch(0/1 : Batch number(469/782) : Batch loss : 0.3677932620048523
# Epoch(0/1 : Batch number(470/782) : Batch loss : 0.3629623353481293
# Epoch(0/1 : Batch number(471/782) : Batch loss : 0.30996525287628174
# Epoch(0/1 : Batch number(472/782) : Batch loss : 0.27902528643608093
# Epoch(0/1 : Batch number(473/782) : Batch loss : 0.3696618974208832
# Epoch(0/1 : Batch number(474/782) : Batch loss : 0.38482144474983215
# Epoch(0/1 : Batch number(475/782) : Batch loss : 0.39223968982696533
# Epoch(0/1 : Batch number(476/782) : Batch loss : 0.3916223645210266
# Epoch(0/1 : Batch number(477/782) : Batch loss : 0.31104612350463867
# Epoch(0/1 : Batch number(478/782) : Batch loss : 0.5499612092971802
# Epoch(0/1 : Batch number(479/782) : Batch loss : 0.40617191791534424
# Epoch(0/1 : Batch number(480/782) : Batch loss : 0.2774219810962677
# Epoch(0/1 : Batch number(481/782) : Batch loss : 0.40561825037002563
# Epoch(0/1 : Batch number(482/782) : Batch loss : 0.35204777121543884
# Epoch(0/1 : Batch number(483/782) : Batch loss : 0.3733025789260864
# Epoch(0/1 : Batch number(484/782) : Batch loss : 0.40597161650657654
# Epoch(0/1 : Batch number(485/782) : Batch loss : 0.40620914101600647
# Epoch(0/1 : Batch number(486/782) : Batch loss : 0.5066537261009216
# Epoch(0/1 : Batch number(487/782) : Batch loss : 0.17715799808502197
# Epoch(0/1 : Batch number(488/782) : Batch loss : 0.39810246229171753
# Epoch(0/1 : Batch number(489/782) : Batch loss : 0.3385487198829651
# Epoch(0/1 : Batch number(490/782) : Batch loss : 0.5030120611190796
# Epoch(0/1 : Batch number(491/782) : Batch loss : 0.2700013518333435
# Epoch(0/1 : Batch number(492/782) : Batch loss : 0.25049641728401184
# Epoch(0/1 : Batch number(493/782) : Batch loss : 0.3242274820804596
# Epoch(0/1 : Batch number(494/782) : Batch loss : 0.1710757464170456
# Epoch(0/1 : Batch number(495/782) : Batch loss : 0.1983686089515686
# Epoch(0/1 : Batch number(496/782) : Batch loss : 0.3174472153186798
# Epoch(0/1 : Batch number(497/782) : Batch loss : 0.3574816584587097
# Epoch(0/1 : Batch number(498/782) : Batch loss : 0.5561038851737976
# Epoch(0/1 : Batch number(499/782) : Batch loss : 0.2564046382904053
# Epoch(0/1 : Batch number(500/782) : Batch loss : 0.3678622841835022
# Epoch(0/1 : Batch number(501/782) : Batch loss : 0.3591267466545105
# Epoch(0/1 : Batch number(502/782) : Batch loss : 0.3279535174369812
# Epoch(0/1 : Batch number(503/782) : Batch loss : 0.5286173224449158
# Epoch(0/1 : Batch number(504/782) : Batch loss : 0.4204421043395996
# Epoch(0/1 : Batch number(505/782) : Batch loss : 0.3177160620689392
# Epoch(0/1 : Batch number(506/782) : Batch loss : 0.4749784469604492
# Epoch(0/1 : Batch number(507/782) : Batch loss : 0.1879068911075592
# Epoch(0/1 : Batch number(508/782) : Batch loss : 0.2620161771774292
# Epoch(0/1 : Batch number(509/782) : Batch loss : 0.38453179597854614
# Epoch(0/1 : Batch number(510/782) : Batch loss : 0.4586678743362427
# Epoch(0/1 : Batch number(511/782) : Batch loss : 0.3919260501861572
# Epoch(0/1 : Batch number(512/782) : Batch loss : 0.4227123260498047
# Epoch(0/1 : Batch number(513/782) : Batch loss : 0.2888904809951782
# Epoch(0/1 : Batch number(514/782) : Batch loss : 0.4847010374069214
# Epoch(0/1 : Batch number(515/782) : Batch loss : 0.26086747646331787
# Epoch(0/1 : Batch number(516/782) : Batch loss : 0.40354689955711365
# Epoch(0/1 : Batch number(517/782) : Batch loss : 0.36040475964546204
# Epoch(0/1 : Batch number(518/782) : Batch loss : 0.6032034158706665
# Epoch(0/1 : Batch number(519/782) : Batch loss : 0.32806700468063354
# Epoch(0/1 : Batch number(520/782) : Batch loss : 0.28103750944137573
# Epoch(0/1 : Batch number(521/782) : Batch loss : 0.2963220179080963
# Epoch(0/1 : Batch number(522/782) : Batch loss : 0.36072248220443726
# Epoch(0/1 : Batch number(523/782) : Batch loss : 0.4777821898460388
# Epoch(0/1 : Batch number(524/782) : Batch loss : 0.2830663025379181
# Epoch(0/1 : Batch number(525/782) : Batch loss : 0.23531126976013184
# Epoch(0/1 : Batch number(526/782) : Batch loss : 0.25945019721984863
# Epoch(0/1 : Batch number(527/782) : Batch loss : 0.3138590455055237
# Epoch(0/1 : Batch number(528/782) : Batch loss : 0.22998449206352234
# Epoch(0/1 : Batch number(529/782) : Batch loss : 0.5258719325065613
# Epoch(0/1 : Batch number(530/782) : Batch loss : 0.28289636969566345
# Epoch(0/1 : Batch number(531/782) : Batch loss : 0.26737308502197266
# Epoch(0/1 : Batch number(532/782) : Batch loss : 0.39546236395835876
# Epoch(0/1 : Batch number(533/782) : Batch loss : 0.30605340003967285
# Epoch(0/1 : Batch number(534/782) : Batch loss : 0.3807035982608795
# Epoch(0/1 : Batch number(535/782) : Batch loss : 0.6332889199256897
# Epoch(0/1 : Batch number(536/782) : Batch loss : 0.35760486125946045
# Epoch(0/1 : Batch number(537/782) : Batch loss : 0.634487509727478
# Epoch(0/1 : Batch number(538/782) : Batch loss : 0.4903244078159332
# Epoch(0/1 : Batch number(539/782) : Batch loss : 0.22531890869140625
# Epoch(0/1 : Batch number(540/782) : Batch loss : 0.16204045712947845
# Epoch(0/1 : Batch number(541/782) : Batch loss : 0.2499203234910965
# Epoch(0/1 : Batch number(542/782) : Batch loss : 0.4523686170578003
# Epoch(0/1 : Batch number(543/782) : Batch loss : 0.28821390867233276
# Epoch(0/1 : Batch number(544/782) : Batch loss : 0.6061722040176392
# Epoch(0/1 : Batch number(545/782) : Batch loss : 0.47585082054138184
# Epoch(0/1 : Batch number(546/782) : Batch loss : 0.33169716596603394
# Epoch(0/1 : Batch number(547/782) : Batch loss : 0.4406723976135254
# Epoch(0/1 : Batch number(548/782) : Batch loss : 0.3460240662097931
# Epoch(0/1 : Batch number(549/782) : Batch loss : 0.2946091890335083
# Epoch(0/1 : Batch number(550/782) : Batch loss : 0.25867050886154175
# Epoch(0/1 : Batch number(551/782) : Batch loss : 0.22991043329238892
# Epoch(0/1 : Batch number(552/782) : Batch loss : 0.39399951696395874
# Epoch(0/1 : Batch number(553/782) : Batch loss : 0.548916757106781
# Epoch(0/1 : Batch number(554/782) : Batch loss : 0.48240378499031067
# Epoch(0/1 : Batch number(555/782) : Batch loss : 0.25930023193359375
# Epoch(0/1 : Batch number(556/782) : Batch loss : 0.41291841864585876
# Epoch(0/1 : Batch number(557/782) : Batch loss : 0.4703797698020935
# Epoch(0/1 : Batch number(558/782) : Batch loss : 0.42273569107055664
# Epoch(0/1 : Batch number(559/782) : Batch loss : 0.5336227416992188
# Epoch(0/1 : Batch number(560/782) : Batch loss : 0.22060415148735046
# Epoch(0/1 : Batch number(561/782) : Batch loss : 0.2958603501319885
# Epoch(0/1 : Batch number(562/782) : Batch loss : 0.3282337486743927
# Epoch(0/1 : Batch number(563/782) : Batch loss : 0.18482238054275513
# Epoch(0/1 : Batch number(564/782) : Batch loss : 0.4434431493282318
# Epoch(0/1 : Batch number(565/782) : Batch loss : 0.3062063455581665
# Epoch(0/1 : Batch number(566/782) : Batch loss : 0.41540274024009705
# Epoch(0/1 : Batch number(567/782) : Batch loss : 0.34416937828063965
# Epoch(0/1 : Batch number(568/782) : Batch loss : 0.5190648436546326
# Epoch(0/1 : Batch number(569/782) : Batch loss : 0.4863506853580475
# Epoch(0/1 : Batch number(570/782) : Batch loss : 0.36976611614227295
# Epoch(0/1 : Batch number(571/782) : Batch loss : 0.2727365493774414
# Epoch(0/1 : Batch number(572/782) : Batch loss : 0.2368452101945877
# Epoch(0/1 : Batch number(573/782) : Batch loss : 0.3865487575531006
# Epoch(0/1 : Batch number(574/782) : Batch loss : 0.31597810983657837
# Epoch(0/1 : Batch number(575/782) : Batch loss : 0.41574782133102417
# Epoch(0/1 : Batch number(576/782) : Batch loss : 0.29588404297828674
# Epoch(0/1 : Batch number(577/782) : Batch loss : 0.4249539375305176
# Epoch(0/1 : Batch number(578/782) : Batch loss : 0.2149907648563385
# Epoch(0/1 : Batch number(579/782) : Batch loss : 0.25884318351745605
# Epoch(0/1 : Batch number(580/782) : Batch loss : 0.32059240341186523
# Epoch(0/1 : Batch number(581/782) : Batch loss : 0.4634254276752472
# Epoch(0/1 : Batch number(582/782) : Batch loss : 0.37800920009613037
# Epoch(0/1 : Batch number(583/782) : Batch loss : 0.3017098307609558
# Epoch(0/1 : Batch number(584/782) : Batch loss : 0.5524423718452454
# Epoch(0/1 : Batch number(585/782) : Batch loss : 0.2072415053844452
# Epoch(0/1 : Batch number(586/782) : Batch loss : 0.2454875260591507
# Epoch(0/1 : Batch number(587/782) : Batch loss : 0.2221968173980713
# Epoch(0/1 : Batch number(588/782) : Batch loss : 0.2944984436035156
# Epoch(0/1 : Batch number(589/782) : Batch loss : 0.38286957144737244
# Epoch(0/1 : Batch number(590/782) : Batch loss : 0.2249930053949356
# Epoch(0/1 : Batch number(591/782) : Batch loss : 0.37158581614494324
# Epoch(0/1 : Batch number(592/782) : Batch loss : 0.27277177572250366
# Epoch(0/1 : Batch number(593/782) : Batch loss : 0.37645819783210754
# Epoch(0/1 : Batch number(594/782) : Batch loss : 0.3725854158401489
# Epoch(0/1 : Batch number(595/782) : Batch loss : 0.4055253863334656
# Epoch(0/1 : Batch number(596/782) : Batch loss : 0.39371418952941895
# Epoch(0/1 : Batch number(597/782) : Batch loss : 0.25595197081565857
# Epoch(0/1 : Batch number(598/782) : Batch loss : 0.3797113299369812
# Epoch(0/1 : Batch number(599/782) : Batch loss : 0.26928073167800903
# Epoch(0/1 : Batch number(600/782) : Batch loss : 0.3105725049972534
# Epoch(0/1 : Batch number(601/782) : Batch loss : 0.35164526104927063
# Epoch(0/1 : Batch number(602/782) : Batch loss : 0.4579613208770752
# Epoch(0/1 : Batch number(603/782) : Batch loss : 0.36984702944755554
# Epoch(0/1 : Batch number(604/782) : Batch loss : 0.44691482186317444
# Epoch(0/1 : Batch number(605/782) : Batch loss : 0.4748189449310303
# Epoch(0/1 : Batch number(606/782) : Batch loss : 0.2888532876968384
# Epoch(0/1 : Batch number(607/782) : Batch loss : 0.211777463555336
# Epoch(0/1 : Batch number(608/782) : Batch loss : 0.3936076760292053
# Epoch(0/1 : Batch number(609/782) : Batch loss : 0.3295638859272003
# Epoch(0/1 : Batch number(610/782) : Batch loss : 0.23755624890327454
# Epoch(0/1 : Batch number(611/782) : Batch loss : 0.34766852855682373
# Epoch(0/1 : Batch number(612/782) : Batch loss : 0.31402885913848877
# Epoch(0/1 : Batch number(613/782) : Batch loss : 0.4109625816345215
# Epoch(0/1 : Batch number(614/782) : Batch loss : 0.2912876009941101
# Epoch(0/1 : Batch number(615/782) : Batch loss : 0.30294278264045715
# Epoch(0/1 : Batch number(616/782) : Batch loss : 0.20229630172252655
# Epoch(0/1 : Batch number(617/782) : Batch loss : 0.42223918437957764
# Epoch(0/1 : Batch number(618/782) : Batch loss : 0.482706755399704
# Epoch(0/1 : Batch number(619/782) : Batch loss : 0.34383130073547363
# Epoch(0/1 : Batch number(620/782) : Batch loss : 0.30329835414886475
# Epoch(0/1 : Batch number(621/782) : Batch loss : 0.2622714936733246
# Epoch(0/1 : Batch number(622/782) : Batch loss : 0.3634519577026367
# Epoch(0/1 : Batch number(623/782) : Batch loss : 0.42337313294410706
# Epoch(0/1 : Batch number(624/782) : Batch loss : 0.28814974427223206
# Epoch(0/1 : Batch number(625/782) : Batch loss : 0.32068949937820435
# Epoch(0/1 : Batch number(626/782) : Batch loss : 0.3184039294719696
# Epoch(0/1 : Batch number(627/782) : Batch loss : 0.30555182695388794
# Epoch(0/1 : Batch number(628/782) : Batch loss : 0.5179579257965088
# Epoch(0/1 : Batch number(629/782) : Batch loss : 0.3732903003692627
# Epoch(0/1 : Batch number(630/782) : Batch loss : 0.4283149838447571
# Epoch(0/1 : Batch number(631/782) : Batch loss : 0.33671629428863525
# Epoch(0/1 : Batch number(632/782) : Batch loss : 0.42435288429260254
# Epoch(0/1 : Batch number(633/782) : Batch loss : 0.4724539518356323
# Epoch(0/1 : Batch number(634/782) : Batch loss : 0.33609557151794434
# Epoch(0/1 : Batch number(635/782) : Batch loss : 0.24766305088996887
# Epoch(0/1 : Batch number(636/782) : Batch loss : 0.3833959698677063
# Epoch(0/1 : Batch number(637/782) : Batch loss : 0.30215996503829956
# Epoch(0/1 : Batch number(638/782) : Batch loss : 0.42892515659332275
# Epoch(0/1 : Batch number(639/782) : Batch loss : 0.2901313006877899
# Epoch(0/1 : Batch number(640/782) : Batch loss : 0.2762252688407898
# Epoch(0/1 : Batch number(641/782) : Batch loss : 0.34284889698028564
# Epoch(0/1 : Batch number(642/782) : Batch loss : 0.2846866250038147
# Epoch(0/1 : Batch number(643/782) : Batch loss : 0.2864999771118164
# Epoch(0/1 : Batch number(644/782) : Batch loss : 0.3743875026702881
# Epoch(0/1 : Batch number(645/782) : Batch loss : 0.2694271206855774
# Epoch(0/1 : Batch number(646/782) : Batch loss : 0.20834951102733612
# Epoch(0/1 : Batch number(647/782) : Batch loss : 0.2862784266471863
# Epoch(0/1 : Batch number(648/782) : Batch loss : 0.2578738033771515
# Epoch(0/1 : Batch number(649/782) : Batch loss : 0.3645212650299072
# Epoch(0/1 : Batch number(650/782) : Batch loss : 0.5139133930206299
# Epoch(0/1 : Batch number(651/782) : Batch loss : 0.26414740085601807
# Epoch(0/1 : Batch number(652/782) : Batch loss : 0.4037960469722748
# Epoch(0/1 : Batch number(653/782) : Batch loss : 0.29895681142807007
# Epoch(0/1 : Batch number(654/782) : Batch loss : 0.3034692704677582
# Epoch(0/1 : Batch number(655/782) : Batch loss : 0.447470486164093
# Epoch(0/1 : Batch number(656/782) : Batch loss : 0.3714165687561035
# Epoch(0/1 : Batch number(657/782) : Batch loss : 0.31617844104766846
# Epoch(0/1 : Batch number(658/782) : Batch loss : 0.25308290123939514
# Epoch(0/1 : Batch number(659/782) : Batch loss : 0.25591403245925903
# Epoch(0/1 : Batch number(660/782) : Batch loss : 0.4346475601196289
# Epoch(0/1 : Batch number(661/782) : Batch loss : 0.3027467131614685
# Epoch(0/1 : Batch number(662/782) : Batch loss : 0.2071525752544403
# Epoch(0/1 : Batch number(663/782) : Batch loss : 0.23048290610313416
# Epoch(0/1 : Batch number(664/782) : Batch loss : 0.2545625567436218
# Epoch(0/1 : Batch number(665/782) : Batch loss : 0.361674427986145
# Epoch(0/1 : Batch number(666/782) : Batch loss : 0.3394395112991333
# Epoch(0/1 : Batch number(667/782) : Batch loss : 0.40756407380104065
# Epoch(0/1 : Batch number(668/782) : Batch loss : 0.35889771580696106
# Epoch(0/1 : Batch number(669/782) : Batch loss : 0.24960258603096008
# Epoch(0/1 : Batch number(670/782) : Batch loss : 0.5103439688682556
# Epoch(0/1 : Batch number(671/782) : Batch loss : 0.34819650650024414
# Epoch(0/1 : Batch number(672/782) : Batch loss : 0.41212570667266846
# Epoch(0/1 : Batch number(673/782) : Batch loss : 0.27036258578300476
# Epoch(0/1 : Batch number(674/782) : Batch loss : 0.33769088983535767
# Epoch(0/1 : Batch number(675/782) : Batch loss : 0.37209147214889526
# Epoch(0/1 : Batch number(676/782) : Batch loss : 0.19886088371276855
# Epoch(0/1 : Batch number(677/782) : Batch loss : 0.29773932695388794
# Epoch(0/1 : Batch number(678/782) : Batch loss : 0.37949636578559875
# Epoch(0/1 : Batch number(679/782) : Batch loss : 0.2975507378578186
# Epoch(0/1 : Batch number(680/782) : Batch loss : 0.4032920002937317
# Epoch(0/1 : Batch number(681/782) : Batch loss : 0.3148173689842224
# Epoch(0/1 : Batch number(682/782) : Batch loss : 0.30688604712486267
# Epoch(0/1 : Batch number(683/782) : Batch loss : 0.26635825634002686
# Epoch(0/1 : Batch number(684/782) : Batch loss : 0.2945583462715149
# Epoch(0/1 : Batch number(685/782) : Batch loss : 0.3097046911716461
# Epoch(0/1 : Batch number(686/782) : Batch loss : 0.3777065575122833
# Epoch(0/1 : Batch number(687/782) : Batch loss : 0.3163720369338989
# Epoch(0/1 : Batch number(688/782) : Batch loss : 0.2700107991695404
# Epoch(0/1 : Batch number(689/782) : Batch loss : 0.5490942597389221
# Epoch(0/1 : Batch number(690/782) : Batch loss : 0.3136671185493469
# Epoch(0/1 : Batch number(691/782) : Batch loss : 0.3982997536659241
# Epoch(0/1 : Batch number(692/782) : Batch loss : 0.3717077970504761
# Epoch(0/1 : Batch number(693/782) : Batch loss : 0.517022967338562
# Epoch(0/1 : Batch number(694/782) : Batch loss : 0.3333180844783783
# Epoch(0/1 : Batch number(695/782) : Batch loss : 0.3556535243988037
# Epoch(0/1 : Batch number(696/782) : Batch loss : 0.29081881046295166
# Epoch(0/1 : Batch number(697/782) : Batch loss : 0.4455987215042114
# Epoch(0/1 : Batch number(698/782) : Batch loss : 0.4271128177642822
# Epoch(0/1 : Batch number(699/782) : Batch loss : 0.3400196433067322
# Epoch(0/1 : Batch number(700/782) : Batch loss : 0.2618911862373352
# Epoch(0/1 : Batch number(701/782) : Batch loss : 0.34468287229537964
# Epoch(0/1 : Batch number(702/782) : Batch loss : 0.3684128224849701
# Epoch(0/1 : Batch number(703/782) : Batch loss : 0.2933584749698639
# Epoch(0/1 : Batch number(704/782) : Batch loss : 0.4333541691303253
# Epoch(0/1 : Batch number(705/782) : Batch loss : 0.2824542224407196
# Epoch(0/1 : Batch number(706/782) : Batch loss : 0.261599063873291
# Epoch(0/1 : Batch number(707/782) : Batch loss : 0.41183745861053467
# Epoch(0/1 : Batch number(708/782) : Batch loss : 0.25571388006210327
# Epoch(0/1 : Batch number(709/782) : Batch loss : 0.3875630497932434
# Epoch(0/1 : Batch number(710/782) : Batch loss : 0.24325454235076904
# Epoch(0/1 : Batch number(711/782) : Batch loss : 0.3016999363899231
# Epoch(0/1 : Batch number(712/782) : Batch loss : 0.24522536993026733
# Epoch(0/1 : Batch number(713/782) : Batch loss : 0.1816437840461731
# Epoch(0/1 : Batch number(714/782) : Batch loss : 0.23093974590301514
# Epoch(0/1 : Batch number(715/782) : Batch loss : 0.38106977939605713
# Epoch(0/1 : Batch number(716/782) : Batch loss : 0.43180742859840393
# Epoch(0/1 : Batch number(717/782) : Batch loss : 0.32518666982650757
# Epoch(0/1 : Batch number(718/782) : Batch loss : 0.32400235533714294
# Epoch(0/1 : Batch number(719/782) : Batch loss : 0.4829275906085968
# Epoch(0/1 : Batch number(720/782) : Batch loss : 0.26322174072265625
# Epoch(0/1 : Batch number(721/782) : Batch loss : 0.324082612991333
# Epoch(0/1 : Batch number(722/782) : Batch loss : 0.3187030851840973
# Epoch(0/1 : Batch number(723/782) : Batch loss : 0.2598077058792114
# Epoch(0/1 : Batch number(724/782) : Batch loss : 0.33123207092285156
# Epoch(0/1 : Batch number(725/782) : Batch loss : 0.2384994775056839
# Epoch(0/1 : Batch number(726/782) : Batch loss : 0.3073420524597168
# Epoch(0/1 : Batch number(727/782) : Batch loss : 0.5075702667236328
# Epoch(0/1 : Batch number(728/782) : Batch loss : 0.31395062804222107
# Epoch(0/1 : Batch number(729/782) : Batch loss : 0.2996285557746887
# Epoch(0/1 : Batch number(730/782) : Batch loss : 0.42076408863067627
# Epoch(0/1 : Batch number(731/782) : Batch loss : 0.2861657738685608
# Epoch(0/1 : Batch number(732/782) : Batch loss : 0.36619362235069275
# Epoch(0/1 : Batch number(733/782) : Batch loss : 0.33506500720977783
# Epoch(0/1 : Batch number(734/782) : Batch loss : 0.3723216652870178
# Epoch(0/1 : Batch number(735/782) : Batch loss : 0.4221004247665405
# Epoch(0/1 : Batch number(736/782) : Batch loss : 0.159153014421463
# Epoch(0/1 : Batch number(737/782) : Batch loss : 0.43253305554389954
# Epoch(0/1 : Batch number(738/782) : Batch loss : 0.25360894203186035
# Epoch(0/1 : Batch number(739/782) : Batch loss : 0.2856482267379761
# Epoch(0/1 : Batch number(740/782) : Batch loss : 0.25310224294662476
# Epoch(0/1 : Batch number(741/782) : Batch loss : 0.39683711528778076
# Epoch(0/1 : Batch number(742/782) : Batch loss : 0.3859531879425049
# Epoch(0/1 : Batch number(743/782) : Batch loss : 0.3768098056316376
# Epoch(0/1 : Batch number(744/782) : Batch loss : 0.22570613026618958
# Epoch(0/1 : Batch number(745/782) : Batch loss : 0.4406195878982544
# Epoch(0/1 : Batch number(746/782) : Batch loss : 0.280071884393692
# Epoch(0/1 : Batch number(747/782) : Batch loss : 0.4858895540237427
# Epoch(0/1 : Batch number(748/782) : Batch loss : 0.45827120542526245
# Epoch(0/1 : Batch number(749/782) : Batch loss : 0.2717663049697876
# Epoch(0/1 : Batch number(750/782) : Batch loss : 0.2587428689002991
# Epoch(0/1 : Batch number(751/782) : Batch loss : 0.313371479511261
# Epoch(0/1 : Batch number(752/782) : Batch loss : 0.2822495400905609
# Epoch(0/1 : Batch number(753/782) : Batch loss : 0.4463120102882385
# Epoch(0/1 : Batch number(754/782) : Batch loss : 0.3223622441291809
# Epoch(0/1 : Batch number(755/782) : Batch loss : 0.3273252248764038
# Epoch(0/1 : Batch number(756/782) : Batch loss : 0.4591098129749298
# Epoch(0/1 : Batch number(757/782) : Batch loss : 0.4521329402923584
# Epoch(0/1 : Batch number(758/782) : Batch loss : 0.31722283363342285
# Epoch(0/1 : Batch number(759/782) : Batch loss : 0.4603036642074585
# Epoch(0/1 : Batch number(760/782) : Batch loss : 0.45203930139541626
# Epoch(0/1 : Batch number(761/782) : Batch loss : 0.3845888078212738
# Epoch(0/1 : Batch number(762/782) : Batch loss : 0.37806326150894165
# Epoch(0/1 : Batch number(763/782) : Batch loss : 0.4697816073894501
# Epoch(0/1 : Batch number(764/782) : Batch loss : 0.45621734857559204
# Epoch(0/1 : Batch number(765/782) : Batch loss : 0.4529048502445221
# Epoch(0/1 : Batch number(766/782) : Batch loss : 0.4899970293045044
# Epoch(0/1 : Batch number(767/782) : Batch loss : 0.2575657367706299
# Epoch(0/1 : Batch number(768/782) : Batch loss : 0.30408453941345215
# Epoch(0/1 : Batch number(769/782) : Batch loss : 0.1429777592420578
# Epoch(0/1 : Batch number(770/782) : Batch loss : 0.46093320846557617
# Epoch(0/1 : Batch number(771/782) : Batch loss : 0.29603248834609985
# Epoch(0/1 : Batch number(772/782) : Batch loss : 0.22540731728076935
# Epoch(0/1 : Batch number(773/782) : Batch loss : 0.36483529210090637
# Epoch(0/1 : Batch number(774/782) : Batch loss : 0.23880138993263245
# Epoch(0/1 : Batch number(775/782) : Batch loss : 0.35433435440063477
# Epoch(0/1 : Batch number(776/782) : Batch loss : 0.37521374225616455
# Epoch(0/1 : Batch number(777/782) : Batch loss : 0.23513823747634888
# Epoch(0/1 : Batch number(778/782) : Batch loss : 0.4984719157218933
# Epoch(0/1 : Batch number(779/782) : Batch loss : 0.27548471093177795
# Epoch(0/1 : Batch number(780/782) : Batch loss : 0.2892357110977173
# Epoch(0/1 : Batch number(781/782) : Batch loss : 0.24925567209720612
# Epoch(0/1 : Batch number(782/782) : Batch loss : 0.3094531297683716
# Training loss : 0.3488912426907083

# %% [markdown]
# ### The accuracy of the model

# %%
model.to('cpu')

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0

    #set_trace()
    for batch, (images, labels) in enumerate(testloader,1):
        
        logps = model(images)
        output = torch.exp(logps)
        
        pred = torch.argmax(output, 1)
        total += labels.size(0)
        num_correct += (pred == labels).sum().item()
        print(f'Batch ({batch}/{len(testloader)})')
        
        if batch == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 84.0625%
